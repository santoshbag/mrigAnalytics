# %%
# import necessary libraries
# !pip install yfinance
# !pip install mplfinance
import mrigutilities as mu
import pandas as pd
import yfinance as yf
import numpy as np
import math
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

name = 'SBIN.NS'
[levels,df] = mu.getLevels(name)

# for visualization
def plot_all(levels, df):    
  fig, ax = plt.subplots(figsize=(16, 9))   
  candlestick_ohlc(ax,df.values,width=0.6, colorup='green', 
    colordown='red', alpha=0.8)    
  date_format = mpl_dates.DateFormatter('%d %b %Y')
  ax.xaxis.set_major_formatter(date_format)    
  for level in levels:        
    plt.hlines(level[1], xmin = df['Date'][level[0]], xmax = 
      max(df['Date']), colors='blue', linestyle='--')    
  fig.show()

plot_all(levels,df)
# Out:
# Requirement already satisfied: yfinance in c:\anaconda\lib\site-packages (0.2.12)
# Requirement already satisfied: frozendict>=2.3.4 in c:\anaconda\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: cryptography>=3.3.2 in c:\anaconda\lib\site-packages (from yfinance) (38.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\anaconda\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in c:\anaconda\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in c:\anaconda\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: multitasking>=0.0.7 in c:\anaconda\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\anaconda\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\anaconda\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.26 in c:\anaconda\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: mplfinance in c:\anaconda\lib\site-packages (0.12.9b7)
# Requirement already satisfied: pandas in c:\anaconda\lib\site-packages (from mplfinance) (1.4.4)
# Requirement already satisfied: matplotlib in c:\anaconda\lib\site-packages (from mplfinance) (3.6.3)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas->mplfinance) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# C:\anaconda\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_15992\2969485872.py:26: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
[levels,df] = mu.getLevels(name,method='window')
plot_all(levels,df)
# Out:
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_15992\2969485872.py:26: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
