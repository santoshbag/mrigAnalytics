# %%
import mrigutilities as mu
import pandas as pd
import datetime
import os,sys
import yahooquery as yq
import kite.kite_trade as zkite
import json
from mrigquery import fundamentals as funda
import interface.web.webdashboard as wdb

pd.options.display.float_format = '${:,.2f}'.format

expiry1 = mu.last_thursday_of_month(datetime.date.today())
expiry2 = mu.last_thursday_of_month(expiry1 + datetime.timedelta(days=30))
expiry3 = mu.last_thursday_of_month(expiry2 + datetime.timedelta(days=30))
expiry1,expiry2, expiry3
session = mu.getKiteSession()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
engine = mu.sql_engine()
# Out:
# C:\Users\santoshbag\anaconda3\Lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   __warnings.warn('\n\n  ================================================================='+
# connection active

# %%
import requests

# Example API URL
url = "http://127.0.0.1:8000/api/stockdata/SBIN/1Y"

# Send GET request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data
    json_data = response.json()
    print(json_data)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# [{"date":1702857600000,"symbol":"SBIN","series":"EQ","prev_close":648.25,"open":646.65,"high":655.65,"low":642.4,"last":647.6,"close":648.5,"vwap":null,"volume":16221796.0,"turnover":10544832650.9500007629,"trades":347590.0,"deliverable_volume":null,"per_deliverable_volume":null,"pe":null,"pb":null,"div_yield":null,"close_adj":648.5,"volume_adj":null,"nse_vol":null,"index_members":null,"daily_logreturns":null,"SMA_20":null,"SMA_60":null,"SMA_100":null},{"date":1702944000000,"symbol":"SBIN","series":"EQ","prev_close":648.5,"open":648.5,"high":659.6,"low":640.25,"last":656.0,"close":655.4,"vwap":null,"volume":19964008.0,"turnover":13034125974.8500003815,"trades":384049.0,"deliverable_volume":null,"per_deliverable_volume":null,"pe":null,"pb":null,"div_yield":null,"close_adj":655.4,"volume_adj":null,"nse_vol":null,"index_members":null,"daily_logreturns":0.0105837325,"SMA_20":null,"SMA_60":null,"SMA_100":null},{"date":1703030400000,"symbol":"SBIN","series":"EQ","prev_close":655.4,"open":6
# ...

# %%
import yfinance as yf

df = yf.download('^NSEI',period='5d',interval='1m')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Datetime
# 2024-10-28 09:15:00+05:30 $24,275.35 $24,288.90 $24,239.90 $24,250.95
# 2024-10-28 09:16:00+05:30 $24,252.55 $24,263.85 $24,235.25 $24,263.85
# 2024-10-28 09:17:00+05:30 $24,265.15 $24,270.50 $24,245.85 $24,247.80
# 2024-10-28 09:18:00+05:30 $24,244.40 $24,248.40 $24,232.70 $24,243.05
# 2024-10-28 09:19:00+05:30 $24,243.30 $24,251.65 $24,241.00 $24,249.65
# 2024-10-28 09:20:00+05:30 $24,248.80 $24,255.95 $24,231.05 $24,249.45
# 2024-10-28 09:21:00+05:30 $24,249.65 $24,258.80 $24,239.00 $24,243.85
# 2024-10-28 09:22:00+05:30 $24,243.85 $24,270.60 $24,243.85 $24,270.60
# 2024-10-28 09:23:00+05:30 $24,269.05 $24,273.20 $24,261.30 $24,264.40
# 2024-10-28 09:24:00+05:30 $24,265.15 $24,275.20 $24,260.40 $24,272.95
# 2024-10-28 09:25:00+05:30 $24,269.50 $24,274.85 $24,255.80 $24,258.90
# ...

# %%
# ten30 = df.loc[(df.index  <= '2024-10-31') & (df.index  > '2024-10-30')]
# ten29 = df.loc[(df.index  <= '2024-10-29') & (df.index  > '2024-10-28')]
# len(ten30)
# len(ten29)
(max(df.index).date() - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
df.loc[(df.index  > (max(df.index).date() - datetime.timedelta(days=1)).strftime('%Y-%m-%d'))]
# Out:
# '2024-10-30'

# %%
stocks = wdb.mrigweb_stock_mini('SBIN')
stocks = json.dumps(stocks)
stocks
# Out:
# [*********************100%%**********************]  1 of 1 completed
# {}
# [['Last Price', 'Open', 'Previous Close', 'Day High', 'Day Low', '52 Week High', '52 Week Low'], [804.6500244140625, 806.0499877929688, 781.45, 807.5, 801.5999755859375, 905.65, 547.0]]
# Return List : Getting from Database
# Return List : Getting from Database
# Ratio List : Creating Table
# Income Statement : Creating Table
# Balance Sheet : Creating Table
# ...
