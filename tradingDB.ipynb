# %%
import tradingDB as tdb
import pandas as pd

def highlight(s):
    if s.l_s == '':
        return ['background-color: yellow'] * len(s)
    else:
        return ['background-color: white'] * len(s)
# Out:
# C:\anaconda\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
pos = tdb.showDB(flag=True,diagnostic=False)

df1 = pos.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()

df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')

df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')


df = (pd.concat([df1, df3])
        .reindex(df1.columns, axis=1)
        .fillna('')
        .sort_values(['scrip','l_s'], ascending=True,ignore_index=True))
#df.set_index('scrip',inplace=True)

df.style.apply(highlight, axis=1).format(precision=0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:105: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = positions.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:107: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:109: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_14888\1819101778.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = pos.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_14888\1819101778.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_14888\1819101778.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')
# <style type="text/css">
# #T_34ed8_row0_col0, #T_34ed8_row0_col1, #T_34ed8_row0_col2, #T_34ed8_row0_col3, #T_34ed8_row0_col4, #T_34ed8_row0_col5, #T_34ed8_row0_col6, #T_34ed8_row0_col7, #T_34ed8_row0_col8, #T_34ed8_row3_col0, #T_34ed8_row3_col1, #T_34ed8_row3_col2, #T_34ed8_row3_col3, #T_34ed8_row3_col4, #T_34ed8_row3_col5, #T_34ed8_row3_col6, #T_34ed8_row3_col7, #T_34ed8_row3_col8, #T_34ed8_row16_col0, #T_34ed8_row16_col1, #T_34ed8_row16_col2, #T_34ed8_row16_col3, #T_34ed8_row16_col4, #T_34ed8_row16_col5, #T_34ed8_row16_col6, #T_34ed8_row16_col7, #T_34ed8_row16_col8, #T_34ed8_row20_col0, #T_34ed8_row20_col1, #T_34ed8_row20_col2, #T_34ed8_row20_col3, #T_34ed8_row20_col4, #T_34ed8_row20_col5, #T_34ed8_row20_col6, #T_34ed8_row20_col7, #T_34ed8_row20_col8, #T_34ed8_row35_col0, #T_34ed8_row35_col1, #T_34ed8_row35_col2, #T_34ed8_row35_col3, #T_34ed8_row35_col4, #T_34ed8_row35_col5, #T_34ed8_row35_col6, #T_34ed8_row35_col7, #T_34ed8_row35_col8 {
#   background-color: yellow;
# }
_row14_col2, #T_34ed8_row14_col3, #T_34ed8_row14_col4, #T_34ed8_row14_col5, #T_34ed8_row14_col6, #T_34ed8_row14_col7, #T_34ed8_row14_col8, #T_34ed8_row15_col0, #T_34ed8_row15_col1, #T_34ed8_row15_col2, #T_34ed8_row15_col3, #T_34ed8_row15_col4, #T_34ed8_row15_col5, #T_34ed8_row15_col6, #T_34ed8_row15_col7, #T_34ed8_row15_col8, #T_34ed8_row17_col0, #T_34ed8_row17_col1, #T_34ed8_row17_col2, #T_34ed8_row17_col3, #T_34ed8_row17_col4, #T_34ed8_row17_col5, #T_34ed8_row17_col6, #T_34ed8_row17_col7, #T_34ed8_row17_col8, #T_34ed8_row18_col0, #T_34ed8_row18_col1, #T_34ed8_row18_col2, #T_34ed8_row18_col3, #T_34ed8_row18_col4, #T_34ed8_row18_col5, #T_34ed8_row18_col6, #T_34ed8_row18_col7, #T_34ed8_row18_col8, #T_34ed8_row19_col0, #T_34ed8_row19_col1, #T_34ed8_row19_col2, #T_34ed8_row19_col3, #T_34ed8_row19_col4, #T_34ed8_row19_col5, #T_34ed8_row19_col6, #T_34ed8_row19_col7, #T_34ed8_row19_col8, #T_34ed8_row21_col0, #T_34ed8_row21_col1, #T_34ed8_row21_col2, #T_34ed8_row21_col3, #T_34ed8_row21_col4, #T_34ed8_row21_col5, #T_34ed8_row21_col6, #T_34ed8_row21_col7, #T_34ed8_row21_col8, #T_34ed8_row22_col0, #T_34ed8_row22_col1, #T_34ed8_row22_col2, #T_34ed8_row22_col3, #T_34ed8_row22_col4, #T_34ed8_row22_col5, #T_34ed8_row22_col6, #T_34ed8_row22_col7, #T_34ed8_row22_col8, #T_34ed8_row23_col0, #T_34ed8_row23_col1, #T_34ed8_row23_col2, #T_34ed8_row23_col3, #T_34ed8_row23_col4, #T_34ed8_row23_col5, #T_34ed8_row23_col6, #T_34ed8_row23_col7, #T_34ed8_row23_col8, #T_34ed8_row24_col0, #T_34ed8_row24_col1, #T_34ed8_row24_col2, #T_34ed8_row24_col3, #T_34ed8_row24_col4, #T_34ed8_row24_col5, #T_34ed8_row24_col6, #T_34ed8_row24_col7, #T_34ed8_row24_col8, #T_34ed8_row25_col0, #T_34ed8_row25_col1, #T_34ed8_row25_col2, #T_34ed8_row25_col3, #T_34ed8_row25_col4 ...
#   background-color: white;
# }
# </style>
# <table id="T_34ed8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ed8_level0_col0" class="col_heading level0 col0" >scrip</th>
#       <th id="T_34ed8_level0_col1" class="col_heading level0 col1" >instrument</th>
#       <th id="T_34ed8_level0_col2" class="col_heading level0 col2" >l_s</th>
#       <th id="T_34ed8_level0_col3" class="col_heading level0 col3" >qty</th>
#       <th id="T_34ed8_level0_col4" class="col_heading level0 col4" >orig_liab</th>
#       <th id="T_34ed8_level0_col5" class="col_heading level0 col5" >curr_liab</th>
#       <th id="T_34ed8_level0_col6" class="col_heading leve
