# %%
import mrigutilities as mu
import pandas as pd
import datetime
import os,sys
import yahooquery as yq
import kite.kite_trade as zkite
import json

expiry1 = mu.last_thursday_of_month(datetime.date.today())
expiry2 = mu.last_thursday_of_month(expiry1 + datetime.timedelta(days=30))
expiry3 = mu.last_thursday_of_month(expiry2 + datetime.timedelta(days=30))
expiry1,expiry2, expiry3
session = mu.getKiteSession()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
engine = mu.sql_engine()
# Out:
# connection active

# %%
from yahooquery import Ticker

symbol_list_yahoo = ['TATAPOWER.NS', 'TATAMOTORS.NS']

ticker = Ticker(symbol_list_yahoo) 
fin_data_dict = ticker.financial_data
fin_data_df = pd.DataFrame.from_dict(fin_data_dict, orient='index').T
fin_data_df

# %%
# from xbrl import XBRLParser, GAAP, GAAPSerializer
import xml.etree.ElementTree as ET
import requests
eq_dir_qtr = os.path.join('resources','equity_research','FINRESULTS_QTRLY_AXISBANK.csv')
eq_dir_ann = os.path.join('resources','equity_research','FINRESULTS_ANNUAL_AXISBANK.csv')


def parse_xbrl(url):
    result = pd.DataFrame()
    i = 0
    s = requests.Session()
    headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    # finres = pd.DataFrame.from_dict(results, orient='index')
    # finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    return results



sym = os.path.basename(eq_dir).split('.')[0].split('_')[2]
# print(sym)



url = ['https://nsearchives.nseindia.com/corporate/xbrl/BANKING_104623_1105106_21042024122701.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_101078_1023175_16012024051131.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_97616_956099_17102023052102.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_94218_888372_17072023062652.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_90715_821266_17042023022426.xml']

data = pd.read_csv(eq_dir_ann)
cols = {'CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
data = data[cols.keys()]
data['symbol'] = sym
data.rename(columns=cols,inplace=True)
data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
data = data[data['period_ended'] > datetime.date(2020,1,1)] 
data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
print(data['results'])

# %%
# Implementation of specific results file with specific name format having only one symbol

import zipfile,re
import requests
import xml.etree.ElementTree as ET


headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}


def parse_xbrl(url):
    result = pd.DataFrame()
    # print(url)
    i = 0
    s = requests.Session()
    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    finres = pd.DataFrame.from_dict(results, orient='index')
    finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    results = json.dumps(results)
    return results


eq_dir_qtr = os.path.join('resources','equity_research')
timestamp = datetime.datetime.now()
for r,d,f in os.walk(eq_dir_qtr):
    for file in f:
        if re.search("^FINRESULTS_.*csv",file):
        # if re.search("^FINRESULTS_ANNUAL_TATAMOTORS.*csv",file):            
            sym = os.path.basename(file).split('.')[0].split('_')[2]

            # stockbhavlist.append(os.path.join(r,file))
            file = os.path.join(r,file)
            print(file)
            data = pd.read_csv(file)
            cols = {'CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
            data = data[cols.keys()]
            data['symbol'] = sym
            data.rename(columns=cols,inplace=True)
            data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
            data = data[data['period_ended'] > datetime.date(2020,1,1)] 
            data = data[data['consolidated'] == 'Consolidated']
            try:
                data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
                data['timestamp'] = timestamp
                data.drop('xbrl_url', axis=1, inplace=True)
                data.to_sql('financial_results',engine,if_exists='append',index=False)
                print(data)#[['consolidated','xbrl_url','results']])
            except:
                pass

# %%
# Implementation of general results file having several symbols together

import zipfile,re
import requests
import xml.etree.ElementTree as ET


headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}


def parse_xbrl(url):
    result = pd.DataFrame()
    # print(url)
    i = 0
    s = requests.Session()
    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    finres = pd.DataFrame.from_dict(results, orient='index')
    finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    results = json.dumps(results)
    return results

def getSymbol(company_desc):
    print(company_desc)
    sym = company_desc
    try:
        sym = engine.execute("select symbol from security_master where stock_name='"+company_desc+"' limit 1").fetchone()[0]
    except:
        pass
    return sym

eq_dir_qtr = os.path.join('resources','equity_research')
timestamp = datetime.datetime.now()
for r,d,f in os.walk(eq_dir_qtr):
    for file in f:
        if re.search("^FINANCIAL_RESULTS.*csv",file):
        # if re.search("^FINRESULTS_ANNUAL_TATAMOTORS.*csv",file):            
            # sym = os.path.basename(file).split('.')[0].split('_')[2]

            # stockbhavlist.append(os.path.join(r,file))
            file = os.path.join(r,file)
            print(file)
            data = pd.read_csv(file)
            cols = {'COMPANY NAME':'symbol','CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
            data = data[cols.keys()]
            data.rename(columns=cols,inplace=True)
            data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
            data = data[data['period_ended'] > datetime.date(2020,1,1)] 
            data = data[data['consolidated'] == 'Consolidated']
            try:
                data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
                data['timestamp'] = timestamp
                data.drop('xbrl_url', axis=1, inplace=True)
                data['symbol'] = data['symbol'].apply(lambda x: getSymbol(x))                
                # data.to_sql('financial_results',engine,if_exists='append',index=False)
                print(data)#[['consolidated','xbrl_url','results']])
            except:
                pass
            print(data)
# Out:
# resources\equity_research\FINANCIAL_RESULTS.csv
# HDFC Bank Limited
# Poonawalla Fincorp Limited
# Rossari Biotech Limited
# Aarti Surfactants Limited
# Gravita India Limited
# Arihant Capital Markets Limited
# Vikas Lifecare Limited
# Shakti Pumps (India) Limited
# JK Cement Limited
# Kotak Mahindra Bank Limited
# Kabra Extrusion Technik Limited
# Seshasayee Paper and Boards Limited
# Yes Bank Limited
# Integra Essentia Limited
# Union Bank of India
# RBL Bank Limited
# Summit Securities Limited
# Aurum PropTech Limited
# Tree House Education & Accessories Limited
# Ksolves India Limited
# Blue Dart Express Limited
# ROUTE MOBILE LIMITED
# Mahindra EPC Irrigation Limited
# Bharat Petroleum Corporation Limited
# PVR INOX Limited
# Reliance Industries Limited
# JSW Energy Limited
# Patanjali Foods Limited
# Oberoi Realty Limited
# Tejas Networks Limited
# Jubilant Pharmova Limited
# JSW Steel Limited
# Nippon Life India Asset Management Limited
# CREDITACCESS GRAMEEN LIMITED
# UltraTech Cement Limited
# The Indian Hotels Company Limited
# One 97 Communications Limited
# CIE Automotive India Limited
# Wipro Limited
# Transformers And Rectifiers (India) Limited
# Atul Limited
# Sagar Cements Limited
# Onward Technologies Limited
# Aether Industries Limited
# Inventure Growth & Securities Limited
# L&T Technology Services Limited
# Tanla Platforms Limited
# Havells India Limited
# Grindwell Norton Limited
# Premier Explosives Limited
# Infosys Limited
# The South Indian Bank Limited
# CEAT Limited
# Shoppers Stop Limited
# Tata Communications Limited
# Sterling and Wilson Renewable Energy Limited
# Choice International Limited
# Persistent Systems Limited
# Polycab India Limited
# Dalmia Bharat Limited
# Menon Bearings Limited
# Reliance Industrial Infrastructure Limited
# Central Bank of India
# JSW Infrastructure Limited
# Tata Technologies Limited
# Newgen Software Technologies Limited
# Mastek Limited
# Vimta Labs Limited
# Asian Paints Limited
# Hathway Cable & Datacom Limited
# LTIMindtree Limited
# Alok Industries Limited
# TV18 Broadcast Limited
# Network18 Media & Investments Limited
# Elecon Engineering Company Limited
# Jubilant Ingrevia Limited
# Agro Tech Foods Limited
# CRISIL Limited
# L&T Finance Limited
# Himadri Speciality Chemical Limited
# Century Textiles & Industries Limited
# Bajaj Auto Limited
# Viceroy Hotels Limited
# Kellton Tech Solutions Limited
# D.B.Corp Limited
# Angel One Limited
# Jio Financial Services Limited
# Den Networks Limited
# Monarch Networth Capital Limited
# HDFC Asset Management Company Limited
# Bank of Maharashtra
# Ganesh Housing Corporation Limited
# Geojit Financial Services Limited
# Avenue Supermarts Limited
# Bhansali Engineering Polymers Limited
# Excel Realty N Infra Limited
# HCL Technologies Limited
# 5Paisa Capital Limited
# Oriental Hotels Limited
# Vipul Limited
# NELCO Limited
# GTPL Hathway Limited
# Tata Consultancy Services Limited
# GNA Axles Limited
# JTL INDUSTRIES LIMITED
# Wealth First Portfolio Managers Limited
# DRC Systems India Limited
# Hexa Tradex Limited
# Lancor Holdings Limited
# Kesoram Industries Limited
# KCP Sugar and Industries Corporation Limited
# Delta Corp Limited
# R. S. Software (India) Limited
# Shalby Limited
#          symbol  consolidated     period period_ended     related_qtr  \
# 0      HDFCBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 4    POONAWALLA  Consolidated  Quarterly   2024-06-30   First Quarter
# 6       ROSSARI  Consolidated  Quarterly   2024-06-30   First Quarter
# 8     AARTISURF  Consolidated  Quarterly   2024-06-30   First Quarter
# 10      GRAVITA  Consolidated  Quarterly   2024-06-30   First Quarter
# 12   ARIHANTCAP  Consolidated  Quarterly   2024-06-30   First Quarter
# 14    VIKASLIFE  Consolidated  Quarterly   2024-06-30   First Quarter
# 18   SHAKTIPUMP  Consolidated  Quarterly   2024-06-30   First Quarter
# 19     JKCEMENT  Consolidated  Quarterly   2024-06-30   First Quarter
# 22    KOTAKBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 24   KABRAEXTRU  Consolidated  Quarterly   2024-06-30   First Quarter
# 26   SESHAPAPER  Consolidated  Quarterly   2024-06-30   First Quarter
# 28      YESBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 31     ESSENTIA  Consolidated  Quarterly   2024-06-30   First Quarter
# 34    UNIONBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 35      RBLBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 37    SUMMITSEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 39        AURUM  Consolidated  Quarterly   2024-06-30   First Quarter
# 42    TREEHOUSE  Consolidated  Quarterly   2024-06-30   First Quarter
# 44      KSOLVES  Consolidated  Quarterly   2024-06-30   First Quarter
# 46     BLUEDART  Consolidated  Quarterly   2024-06-30   First Quarter
# 48        ROUTE  Consolidated  Quarterly   2024-06-30   First Quarter
# 50       MAHEPC  Consolidated  Quarterly   2024-06-30   First Quarter
# 52         BPCL  Consolidated  Quarterly   2024-06-30   First Quarter
# 54      PVRINOX  Consolidated  Quarterly   2024-06-30   First Quarter
# 58     RELIANCE  Consolidated  Quarterly   2024-06-30   First Quarter
# 60    JSWENERGY  Consolidated  Quarterly   2024-06-30   First Quarter
# 62    PATANJALI  Consolidated  Quarterly   2024-06-30   First Quarter
# 64   OBEROIRLTY  Consolidated  Quarterly   2024-06-30   First Quarter
# 66     TEJASNET  Consolidated  Quarterly   2024-06-30   First Quarter
# 68   JUBLPHARMA  Consolidated  Quarterly   2024-06-30   First Quarter
# 71     JSWSTEEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 73    NAM-INDIA  Consolidated  Quarterly   2024-06-30   First Quarter
# 75    CREDITACC  Consolidated  Quarterly   2024-06-30   First Quarter
# 77   ULTRACEMCO  Consolidated  Quarterly   2024-06-30   First Quarter
# 79     INDHOTEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 82        PAYTM  Consolidated  Quarterly   2024-06-30   First Quarter
# 86     CIEINDIA  Consolidated  Quarterly   2024-06-30  Second Quarter
# 87        WIPRO  Consolidated  Quarterly   2024-06-30   First Quarter
# 89         TRIL  Consolidated  Quarterly   2024-06-30   First Quarter
# 91         ATUL  Consolidated  Quarterly   2024-06-30   First Quarter
# 94       SAGCEM  Consolidated  Quarterly   2024-06-30   First Quarter
# 98    ONWARDTEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 100      AETHER  Consolidated  Quarterly   2024-06-30   First Quarter
# 102   INVENTURE  Consolidated  Quarterly   2024-06-30   First Quarter
# 104        LTTS  Consolidated  Quarterly   2024-06-30   First Quarter
# 106       TANLA  Consolidated  Quarterly   2024-06-30   First Quarter
# 109     HAVELLS  Consolidated  Quarterly   2024-06-30   First Quarter
# 111   GRINDWELL  Consolidated  Quarterly   2024-06-30   First Quarter
# 113   PREMEXPLN  Consolidated  Quarterly   2024-06-30   First Quarter
# 115        INFY  Consolidated  Quarterly   2024-06-30   First Quarter
# 117   SOUTHBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 118     CEATLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 121  SHOPERSTOP  Consolidated  Quarterly   2024-06-30   First Quarter
# 125    TATACOMM  Consolidated  Quarterly   2024-06-30   First Quarter
# 127     SWSOLAR  Consolidated  Quarterly   2024-06-30   First Quarter
# 129    CHOICEIN  Consolidated  Quarterly   2024-06-30   First Quarter
# 131  PERSISTENT  Consolidated  Quarterly   2024-06-30   First Quarter
# 133     POLYCAB  Consolidated  Quarterly   2024-06-30   First Quarter
# 135   DALMIABHA  Consolidated  Quarterly   2024-06-30   First Quarter
# 137     MENONBE  Consolidated  Quarterly   2024-06-30   First Quarter
# 138        RIIL  Consolidated  Quarterly   2024-06-30   First Quarter
# 141   CENTRALBK  Consolidated  Quarterly   2024-06-30   First Quarter
# 145    JSWINFRA  Consolidated  Quarterly   2024-06-30   First Quarter
# 147    TATATECH  Consolidated  Quarterly   2024-06-30   First Quarter
# 149      NEWGEN  Consolidated  Quarterly   2024-06-30   First Quarter
# 152      MASTEK  Consolidated  Quarterly   2024-06-30   First Quarter
# 158   VIMTALABS  Consolidated  Quarterly   2024-06-30   First Quarter
# 159  ASIANPAINT  Consolidated  Quarterly   2024-06-30   First Quarter
# 161     HATHWAY  Consolidated  Quarterly   2024-06-30   First Quarter
# 163        LTIM  Consolidated  Quarterly   2024-06-30   First Quarter
# 166    ALOKTEXT  Consolidated  Quarterly   2024-06-30   First Quarter
# 168  TV18BRDCST  Consolidated  Quarterly   2024-06-30   First Quarter
# 170   NETWORK18  Consolidated  Quarterly   2024-06-30   First Quarter
# 172      ELECON  Consolidated  Quarterly   2024-06-30   First Quarter
# 174  JUBLINGREA  Consolidated  Quarterly   2024-06-30   First Quarter
# 176        ATFL  Consolidated  Quarterly   2024-06-30   First Quarter
# 179      CRISIL  Consolidated  Quarterly   2024-06-30  Second Quarter
# 182         LTF  Consolidated  Quarterly   2024-06-30   First Quarter
# 184        HSCL  Consolidated  Quarterly   2024-06-30   First Quarter
# 185  CENTURYTEX  Consolidated  Quarterly   2024-06-30   First Quarter
# 188  BAJAJ-AUTO  Consolidated  Quarterly   2024-06-30   First Quarter
# 190       VHLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 192  KELLTONTEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 195      DBCORP  Consolidated  Quarterly   2024-06-30   First Quarter
# 200    ANGELONE  Consolidated  Quarterly   2024-06-30   First Quarter
# 202      JIOFIN  Consolidated  Quarterly   2024-06-30   First Quarter
# 205         DEN  Consolidated  Quarterly   2024-06-30   First Quarter
# 208     MONARCH  Consolidated  Quarterly   2024-06-30   First Quarter
# 211     HDFCAMC  Consolidated  Quarterly   2024-06-30   First Quarter
# 214    MAHABANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 217  GANESHHOUC  Consolidated  Quarterly   2024-06-30   First Quarter
# 220   GEOJITFSL  Consolidated  Quarterly   2024-06-30   First Quarter
# 222       DMART  Consolidated  Quarterly   2024-06-30   First Quarter
# 225        BEPL  Consolidated  Quarterly   2024-06-30   First Quarter
# 227       EXCEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 231     HCLTECH  Consolidated  Quarterly   2024-06-30   First Quarter
# 233      5PAISA  Consolidated  Quarterly   2024-06-30   First Quarter
# 236   ORIENTHOT  Consolidated  Quarterly   2024-06-30   First Quarter
# 238    VIPULLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 240       NELCO  Consolidated  Quarterly   2024-06-30   First Quarter
# 242        GTPL  Consolidated  Quarterly   2024-06-30   First Quarter
# 243         TCS  Consolidated  Quarterly   2024-06-30   First Quarter
# 247         GNA  Consolidated  Quarterly   2024-06-30   First Quarter
# 249      JTLIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 251      WEALTH  Consolidated  Quarterly   2024-06-30   First Quarter
# 254  DRCSYSTEMS  Consolidated  Quarterly   2024-06-30   First Quarter
# 256  HEXATRADEX  Consolidated  Quarterly   2024-06-30   First Quarter
# 259   LANCORHOL  Consolidated  Quarterly   2024-06-30   First Quarter
# 260  KESORAMIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 262   KCPSUGIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 264   DELTACORP  Consolidated  Quarterly   2024-06-30   First Quarter
# 266  RSSOFTWARE  Consolidated  Quarterly   2024-06-30   First Quarter
# 270      SHALBY  Consolidated  Quarterly   2024-06-30   First Quarter
#
#                                                results  \
# 0    {"ScripCode": "500180", "Symbol": "HDFCBANK", ...
# 4    {"ScripCode": "524000", "Symbol": "POONAWALLA"...
# 6    {"ScripCode": "543213", "Symbol": "ROSSARI", "...
# 8    {"ScripCode": "543210", "Symbol": "AARTISURF",...
# 10   {"ScripCode": "533282", "Symbol": "GRAVITA", "...
# 12   {"ScripCode": "511605", "Symbol": "ARIHANTCAP"...
# 14   {"ScripCode": "542655", "Symbol": "VIKASLIFE",...
# 18   {"ScripCode": "531431", "Symbol": "SHAKTIPUMP"...
# 19   {"ScripCode": "532644", "Symbol": "JKCEMENT", ...
# 22   {"ScripCode": "500247", "Symbol": "KOTAKBANK",...
# 24   {"ScripCode": "524109", "Symbol": "KABRAEXTRU"...
# 26   {"ScripCode": "502450", "Symbol": "SESHAPAPER"...
# 28   {"ScripCode": "532648", "Symbol": "YESBANK", "...
# 31   {"ScripCode": "535958", "Symbol": "ESSENTIA", ...
# 34   {"ScripCode": "532477", "Symbol": "UNIONBANK",...
# 35   {"ScripCode": "540065", "Symbol": "RBLBANK", "...
# 37   {"ScripCode": "533306", "Symbol": "SUMMITSEC",...
# 39   {"ScripCode": "539289", "Symbol": "AURUM", "MS...
# 42   {"ScripCode": "533540", "Symbol": "TREEHOUSE",...
# 44   {"ScripCode": "543599", "Symbol": "KSOLVES", "...
# 46   {"ScripCode": "526612", "Symbol": "BLUEDART", ...
# 48   {"ScripCode": "543228", "Symbol": "ROUTE", "MS...
# 50   {"ScripCode": "523754", "Symbol": "MAHEPC", "M...
# 52   {"ScripCode": "500547", "Symbol": "BPCL", "MSE...
# 54   {"ScripCode": "532689", "Symbol": "PVRINOX", "...
# 58   {"ScripCode": "500325", "Symbol": "RELIANCE", ...
# 60   {"ScripCode": "533148", "Symbol": "JSWENERGY",...
# 62   {"ScripCode": "500368", "Symbol": "PATANJALI",...
# 64   {"ScripCode": "533273", "Symbol": "OBEROIRLTY"...
# 66   {"ScripCode": "540595", "Symbol": "TEJASNET", ...
# 68   {"ScripCode": "530019", "Symbol": "JUBLPHARMA"...
# 71   {"ScripCode": "500228", "Symbol": "JSWSTEEL", ...
# 73   {"ScripCode": "540767", "Symbol": "NAM-INDIA",...
# 75   {"ScripCode": "541770", "Symbol": "CREDITACC",...
# 77   {"ScripCode": "532538", "Symbol": "ULTRACEMCO"...
# 79   {"ScripCode": "500850", "Symbol": "INDHOTEL", ...
# 82   {"ScripCode": "543396", "Symbol": "PAYTM", "MS...
# 86   {"ScripCode": "532756", "Symbol": "CIEINDIA", ...
# 87   {"ScripCode": "507685", "Symbol": "WIPRO", "MS...
# 89   {"ScripCode": "532928", "Symbol": "TRIL", "MSE...
# 91   {"ScripCode": "500027", "Symbol": "ATUL", "MSE...
# 94   {"ScripCode": "502090", "Symbol": "SAGCEM", "M...
# 98   {"ScripCode": "517536", "Symbol": "ONWARDTEC",...
# 100  {"ScripCode": "543534", "Symbol": "AETHER", "M...
# 102  {"ScripCode": "533506", "Symbol": "INVENTURE",...
# 104  {"ScripCode": "540115", "Symbol": "LTTS", "MSE...
# 106  {"ScripCode": "532790", "Symbol": "TANLA", "MS...
# 109  {"ScripCode": "517354", "Symbol": "HAVELLS", "...
# 111  {"ScripCode": "506076", "Symbol": "GRINDWELL",...
# 113  {"ScripCode": "526247", "Symbol": "PREMEXPLN",...
# 115  {"ScripCode": "500209", "Symbol": "INFY", "MSE...
# 117  {"ScripCode": "532218", "Symbol": "SOUTHBANK",...
# 118  {"ScripCode": "500878", "Symbol": "CEATLTD", "...
# 121  {"ScripCode": "532638", "Symbol": "SHOPERSTOP"...
# 125  {"ScripCode": "500483", "Symbol": "TATACOMM", ...
# 127  {"ScripCode": "542760", "Symbol": "SWSOLAR", "...
# 129  {"ScripCode": "531358", "Symbol": "CHOICEIN", ...
# 131  {"ScripCode": "533179", "Symbol": "PERSISTENT"...
# 133  {"ScripCode": "542652", "Symbol": "POLYCAB", "...
# 135  {"ScripCode": "542216", "Symbol": "DALBHARAT",...
# 137  {"ScripCode": "523828", "Symbol": "MENONBE", "...
# 138  {"ScripCode": "523445", "Symbol": "RIIL", "MSE...
# 141  {"ScripCode": "532885", "Symbol": "CENTRALBK",...
# 145  {"ScripCode": "543994", "Symbol": "JSWINFRA", ...
# 147  {"ScripCode": "544028", "Symbol": "TATATECH", ...
# 149  {"ScripCode": "540900", "Symbol": "NEWGEN", "M...
# 152  {"ScripCode": "523704", "Symbol": "MASTEK", "M...
# 158  {"ScripCode": "524394", "Symbol": "VIMTALABS",...
# 159  {"ScripCode": "500820", "Symbol": "ASIANPAINT"...
# 161  {"ScripCode": "533162", "Symbol": "HATHWAY", "...
# 163  {"ScripCode": "540005", "Symbol": "LTIM", "MSE...
# 166  {"ScripCode": "521070", "Symbol": "ALOKINDS", ...
# 168  {"ScripCode": "532800", "Symbol": "TV18BRDCST"...
# 170  {"ScripCode": "532798", "Symbol": "NETWORK18",...
# 172  {"ScripCode": "505700", "Symbol": "ELECON", "M...
# 174  {"ScripCode": "543271", "Symbol": "JUBLINGREA"...
# 176  {"ScripCode": "500215", "Symbol": "ATFL", "MSE...
# 179  {"ScripCode": "500092", "Symbol": "CRISIL", "M...
# 182  {"ScripCode": "533519", "Symbol": "LTF", "MSEI...
# 184  {"ScripCode": "500184", "Symbol": "HSCL", "MSE...
# 185  {"ScripCode": "500040", "Symbol": "CENTURYTEX"...
# 188  {"ScripCode": "532977", "Symbol": "BAJAJ-AUTO"...
# 190  {"ScripCode": "523796", "Symbol": "VHLTD", "MS...
# 192  {"ScripCode": "519602", "Symbol": "KELLTONTEC"...
# 195  {"ScripCode": "533151", "Symbol": "DBCORP", "M...
# 200  {"ScripCode": "543235", "Symbol": "ANGELONE", ...
# 202  {"ScripCode": "543940", "Symbol": "JIOFIN", "M...
# 205  {"ScripCode": "533137", "Symbol": "DEN", "MSEI...
# 208  {"ScripCode": "511551", "Symbol": "MONARCH", "...
# 211  {"ScripCode": "541729", "Symbol": "HDFCAMC", "...
# 214  {"ScripCode": "532525", "Symbol": "MAHABANK", ...
# 217  {"ScripCode": "526367", "Symbol": "GANESHHOUC"...
# 220  {"ScripCode": "532285", "Symbol": "GEOJITFSL",...
# 222  {"ScripCode": "540376", "Symbol": "DMART", "MS...
# 225  {"ScripCode": "500052", "Symbol": "BEPL", "MSE...
# 227  {"ScripCode": "533090", "Symbol": "EXCEL", "MS...
# 231  {"ScripCode": "532281", "Symbol": "HCLTECH", "...
# 233  {"ScripCode": "540776", "Symbol": "5PAISA", "M...
# 236  {"ScripCode": "500314", "Symbol": "ORIENTHOT",...
# 238  {"ScripCode": "511726", "Symbol": "VIPULLTD", ...
# 240  {"ScripCode": "504112", "Symbol": "NELCO", "MS...
# 242  {"ScripCode": "540602", "Symbol": "GTPL", "MSE...
# 243  {"ScripCode": "532540", "Symbol": "TCS", "MSEI...
# 247  {"ScripCode": "540124", "Symbol": "GNA", "MSEI...
# 249  {"ScripCode": "534600", "Symbol": "JTLIND", "M...
# 251  {"ScripCode": "123456", "Symbol": "WEALTH", "M...
# 254  {"ScripCode": "543268", "Symbol": "DRCSYSTEMS"...
# 256  {"ScripCode": "534328", "Symbol": "HEXATRADEX"...
# 259  {"ScripCode": "509048", "Symbol": "LANCORHOL",...
# 260  {"ScripCode": "502937", "Symbol": "KESORAMIND"...
# 262  {"ScripCode": "533192", "Symbol": "KCPSUGIND",...
# 264  {"ScripCode": "532848", "Symbol": "DELTACORP",...
# 266  {"ScripCode": "517447", "Symbol": "RSSOFTWARE"...
# 270  {"ScripCode": "540797", "Symbol": "SHALBY", "M...
#
#                      timestamp
# 0   2024-07-23 10:27:25.581147
# 4   2024-07-23 10:27:25.581147
# 6   2024-07-23 10:27:25.581147
# 8   2024-07-23 10:27:25.581147
# 10  2024-07-23 10:27:25.581147
# 12  2024-07-23 10:27:25.581147
# 14  2024-07-23 10:27:25.581147
# 18  2024-07-23 10:27:25.581147
# 19  2024-07-23 10:27:25.581147
# 22  2024-07-23 10:27:25.581147
# 24  2024-07-23 10:27:25.581147
# 26  2024-07-23 10:27:25.581147
# 28  2024-07-23 10:27:25.581147
# 31  2024-07-23 10:27:25.581147
# 34  2024-07-23 10:27:25.581147
# 35  2024-07-23 10:27:25.581147
# 37  2024-07-23 10:27:25.581147
# 39  2024-07-23 10:27:25.581147
# 42  2024-07-23 10:27:25.581147
# 44  2024-07-23 10:27:25.581147
# 46  2024-07-23 10:27:25.581147
# 48  2024-07-23 10:27:25.581147
# 50  2024-07-23 10:27:25.581147
# 52  2024-07-23 10:27:25.581147
# 54  2024-07-23 10:27:25.581147
# 58  2024-07-23 10:27:25.581147
# 60  2024-07-23 10:27:25.581147
# 62  2024-07-23 10:27:25.581147
# 64  2024-07-23 10:27:25.581147
# 66  2024-07-23 10:27:25.581147
# 68  2024-07-23 10:27:25.581147
# 71  2024-07-23 10:27:25.581147
# 73  2024-07-23 10:27:25.581147
# 75  2024-07-23 10:27:25.581147
# 77  2024-07-23 10:27:25.581147
# 79  2024-07-23 10:27:25.581147
# 82  2024-07-23 10:27:25.581147
# 86  2024-07-23 10:27:25.581147
# 87  2024-07-23 10:27:25.581147
# 89  2024-07-23 10:27:25.581147
# 91  2024-07-23 10:27:25.581147
# 94  2024-07-23 10:27:25.581147
# 98  2024-07-23 10:27:25.581147
# 100 2024-07-23 10:27:25.581147
# 102 2024-07-23 10:27:25.581147
# 104 2024-07-23 10:27:25.581147
# 106 2024-07-23 10:27:25.581147
# 109 2024-07-23 10:27:25.581147
# 111 2024-07-23 10:27:25.581147
# 113 2024-07-23 10:27:25.581147
# 115 2024-07-23 10:27:25.581147
# 117 2024-07-23 10:27:25.581147
# 118 2024-07-23 10:27:25.581147
# 121 2024-07-23 10:27:25.581147
# 125 2024-07-23 10:27:25.581147
# 127 2024-07-23 10:27:25.581147
# 129 2024-07-23 10:27:25.581147
# 131 2024-07-23 10:27:25.581147
# 133 2024-07-23 10:27:25.581147
# 135 2024-07-23 10:27:25.581147
# 137 2024-07-23 10:27:25.581147
# 138 2024-07-23 10:27:25.581147
# 141 2024-07-23 10:27:25.581147
# 145 2024-07-23 10:27:25.581147
# 147 2024-07-23 10:27:25.581147
# 149 2024-07-23 10:27:25.581147
# 152 2024-07-23 10:27:25.581147
# 158 2024-07-23 10:27:25.581147
# 159 2024-07-23 10:27:25.581147
# 161 2024-07-23 10:27:25.581147
# 163 2024-07-23 10:27:25.581147
# 166 2024-07-23 10:27:25.581147
# 168 2024-07-23 10:27:25.581147
# 170 2024-07-23 10:27:25.581147
# 172 2024-07-23 10:27:25.581147
# 174 2024-07-23 10:27:25.581147
# 176 2024-07-23 10:27:25.581147
# 179 2024-07-23 10:27:25.581147
# 182 2024-07-23 10:27:25.581147
# 184 2024-07-23 10:27:25.581147
# 185 2024-07-23 10:27:25.581147
# 188 2024-07-23 10:27:25.581147
# 190 2024-07-23 10:27:25.581147
# 192 2024-07-23 10:27:25.581147
# 195 2024-07-23 10:27:25.581147
# 200 2024-07-23 10:27:25.581147
# 202 2024-07-23 10:27:25.581147
# 205 2024-07-23 10:27:25.581147
# 208 2024-07-23 10:27:25.581147
# 211 2024-07-23 10:27:25.581147
# 214 2024-07-23 10:27:25.581147
# 217 2024-07-23 10:27:25.581147
# 220 2024-07-23 10:27:25.581147
# 222 2024-07-23 10:27:25.581147
# 225 2024-07-23 10:27:25.581147
# 227 2024-07-23 10:27:25.581147
# 231 2024-07-23 10:27:25.581147
# 233 2024-07-23 10:27:25.581147
# 236 2024-07-23 10:27:25.581147
# 238 2024-07-23 10:27:25.581147
# 240 2024-07-23 10:27:25.581147
# 242 2024-07-23 10:27:25.581147
# 243 2024-07-23 10:27:25.581147
# 247 2024-07-23 10:27:25.581147
# 249 2024-07-23 10:27:25.581147
# 251 2024-07-23 10:27:25.581147
# 254 2024-07-23 10:27:25.581147
# 256 2024-07-23 10:27:25.581147
# 259 2024-07-23 10:27:25.581147
# 260 2024-07-23 10:27:25.581147
# 262 2024-07-23 10:27:25.581147
# 264 2024-07-23 10:27:25.581147
# 266 2024-07-23 10:27:25.581147
# 270 2024-07-23 10:27:25.581147
#          symbol  consolidated     period period_ended     related_qtr  \
# 0      HDFCBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 4    POONAWALLA  Consolidated  Quarterly   2024-06-30   First Quarter
# 6       ROSSARI  Consolidated  Quarterly   2024-06-30   First Quarter
# 8     AARTISURF  Consolidated  Quarterly   2024-06-30   First Quarter
# 10      GRAVITA  Consolidated  Quarterly   2024-06-30   First Quarter
# 12   ARIHANTCAP  Consolidated  Quarterly   2024-06-30   First Quarter
# 14    VIKASLIFE  Consolidated  Quarterly   2024-06-30   First Quarter
# 18   SHAKTIPUMP  Consolidated  Quarterly   2024-06-30   First Quarter
# 19     JKCEMENT  Consolidated  Quarterly   2024-06-30   First Quarter
# 22    KOTAKBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 24   KABRAEXTRU  Consolidated  Quarterly   2024-06-30   First Quarter
# 26   SESHAPAPER  Consolidated  Quarterly   2024-06-30   First Quarter
# 28      YESBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 31     ESSENTIA  Consolidated  Quarterly   2024-06-30   First Quarter
# 34    UNIONBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 35      RBLBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 37    SUMMITSEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 39        AURUM  Consolidated  Quarterly   2024-06-30   First Quarter
# 42    TREEHOUSE  Consolidated  Quarterly   2024-06-30   First Quarter
# 44      KSOLVES  Consolidated  Quarterly   2024-06-30   First Quarter
# 46     BLUEDART  Consolidated  Quarterly   2024-06-30   First Quarter
# 48        ROUTE  Consolidated  Quarterly   2024-06-30   First Quarter
# 50       MAHEPC  Consolidated  Quarterly   2024-06-30   First Quarter
# 52         BPCL  Consolidated  Quarterly   2024-06-30   First Quarter
# 54      PVRINOX  Consolidated  Quarterly   2024-06-30   First Quarter
# 58     RELIANCE  Consolidated  Quarterly   2024-06-30   First Quarter
# 60    JSWENERGY  Consolidated  Quarterly   2024-06-30   First Quarter
# 62    PATANJALI  Consolidated  Quarterly   2024-06-30   First Quarter
# 64   OBEROIRLTY  Consolidated  Quarterly   2024-06-30   First Quarter
# 66     TEJASNET  Consolidated  Quarterly   2024-06-30   First Quarter
# 68   JUBLPHARMA  Consolidated  Quarterly   2024-06-30   First Quarter
# 71     JSWSTEEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 73    NAM-INDIA  Consolidated  Quarterly   2024-06-30   First Quarter
# 75    CREDITACC  Consolidated  Quarterly   2024-06-30   First Quarter
# 77   ULTRACEMCO  Consolidated  Quarterly   2024-06-30   First Quarter
# 79     INDHOTEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 82        PAYTM  Consolidated  Quarterly   2024-06-30   First Quarter
# 86     CIEINDIA  Consolidated  Quarterly   2024-06-30  Second Quarter
# 87        WIPRO  Consolidated  Quarterly   2024-06-30   First Quarter
# 89         TRIL  Consolidated  Quarterly   2024-06-30   First Quarter
# 91         ATUL  Consolidated  Quarterly   2024-06-30   First Quarter
# 94       SAGCEM  Consolidated  Quarterly   2024-06-30   First Quarter
# 98    ONWARDTEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 100      AETHER  Consolidated  Quarterly   2024-06-30   First Quarter
# 102   INVENTURE  Consolidated  Quarterly   2024-06-30   First Quarter
# 104        LTTS  Consolidated  Quarterly   2024-06-30   First Quarter
# 106       TANLA  Consolidated  Quarterly   2024-06-30   First Quarter
# 109     HAVELLS  Consolidated  Quarterly   2024-06-30   First Quarter
# 111   GRINDWELL  Consolidated  Quarterly   2024-06-30   First Quarter
# 113   PREMEXPLN  Consolidated  Quarterly   2024-06-30   First Quarter
# 115        INFY  Consolidated  Quarterly   2024-06-30   First Quarter
# 117   SOUTHBANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 118     CEATLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 121  SHOPERSTOP  Consolidated  Quarterly   2024-06-30   First Quarter
# 125    TATACOMM  Consolidated  Quarterly   2024-06-30   First Quarter
# 127     SWSOLAR  Consolidated  Quarterly   2024-06-30   First Quarter
# 129    CHOICEIN  Consolidated  Quarterly   2024-06-30   First Quarter
# 131  PERSISTENT  Consolidated  Quarterly   2024-06-30   First Quarter
# 133     POLYCAB  Consolidated  Quarterly   2024-06-30   First Quarter
# 135   DALMIABHA  Consolidated  Quarterly   2024-06-30   First Quarter
# 137     MENONBE  Consolidated  Quarterly   2024-06-30   First Quarter
# 138        RIIL  Consolidated  Quarterly   2024-06-30   First Quarter
# 141   CENTRALBK  Consolidated  Quarterly   2024-06-30   First Quarter
# 145    JSWINFRA  Consolidated  Quarterly   2024-06-30   First Quarter
# 147    TATATECH  Consolidated  Quarterly   2024-06-30   First Quarter
# 149      NEWGEN  Consolidated  Quarterly   2024-06-30   First Quarter
# 152      MASTEK  Consolidated  Quarterly   2024-06-30   First Quarter
# 158   VIMTALABS  Consolidated  Quarterly   2024-06-30   First Quarter
# 159  ASIANPAINT  Consolidated  Quarterly   2024-06-30   First Quarter
# 161     HATHWAY  Consolidated  Quarterly   2024-06-30   First Quarter
# 163        LTIM  Consolidated  Quarterly   2024-06-30   First Quarter
# 166    ALOKTEXT  Consolidated  Quarterly   2024-06-30   First Quarter
# 168  TV18BRDCST  Consolidated  Quarterly   2024-06-30   First Quarter
# 170   NETWORK18  Consolidated  Quarterly   2024-06-30   First Quarter
# 172      ELECON  Consolidated  Quarterly   2024-06-30   First Quarter
# 174  JUBLINGREA  Consolidated  Quarterly   2024-06-30   First Quarter
# 176        ATFL  Consolidated  Quarterly   2024-06-30   First Quarter
# 179      CRISIL  Consolidated  Quarterly   2024-06-30  Second Quarter
# 182         LTF  Consolidated  Quarterly   2024-06-30   First Quarter
# 184        HSCL  Consolidated  Quarterly   2024-06-30   First Quarter
# 185  CENTURYTEX  Consolidated  Quarterly   2024-06-30   First Quarter
# 188  BAJAJ-AUTO  Consolidated  Quarterly   2024-06-30   First Quarter
# 190       VHLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 192  KELLTONTEC  Consolidated  Quarterly   2024-06-30   First Quarter
# 195      DBCORP  Consolidated  Quarterly   2024-06-30   First Quarter
# 200    ANGELONE  Consolidated  Quarterly   2024-06-30   First Quarter
# 202      JIOFIN  Consolidated  Quarterly   2024-06-30   First Quarter
# 205         DEN  Consolidated  Quarterly   2024-06-30   First Quarter
# 208     MONARCH  Consolidated  Quarterly   2024-06-30   First Quarter
# 211     HDFCAMC  Consolidated  Quarterly   2024-06-30   First Quarter
# 214    MAHABANK  Consolidated  Quarterly   2024-06-30   First Quarter
# 217  GANESHHOUC  Consolidated  Quarterly   2024-06-30   First Quarter
# 220   GEOJITFSL  Consolidated  Quarterly   2024-06-30   First Quarter
# 222       DMART  Consolidated  Quarterly   2024-06-30   First Quarter
# 225        BEPL  Consolidated  Quarterly   2024-06-30   First Quarter
# 227       EXCEL  Consolidated  Quarterly   2024-06-30   First Quarter
# 231     HCLTECH  Consolidated  Quarterly   2024-06-30   First Quarter
# 233      5PAISA  Consolidated  Quarterly   2024-06-30   First Quarter
# 236   ORIENTHOT  Consolidated  Quarterly   2024-06-30   First Quarter
# 238    VIPULLTD  Consolidated  Quarterly   2024-06-30   First Quarter
# 240       NELCO  Consolidated  Quarterly   2024-06-30   First Quarter
# 242        GTPL  Consolidated  Quarterly   2024-06-30   First Quarter
# 243         TCS  Consolidated  Quarterly   2024-06-30   First Quarter
# 247         GNA  Consolidated  Quarterly   2024-06-30   First Quarter
# 249      JTLIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 251      WEALTH  Consolidated  Quarterly   2024-06-30   First Quarter
# 254  DRCSYSTEMS  Consolidated  Quarterly   2024-06-30   First Quarter
# 256  HEXATRADEX  Consolidated  Quarterly   2024-06-30   First Quarter
# 259   LANCORHOL  Consolidated  Quarterly   2024-06-30   First Quarter
# 260  KESORAMIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 262   KCPSUGIND  Consolidated  Quarterly   2024-06-30   First Quarter
# 264   DELTACORP  Consolidated  Quarterly   2024-06-30   First Quarter
# 266  RSSOFTWARE  Consolidated  Quarterly   2024-06-30   First Quarter
# 270      SHALBY  Consolidated  Quarterly   2024-06-30   First Quarter
#
#                                                results  \
# 0    {"ScripCode": "500180", "Symbol": "HDFCBANK", ...
# 4    {"ScripCode": "524000", "Symbol": "POONAWALLA"...
# 6    {"ScripCode": "543213", "Symbol": "ROSSARI", "...
# 8    {"ScripCode": "543210", "Symbol": "AARTISURF",...
# 10   {"ScripCode": "533282", "Symbol": "GRAVITA", "...
# 12   {"ScripCode": "511605", "Symbol": "ARIHANTCAP"...
# 14   {"ScripCode": "542655", "Symbol": "VIKASLIFE",...
# 18   {"ScripCode": "531431", "Symbol": "SHAKTIPUMP"...
# 19   {"ScripCode": "532644", "Symbol": "JKCEMENT", ...
# 22   {"ScripCode": "500247", "Symbol": "KOTAKBANK",...
# 24   {"ScripCode": "524109", "Symbol": "KABRAEXTRU"...
# 26   {"ScripCode": "502450", "Symbol": "SESHAPAPER"...
# 28   {"ScripCode": "532648", "Symbol": "YESBANK", "...
# 31   {"ScripCode": "535958", "Symbol": "ESSENTIA", ...
# 34   {"ScripCode": "532477", "Symbol": "UNIONBANK",...
# 35   {"ScripCode": "540065", "Symbol": "RBLBANK", "...
# 37   {"ScripCode": "533306", "Symbol": "SUMMITSEC",...
# 39   {"ScripCode": "539289", "Symbol": "AURUM", "MS...
# 42   {"ScripCode": "533540", "Symbol": "TREEHOUSE",...
# 44   {"ScripCode": "543599", "Symbol": "KSOLVES", "...
# 46   {"ScripCode": "526612", "Symbol": "BLUEDART", ...
# 48   {"ScripCode": "543228", "Symbol": "ROUTE", "MS...
# 50   {"ScripCode": "523754", "Symbol": "MAHEPC", "M...
# 52   {"ScripCode": "500547", "Symbol": "BPCL", "MSE...
# 54   {"ScripCode": "532689", "Symbol": "PVRINOX", "...
# 58   {"ScripCode": "500325", "Symbol": "RELIANCE", ...
# 60   {"ScripCode": "533148", "Symbol": "JSWENERGY",...
# 62   {"ScripCode": "500368", "Symbol": "PATANJALI",...
# 64   {"ScripCode": "533273", "Symbol": "OBEROIRLTY"...
# 66   {"ScripCode": "540595", "Symbol": "TEJASNET", ...
# 68   {"ScripCode": "530019", "Symbol": "JUBLPHARMA"...
# 71   {"ScripCode": "500228", "Symbol": "JSWSTEEL", ...
# 73   {"ScripCode": "540767", "Symbol": "NAM-INDIA",...
# 75   {"ScripCode": "541770", "Symbol": "CREDITACC",...
# 77   {"ScripCode": "532538", "Symbol": "ULTRACEMCO"...
# 79   {"ScripCode": "500850", "Symbol": "INDHOTEL", ...
# 82   {"ScripCode": "543396", "Symbol": "PAYTM", "MS...
# 86   {"ScripCode": "532756", "Symbol": "CIEINDIA", ...
# 87   {"ScripCode": "507685", "Symbol": "WIPRO", "MS...
# 89   {"ScripCode": "532928", "Symbol": "TRIL", "MSE...
# 91   {"ScripCode": "500027", "Symbol": "ATUL", "MSE...
# 94   {"ScripCode": "502090", "Symbol": "SAGCEM", "M...
# 98   {"ScripCode": "517536", "Symbol": "ONWARDTEC",...
# 100  {"ScripCode": "543534", "Symbol": "AETHER", "M...
# 102  {"ScripCode": "533506", "Symbol": "INVENTURE",...
# 104  {"ScripCode": "540115", "Symbol": "LTTS", "MSE...
# 106  {"ScripCode": "532790", "Symbol": "TANLA", "MS...
# 109  {"ScripCode": "517354", "Symbol": "HAVELLS", "...
# 111  {"ScripCode": "506076", "Symbol": "GRINDWELL",...
# 113  {"ScripCode": "526247", "Symbol": "PREMEXPLN",...
# 115  {"ScripCode": "500209", "Symbol": "INFY", "MSE...
# 117  {"ScripCode": "532218", "Symbol": "SOUTHBANK",...
# 118  {"ScripCode": "500878", "Symbol": "CEATLTD", "...
# 121  {"ScripCode": "532638", "Symbol": "SHOPERSTOP"...
# 125  {"ScripCode": "500483", "Symbol": "TATACOMM", ...
# 127  {"ScripCode": "542760", "Symbol": "SWSOLAR", "...
# 129  {"ScripCode": "531358", "Symbol": "CHOICEIN", ...
# 131  {"ScripCode": "533179", "Symbol": "PERSISTENT"...
# 133  {"ScripCode": "542652", "Symbol": "POLYCAB", "...
# 135  {"ScripCode": "542216", "Symbol": "DALBHARAT",...
# 137  {"ScripCode": "523828", "Symbol": "MENONBE", "...
# 138  {"ScripCode": "523445", "Symbol": "RIIL", "MSE...
# 141  {"ScripCode": "532885", "Symbol": "CENTRALBK",...
# 145  {"ScripCode": "543994", "Symbol": "JSWINFRA", ...
# 147  {"ScripCode": "544028", "Symbol": "TATATECH", ...
# 149  {"ScripCode": "540900", "Symbol": "NEWGEN", "M...
# 152  {"ScripCode": "523704", "Symbol": "MASTEK", "M...
# 158  {"ScripCode": "524394", "Symbol": "VIMTALABS",...
# 159  {"ScripCode": "500820", "Symbol": "ASIANPAINT"...
# 161  {"ScripCode": "533162", "Symbol": "HATHWAY", "...
# 163  {"ScripCode": "540005", "Symbol": "LTIM", "MSE...
# 166  {"ScripCode": "521070", "Symbol": "ALOKINDS", ...
# 168  {"ScripCode": "532800", "Symbol": "TV18BRDCST"...
# 170  {"ScripCode": "532798", "Symbol": "NETWORK18",...
# 172  {"ScripCode": "505700", "Symbol": "ELECON", "M...
# 174  {"ScripCode": "543271", "Symbol": "JUBLINGREA"...
# 176  {"ScripCode": "500215", "Symbol": "ATFL", "MSE...
# 179  {"ScripCode": "500092", "Symbol": "CRISIL", "M...
# 182  {"ScripCode": "533519", "Symbol": "LTF", "MSEI...
# 184  {"ScripCode": "500184", "Symbol": "HSCL", "MSE...
# 185  {"ScripCode": "500040", "Symbol": "CENTURYTEX"...
# 188  {"ScripCode": "532977", "Symbol": "BAJAJ-AUTO"...
# 190  {"ScripCode": "523796", "Symbol": "VHLTD", "MS...
# 192  {"ScripCode": "519602", "Symbol": "KELLTONTEC"...
# 195  {"ScripCode": "533151", "Symbol": "DBCORP", "M...
# 200  {"ScripCode": "543235", "Symbol": "ANGELONE", ...
# 202  {"ScripCode": "543940", "Symbol": "JIOFIN", "M...
# 205  {"ScripCode": "533137", "Symbol": "DEN", "MSEI...
# 208  {"ScripCode": "511551", "Symbol": "MONARCH", "...
# 211  {"ScripCode": "541729", "Symbol": "HDFCAMC", "...
# 214  {"ScripCode": "532525", "Symbol": "MAHABANK", ...
# 217  {"ScripCode": "526367", "Symbol": "GANESHHOUC"...
# 220  {"ScripCode": "532285", "Symbol": "GEOJITFSL",...
# 222  {"ScripCode": "540376", "Symbol": "DMART", "MS...
# 225  {"ScripCode": "500052", "Symbol": "BEPL", "MSE...
# 227  {"ScripCode": "533090", "Symbol": "EXCEL", "MS...
# 231  {"ScripCode": "532281", "Symbol": "HCLTECH", "...
# 233  {"ScripCode": "540776", "Symbol": "5PAISA", "M...
# 236  {"ScripCode": "500314", "Symbol": "ORIENTHOT",...
# 238  {"ScripCode": "511726", "Symbol": "VIPULLTD", ...
# 240  {"ScripCode": "504112", "Symbol": "NELCO", "MS...
# 242  {"ScripCode": "540602", "Symbol": "GTPL", "MSE...
# 243  {"ScripCode": "532540", "Symbol": "TCS", "MSEI...
# 247  {"ScripCode": "540124", "Symbol": "GNA", "MSEI...
# 249  {"ScripCode": "534600", "Symbol": "JTLIND", "M...
# 251  {"ScripCode": "123456", "Symbol": "WEALTH", "M...
# 254  {"ScripCode": "543268", "Symbol": "DRCSYSTEMS"...
# 256  {"ScripCode": "534328", "Symbol": "HEXATRADEX"...
# 259  {"ScripCode": "509048", "Symbol": "LANCORHOL",...
# 260  {"ScripCode": "502937", "Symbol": "KESORAMIND"...
# 262  {"ScripCode": "533192", "Symbol": "KCPSUGIND",...
# 264  {"ScripCode": "532848", "Symbol": "DELTACORP",...
# 266  {"ScripCode": "517447", "Symbol": "RSSOFTWARE"...
# 270  {"ScripCode": "540797", "Symbol": "SHALBY", "M...
#
#                      timestamp
# 0   2024-07-23 10:27:25.581147
# 4   2024-07-23 10:27:25.581147
# 6   2024-07-23 10:27:25.581147
# 8   2024-07-23 10:27:25.581147
# 10  2024-07-23 10:27:25.581147
# 12  2024-07-23 10:27:25.581147
# 14  2024-07-23 10:27:25.581147
# 18  2024-07-23 10:27:25.581147
# 19  2024-07-23 10:27:25.581147
# 22  2024-07-23 10:27:25.581147
# 24  2024-07-23 10:27:25.581147
# 26  2024-07-23 10:27:25.581147
# 28  2024-07-23 10:27:25.581147
# 31  2024-07-23 10:27:25.581147
# 34  2024-07-23 10:27:25.581147
# 35  2024-07-23 10:27:25.581147
# 37  2024-07-23 10:27:25.581147
# 39  2024-07-23 10:27:25.581147
# 42  2024-07-23 10:27:25.581147
# 44  2024-07-23 10:27:25.581147
# 46  2024-07-23 10:27:25.581147
# 48  2024-07-23 10:27:25.581147
# 50  2024-07-23 10:27:25.581147
# 52  2024-07-23 10:27:25.581147
# 54  2024-07-23 10:27:25.581147
# 58  2024-07-23 10:27:25.581147
# 60  2024-07-23 10:27:25.581147
# 62  2024-07-23 10:27:25.581147
# 64  2024-07-23 10:27:25.581147
# 66  2024-07-23 10:27:25.581147
# 68  2024-07-23 10:27:25.581147
# 71  2024-07-23 10:27:25.581147
# 73  2024-07-23 10:27:25.581147
# 75  2024-07-23 10:27:25.581147
# 77  2024-07-23 10:27:25.581147
# 79  2024-07-23 10:27:25.581147
# 82  2024-07-23 10:27:25.581147
# 86  2024-07-23 10:27:25.581147
# 87  2024-07-23 10:27:25.581147
# 89  2024-07-23 10:27:25.581147
# 91  2024-07-23 10:27:25.581147
# 94  2024-07-23 10:27:25.581147
# 98  2024-07-23 10:27:25.581147
# 100 2024-07-23 10:27:25.581147
# 102 2024-07-23 10:27:25.581147
# 104 2024-07-23 10:27:25.581147
# 106 2024-07-23 10:27:25.581147
# 109 2024-07-23 10:27:25.581147
# 111 2024-07-23 10:27:25.581147
# 113 2024-07-23 10:27:25.581147
# 115 2024-07-23 10:27:25.581147
# 117 2024-07-23 10:27:25.581147
# 118 2024-07-23 10:27:25.581147
# 121 2024-07-23 10:27:25.581147
# 125 2024-07-23 10:27:25.581147
# 127 2024-07-23 10:27:25.581147
# 129 2024-07-23 10:27:25.581147
# 131 2024-07-23 10:27:25.581147
# 133 2024-07-23 10:27:25.581147
# 135 2024-07-23 10:27:25.581147
# 137 2024-07-23 10:27:25.581147
# 138 2024-07-23 10:27:25.581147
# 141 2024-07-23 10:27:25.581147
# 145 2024-07-23 10:27:25.581147
# 147 2024-07-23 10:27:25.581147
# 149 2024-07-23 10:27:25.581147
# 152 2024-07-23 10:27:25.581147
# 158 2024-07-23 10:27:25.581147
# 159 2024-07-23 10:27:25.581147
# 161 2024-07-23 10:27:25.581147
# 163 2024-07-23 10:27:25.581147
# 166 2024-07-23 10:27:25.581147
# 168 2024-07-23 10:27:25.581147
# 170 2024-07-23 10:27:25.581147
# 172 2024-07-23 10:27:25.581147
# 174 2024-07-23 10:27:25.581147
# 176 2024-07-23 10:27:25.581147
# 179 2024-07-23 10:27:25.581147
# 182 2024-07-23 10:27:25.581147
# 184 2024-07-23 10:27:25.581147
# 185 2024-07-23 10:27:25.581147
# 188 2024-07-23 10:27:25.581147
# 190 2024-07-23 10:27:25.581147
# 192 2024-07-23 10:27:25.581147
# 195 2024-07-23 10:27:25.581147
# 200 2024-07-23 10:27:25.581147
# 202 2024-07-23 10:27:25.581147
# 205 2024-07-23 10:27:25.581147
# 208 2024-07-23 10:27:25.581147
# 211 2024-07-23 10:27:25.581147
# 214 2024-07-23 10:27:25.581147
# 217 2024-07-23 10:27:25.581147
# 220 2024-07-23 10:27:25.581147
# 222 2024-07-23 10:27:25.581147
# 225 2024-07-23 10:27:25.581147
# 227 2024-07-23 10:27:25.581147
# 231 2024-07-23 10:27:25.581147
# 233 2024-07-23 10:27:25.581147
# 236 2024-07-23 10:27:25.581147
# 238 2024-07-23 10:27:25.581147
# 240 2024-07-23 10:27:25.581147
# 242 2024-07-23 10:27:25.581147
# 243 2024-07-23 10:27:25.581147
# 247 2024-07-23 10:27:25.581147
# 249 2024-07-23 10:27:25.581147
# 251 2024-07-23 10:27:25.581147
# 254 2024-07-23 10:27:25.581147
# 256 2024-07-23 10:27:25.581147
# 259 2024-07-23 10:27:25.581147
# 260 2024-07-23 10:27:25.581147
# 262 2024-07-23 10:27:25.581147
# 264 2024-07-23 10:27:25.581147
# 266 2024-07-23 10:27:25.581147
# 270 2024-07-23 10:27:25.581147

# %%
getSymbol('Gravita India Limited')
# Out:
# Gravita India Limited
# 'GRAVITA'

# %%
def getResults(symbol,period_start=None,period_end=None,period_type='Quarterly'):

    export_dir = os.path.join('downloads')
    end_date = datetime.date.today()
    if period_end is not None:
        end_date = datetime.datetime.strptime(period_end,'%Y-%m-%d')    
    if period_start is not None:
        start_date = datetime.datetime.strptime(period_start,'%Y-%m-%d')
    else:
        start_date = end_date - datetime.timedelta(days=368)

    sql = "select results from financial_results where symbol='{}' and " \
          "period_ended >= '{}' and period_ended <= '{}' and period='{}' and "\
          "timestamp = (select max(timestamp) from financial_results where symbol= '{}') "
    results = pd.read_sql(sql.format(symbol,start_date.strftime('%Y-%m-%d'),end_date.strftime('%Y-%m-%d'),period_type,symbol),engine)
    result = pd.DataFrame()
    for inx in results.index:
        finres = pd.DataFrame.from_dict(json.loads(results.loc[inx]['results']), orient='index')
        finres.rename(columns={0:finres.loc['DateOfEndOfReportingPeriod'][0]},inplace=True)
        result = pd.concat([result,finres],axis=1)
    
    timestamp = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
    export_file = os.path.join(export_dir,symbol+"_"+start_date.strftime('%Y%m%d')+"_"+end_date.strftime('%Y%m%d')+"_"+period_type+"_"+timestamp+".csv")
    print(result)
    result.to_csv(export_file)
    return result
    # print(json.loads(results.iloc[1]['results']))

# %%
getResults('HEROMOTOCO')
# Out:
#                                                                                            2024-03-31  \
# ScripCode                                                                                      500182
# Symbol                                                                                     HEROMOTOCO
# MSEISymbol                                                                                  NOTLISTED
# NameOfTheCompany                                                                Hero MotoCorp Limited
# ClassOfSecurity                                                                                Equity
# DateOfStartOfFinancialYear                                                                 2023-04-01
# DateOfEndOfFinancialYear                                                                   2024-03-31
# DateOfBoardMeetingWhenFinancialResultsWereApproved                                         2024-05-08
# DateOnWhichPriorIntimationOfTheMeetingForConsid...                                         2024-04-23
# DescriptionOfPresentationCurrency                                                                 INR
# LevelOfRoundingUsedInFinancialStatements                                                       Crores
# ReportingQuarter                                                                               Yearly
# StartTimeOfBoardMeeting                                                                      11:20:00
# EndTimeOfBoardMeeting                                                                        14:35:00
# DateOfStartOfBoardMeeting                                                                  2024-05-08
# DateOfEndOfBoardMeeting                                                                    2024-05-08
# WhetherCashFlowStatementIsApplicableOnCompany                                                    true
# TypeOfCashFlowStatement                                                            Cash Flow Indirect
# DeclarationOfUnmodifiedOpinionOrStatementOnImpa...                  Declaration of unmodified opinion
# IsCompanyReportingMultisegmentOrSingleSegment                                          Single segment
# DescriptionOfSingleSegment                                                                 Automotive
# DateOfStartOfReportingPeriod                                                               2023-04-01
# DateOfEndOfReportingPeriod                                                                 2024-03-31
# WhetherResultsAreAuditedOrUnaudited                                                           Audited
# NatureOfReportStandaloneConsolidated                                                     Consolidated
# RevenueFromOperations                                                                 377886200000.00
# OtherIncome                                                                             8545400000.00
# Income                                                                                386431600000.00
# CostOfMaterialsConsumed                                                               248368900000.00
# PurchasesOfStockInTrade                                                                 4842000000.00
# ChangesInInventoriesOfFinishedGoodsWorkInProgre...                                      1883500000.00
# EmployeeBenefitExpense                                                                 24715500000.00
# FinanceCosts                                                                             763700000.00
# DepreciationDepletionAndAmortisationExpense                                             7573600000.00
# OtherExpenses                                                                          44580000000.00
# Expenses                                                                              332727200000.00
# ProfitBeforeExceptionalItemsAndTax                                                     53704400000.00
# ExceptionalItemsBeforeTax                                                              -1599900000.00
# ProfitBeforeTax                                                                        52104500000.00
# CurrentTax                                                                             12641800000.00
# DeferredTax                                                                              838600000.00
# TaxExpense                                                                             13480400000.00
# NetMovementInRegulatoryDeferralAccountBalancesR...                                               0.00
# ProfitLossForPeriodFromContinuingOperations                                            38624100000.00
# ProfitLossFromDiscontinuedOperationsBeforeTax                                                    0.00
# TaxExpenseOfDiscontinuedOperations                                                               0.00
# ProfitLossFromDiscontinuedOperationsAfterTax                                                     0.00
# ShareOfProfitLossOfAssociatesAndJointVenturesAc...                                     -1202500000.00
# ProfitLossForPeriod                                                                    37421600000.00
# OtherComprehensiveIncomeNetOfTaxes                                                      -328600000.00
# ComprehensiveIncomeForThePeriod                                                        37093000000.00
# ProfitOrLossAttributableToOwnersOfParent                                               37448300000.00
# ProfitOrLossAttributableToNonControllingInterests                                        -26700000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...                                     37120700000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...                                       -27700000.00
# PaidUpValueOfEquityShareCapital                                                          399800000.00
# FaceValueOfEquityShareCapital                                                                       2
# BasicEarningsLossPerShareFromContinuingOperations                                              187.36
# DilutedEarningsLossPerShareFromContinuingOperat...                                             187.04
# BasicEarningsLossPerShareFromDiscontinuedOperat...                                               0.00
# DilutedEarningsLossPerShareFromDiscontinuedOper...                                               0.00
# BasicEarningsLossPerShareFromContinuingAndDisco...                                             187.36
# DilutedEarningsLossPerShareFromContinuingAndDis...                                             187.04
# DisclosureOfNotesOnFinancialResultsExplanatoryT...  3) The above Consolidated financial results ha...
# ReserveExcludingRevaluationReserves                                                   176589400000.00
# DescriptionOfOtherExpenses                                                             Other Expenses
# NonControllingInterest                                                                  1356500000.00
# PropertyPlantAndEquipment                                                              52125800000.00
# CapitalWorkInProgress                                                                   1271600000.00
# InvestmentProperty                                                                               0.00
# Goodwill                                                                                         0.00
# OtherIntangibleAssets                                                                   5436500000.00
# IntangibleAssetsUnderDevelopment                                                        3569000000.00
# BiologicalAssetsOtherThanBearerPlants                                                            0.00
# InvestmentsAccountedForUsingEquityMethod                                               30835900000.00
# NoncurrentInvestments                                                                  53625700000.00
# TradeReceivablesNoncurrent                                                                       0.00
# LoansNoncurrent                                                                          211500000.00
# OtherNoncurrentFinancialAssets                                                          1894400000.00
# NoncurrentFinancialAssets                                                              55731600000.00
# DeferredTaxAssetsNet                                                                    3356800000.00
# OtherNoncurrentAssets                                                                   6046200000.00
# NoncurrentAssets                                                                      158373400000.00
# Inventories                                                                            17559000000.00
# CurrentInvestments                                                                     43050800000.00
# TradeReceivablesCurrent                                                                26302200000.00
# CashAndCashEquivalents                                                                  6049100000.00
# BankBalanceOtherThanCashAndCashEquivalents                                               915600000.00
# LoansCurrent                                                                             245600000.00
# OtherCurrentFinancialAssets                                                             4235300000.00
# CurrentFinancialAssets                                                                 80798600000.00
# CurrentTaxAssets                                                                                 0.00
# OtherCurrentAssets                                                                      4796900000.00
# CurrentAssets                                                                         103154500000.00
# NoncurrentAssetsClassifiedAsHeldForSale                                                          0.00
# RegulatoryDeferralAccountDebitBalancesAndRelate...                                               0.00
# Assets                                                                                261527900000.00
# EquityShareCapital                                                                       399800000.00
# OtherEquity                                                                           176589400000.00
# EquityAttributableToOwnersOfParent                                                    176989200000.00
# Equity                                                                                178345700000.00
# BorrowingsNoncurrent                                                                             0.00
# TradePayablesNoncurrent                                                                          0.00
# OtherNoncurrentFinancialLiabilities                                                     3772600000.00
# NoncurrentFinancialLiabilities                                                          3772600000.00
# ProvisionsNoncurrent                                                                    3224600000.00
# DeferredTaxLiabilitiesNet                                                               5701300000.00
# DeferredGovernmentGrantsNoncurrent                                                               0.00
# OtherNoncurrentLiabilities                                                                       0.00
# NoncurrentLiabilities                                                                  12698500000.00
# BorrowingsCurrent                                                                       3634300000.00
# TradePayablesCurrent                                                                   56229000000.00
# OtherCurrentFinancialLiabilities                                                        2987500000.00
# CurrentFinancialLiabilities                                                            62850800000.00
# OtherCurrentLiabilities                                                                 6038500000.00
# ProvisionsCurrent                                                                       1594400000.00
# CurrentTaxLiabilities                                                                            0.00
# DeferredGovernmentGrantsCurrent                                                                  0.00
# CurrentLiabilities                                                                     70483700000.00
# Liabilities                                                                            83182200000.00
# EquityAndLiabilities                                                                  261527900000.00
# AdjustmentsForFinanceCosts                                                               763700000.00
# AdjustmentsForDecreaseIncreaseInInventories                                                4900000.00
# AdjustmentsForDecreaseIncreaseInTradeReceivable...                                       695900000.00
# AdjustmentsForDecreaseIncreaseInTradeReceivable...                                               0.00
# AdjustmentsForDecreaseIncreaseInOtherCurrentAssets                                     -2102300000.00
# AdjustmentsForDecreaseIncreaseInOtherNoncurrent...                                        70500000.00
# AdjustmentsForOtherFinancialAssetsNoncurrent                                                     0.00
# AdjustmentsForOtherFinancialAssetsCurrent                                               1647800000.00
# AdjustmentsForOtherBankBalances                                                                  0.00
# AdjustmentsForIncreaseDecreaseInTradePayablesCu...                                      8627200000.00
# AdjustmentsForIncreaseDecreaseInTradePayablesNo...                                               0.00
# AdjustmentsForIncreaseDecreaseInOtherCurrentLia...                                       417600000.00
# AdjustmentsForIncreaseDecreaseInOtherNoncurrent...                                               0.00
# AdjustmentsForDepreciationAndAmortisationExpense                                        7573600000.00
# AdjustmentsForImpairmentLossReversalOfImpairmen...                                               0.00
# AdjustmentsForProvisionsCurrent                                                         -332400000.00
# AdjustmentsForProvisionsNoncurrent                                                       980300000.00
# AdjustmentsForOtherFinancialLiabilitiesCurrent                                            83500000.00
# AdjustmentsForOtherFinancialLiabilitiesNoncurrent                                                0.00
# AdjustmentsForUnrealisedForeignExchangeLossesGains                                        19200000.00
# AdjustmentsForDividendIncome                                                             185900000.00
# AdjustmentsForInterestIncome                                                            3013100000.00
# AdjustmentsForSharebasedPayments                                                         237400000.00
# AdjustmentsForFairValueGainsLosses                                                     -4030100000.00
# AdjustmentsForUndistributedProfitsOfAssociates                                          1202500000.00
# OtherAdjustmentsForWhichCashEffectsAreInvesting...                                               0.00
# OtherAdjustmentsToReconcileProfitLoss                                                    162600000.00
# OtherAdjustmentsForNoncashItems                                                                  0.00
# ShareOfProfitAndLossFromPartnershipFirmOrAssoci...                                               0.00
# AdjustmentsForReconcileProfitLoss                                                      10417900000.00
# CashFlowsFromUsedInOperations                                                          62522400000.00
# DividendsReceivedClassifiedAsOperatingActivities                                                 0.00
# InterestPaidClassifiedAsOperatingActivities                                                      0.00
# InterestReceivedClassifiedAsOperatingActivities                                                  0.00
# IncomeTaxesPaidRefundClassifiedAsOperatingActiv...                                     13291700000.00
# OtherInflowsOutflowsOfCashClassifiedAsOperating...                                               0.00
# CashFlowsFromUsedInOperatingActivities                                                 49230700000.00
# CashFlowsFromLosingControlOfSubsidiariesOrOther...                                               0.00
# CashFlowsUsedInObtainingControlOfSubsidiariesOr...                                      6394100000.00
# OtherCashReceiptsFromSalesOfEquityOrDebtInstrum...                                               0.00
# OtherCashPaymentsToAcquireEquityOrDebtInstrumen...                                               0.00
# OtherCashReceiptsFromSalesOfInterestsInJointVen...                                               0.00
# OtherCashPaymentsToAcquireInterestsInJointVentu...                                               0.00
# CashReceiptsFromShareOfProfitsOfPartnershipFirm...                                               0.00
# CashPaymentForInvestmentInPartnershipFirmOrAsso...                                               0.00
# ProceedsFromSalesOfPropertyPlantAndEquipmentCla...                                       107000000.00
# PurchaseOfPropertyPlantAndEquipmentClassifiedAs...                                      7878900000.00
# ProceedsFromSalesOfInvestmentPropertyClassified...                                    453066700000.00
# PurchaseOfInvestmentPropertyClassifiedAsInvesti...                                    461782700000.00
# ProceedsFromSalesOfIntangibleAssetsUnderDevelop...                                               0.00
# PurchaseOfIntangibleAssetsUnderDevelopment                                                       0.00
# ProceedsFromSalesOfGoodwillClassifiedAsInvestin...                                               0.00
# PurchaseOfGoodwillClassifiedAsInvestingActivities                                                0.00
# ProceedsFromSalesOfIntangibleAssetsClassifiedAs...                                               0.00
# PurchaseOfIntangibleAssetsClassifiedAsInvesting...                                               0.00
# ProceedsFromBiologicalAssetsOtherThanBearerPlan...                                               0.00
# PurchaseOfBiologicalAssetsOtherThanBearerPlants...                                               0.00
# ProceedsFromSalesOfOtherLongTermAssetsClassifie...                                               0.00
# PurchaseOfOtherLongTermAssetsClassifiedAsInvest...                                               0.00
# CashAdvancesAndLoansMadeToOtherPartiesClassifie...                                               0.00
# CashReceiptsFromRepaymentOfAdvancesAndLoansMade...                                               0.00
# CashPaymentsForFutureContractsForwardContractsO...                                               0.00
# CashReceiptsFromFutureContractsForwardContracts...                                               0.00
# DividendsReceivedClassifiedAsInvestingActivities                                         610600000.00
# InterestReceivedClassifiedAsInvestingActivities                                         3013100000.00
# IncomeTaxesPaidRefundClassifiedAsInvestingActiv...                                               0.00
# OtherInflowsOutflowsOfCashClassifiedAsInvesting...                                       979600000.00
# ProceedsFromGovernmentGrantsClassifiedAsInvesti...                                               0.00
# CashFlowsFromUsedInInvestingActivities                                                -18278700000.00
# ProceedsFromChangesInOwnershipInterestsInSubsid...                                               0.00
# PaymentsFromChangesInOwnershipInterestsInSubsid...                                               0.00
# ProceedsFromIssuingSharesClassifiedAsFinancingA...                                       104100000.00
# ProceedsFromIssuingOtherEquityInstruments                                                        0.00
# PaymentsToAcquireOrRedeemEntitysShares                                                           0.00
# PaymentsOfOtherEquityInstruments                                                                 0.00
# ProceedsFromExerciseOfStockOptions                                                               0.00
# ProceedsFromIssuingDebenturesNotesBondsEtc                                                       0.00
# ProceedsFromBorrowingsClassifiedAsFinancingActi...                                       702900000.00
# RepaymentsOfBorrowingsClassifiedAsFinancingActi...                                       200900000.00
# PaymentsOfFinanceLeaseLiabilitiesClassifiedAsFi...                                               0.00
# PaymentsOfLeaseLiabilitiesClassifiedAsFinancing...                                       113200000.00
# DividendsPaidClassifiedAsFinancingActivities                                           27020900000.00
# InterestPaidClassifiedAsFinancingActivities                                              763700000.00
# IncomeTaxesPaidRefundClassifiedAsFinancingActiv...                                               0.00
# OtherInflowsOutflowsOfCashClassifiedAsFinancing...                                       125800000.00
# CashFlowsFromUsedInFinancingActivities                                                -27165900000.00
# IncreaseDecreaseInCashAndCashEquivalentsBeforeE...                                      3786100000.00
# EffectOfExchangeRateChangesOnCashAndCashEquival...                                               0.00
# IncreaseDecreaseInCashAndCashEquivalents                                                3786100000.00
# CashAndCashEquivalentsCashFlowStatement                                                 6049100000.00
# DescriptionOfItemThatWillNotBeReclassifiedToPro...  Share of other comprehensive income of associates
# AmountOfItemThatWillNotBeReclassifiedToProfitAn...                                      -315500000.00
# IncomeTaxRelatingToItmesThatWillNotBeReclassifi...                                       -75100000.00
# DescriptionOfItemThatWillBeReclassifiedToProfit...  Share of other comprehensive income of associates
# AmountOfItemThatWillBeReclassifiedToProfitAndLoss                                        -83400000.00
# IncomeTaxRelatingToItmesThatWillBeReclassifiedT...                                         4800000.00
#
#                                                                                            2023-12-31  \
# ScripCode                                                                                      500182
# Symbol                                                                                     HEROMOTOCO
# MSEISymbol                                                                                  NOTLISTED
# NameOfTheCompany                                                                Hero MotoCorp Limited
# ClassOfSecurity                                                                                Equity
# DateOfStartOfFinancialYear                                                                 2023-04-01
# DateOfEndOfFinancialYear                                                                   2024-03-31
# DateOfBoardMeetingWhenFinancialResultsWereApproved                                         2024-02-09
# DateOnWhichPriorIntimationOfTheMeetingForConsid...                                         2024-02-02
# DescriptionOfPresentationCurrency                                                                 INR
# LevelOfRoundingUsedInFinancialStatements                                                       Crores
# ReportingQuarter                                                                        Third quarter
# StartTimeOfBoardMeeting                                                                      14:00:00
# EndTimeOfBoardMeeting                                                                        17:45:00
# DateOfStartOfBoardMeeting                                                                  2024-02-09
# DateOfEndOfBoardMeeting                                                                    2024-02-09
# WhetherCashFlowStatementIsApplicableOnCompany                                                     NaN
# TypeOfCashFlowStatement                                                                           NaN
# DeclarationOfUnmodifiedOpinionOrStatementOnImpa...                                     Not applicable
# IsCompanyReportingMultisegmentOrSingleSegment                                          Single segment
# DescriptionOfSingleSegment                                                                 Automotive
# DateOfStartOfReportingPeriod                                                               2023-04-01
# DateOfEndOfReportingPeriod                                                                 2023-12-31
# WhetherResultsAreAuditedOrUnaudited                                                         Unaudited
# NatureOfReportStandaloneConsolidated                                                     Consolidated
# RevenueFromOperations                                                                 281719400000.00
# OtherIncome                                                                             6772100000.00
# Income                                                                                288491500000.00
# CostOfMaterialsConsumed                                                               190675500000.00
# PurchasesOfStockInTrade                                                                  171500000.00
# ChangesInInventoriesOfFinishedGoodsWorkInProgre...                                       960700000.00
# EmployeeBenefitExpense                                                                 18081200000.00
# FinanceCosts                                                                             687300000.00
# DepreciationDepletionAndAmortisationExpense                                             5607500000.00
# OtherExpenses                                                                          32269900000.00
# Expenses                                                                              248453600000.00
# ProfitBeforeExceptionalItemsAndTax                                                     40037900000.00
# ExceptionalItemsBeforeTax                                                              -1599900000.00
# ProfitBeforeTax                                                                        38438000000.00
# CurrentTax                                                                              9331500000.00
# DeferredTax                                                                              662700000.00
# TaxExpense                                                                              9994200000.00
# NetMovementInRegulatoryDeferralAccountBalancesR...                                               0.00
# ProfitLossForPeriodFromContinuingOperations                                            28443800000.00
# ProfitLossFromDiscontinuedOperationsBeforeTax                                                    0.00
# TaxExpenseOfDiscontinuedOperations                                                               0.00
# ProfitLossFromDiscontinuedOperationsAfterTax                                                     0.00
# ShareOfProfitLossOfAssociatesAndJointVenturesAc...                                      -456800000.00
# ProfitLossForPeriod                                                                    27987000000.00
# OtherComprehensiveIncomeNetOfTaxes                                                      -209800000.00
# ComprehensiveIncomeForThePeriod                                                        27777200000.00
# ProfitOrLossAttributableToOwnersOfParent                                               28098200000.00
# ProfitOrLossAttributableToNonControllingInterests                                       -111200000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...                                     27885700000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...                                      -108500000.00
# PaidUpValueOfEquityShareCapital                                                          399800000.00
# FaceValueOfEquityShareCapital                                                                       2
# BasicEarningsLossPerShareFromContinuingOperations                                              140.58
# DilutedEarningsLossPerShareFromContinuingOperat...                                             140.34
# BasicEarningsLossPerShareFromDiscontinuedOperat...                                               0.00
# DilutedEarningsLossPerShareFromDiscontinuedOper...                                               0.00
# BasicEarningsLossPerShareFromContinuingAndDisco...                                             140.58
# DilutedEarningsLossPerShareFromContinuingAndDis...                                             140.34
# DisclosureOfNotesOnFinancialResultsExplanatoryT...  Notes:      1) The above unaudited Consolidate...
# ReserveExcludingRevaluationReserves                                                               NaN
# DescriptionOfOtherExpenses                                                             Other Expenses
# NonControllingInterest                                                                            NaN
# PropertyPlantAndEquipment                                                                         NaN
# CapitalWorkInProgress                                                                             NaN
# InvestmentProperty                                                                                NaN
# Goodwill                                                                                          NaN
# OtherIntangibleAssets                                                                             NaN
# IntangibleAssetsUnderDevelopment                                                                  NaN
# BiologicalAssetsOtherThanBearerPlants                                                             NaN
# InvestmentsAccountedForUsingEquityMethod                                                          NaN
# NoncurrentInvestments                                                                             NaN
# TradeReceivablesNoncurrent                                                                        NaN
# LoansNoncurrent                                                                                   NaN
# OtherNoncurrentFinancialAssets                                                                    NaN
# NoncurrentFinancialAssets                                                                         NaN
# DeferredTaxAssetsNet                                                                              NaN
# OtherNoncurrentAssets                                                                             NaN
# NoncurrentAssets                                                                                  NaN
# Inventories                                                                                       NaN
# CurrentInvestments                                                                                NaN
# TradeReceivablesCurrent                                                                           NaN
# CashAndCashEquivalents                                                                            NaN
# BankBalanceOtherThanCashAndCashEquivalents                                                        NaN
# LoansCurrent                                                                                      NaN
# OtherCurrentFinancialAssets                                                                       NaN
# CurrentFinancialAssets                                                                            NaN
# CurrentTaxAssets                                                                                  NaN
# OtherCurrentAssets                                                                                NaN
# CurrentAssets                                                                                     NaN
# NoncurrentAssetsClassifiedAsHeldForSale                                                           NaN
# RegulatoryDeferralAccountDebitBalancesAndRelate...                                                NaN
# Assets                                                                                            NaN
# EquityShareCapital                                                                                NaN
# OtherEquity                                                                                       NaN
# EquityAttributableToOwnersOfParent                                                                NaN
# Equity                                                                                            NaN
# BorrowingsNoncurrent                                                                              NaN
# TradePayablesNoncurrent                                                                           NaN
# OtherNoncurrentFinancialLiabilities                                                               NaN
# NoncurrentFinancialLiabilities                                                                    NaN
# ProvisionsNoncurrent                                                                              NaN
# DeferredTaxLiabilitiesNet                                                                         NaN
# DeferredGovernmentGrantsNoncurrent                                                                NaN
# OtherNoncurrentLiabilities                                                                        NaN
# NoncurrentLiabilities                                                                             NaN
# BorrowingsCurrent                                                                                 NaN
# TradePayablesCurrent                                                                              NaN
# OtherCurrentFinancialLiabilities                                                                  NaN
# CurrentFinancialLiabilities                                                                       NaN
# OtherCurrentLiabilities                                                                           NaN
# ProvisionsCurrent                                                                                 NaN
# CurrentTaxLiabilities                                                                             NaN
# DeferredGovernmentGrantsCurrent                                                                   NaN
# CurrentLiabilities                                                                                NaN
# Liabilities                                                                                       NaN
# EquityAndLiabilities                                                                              NaN
# AdjustmentsForFinanceCosts                                                                        NaN
# AdjustmentsForDecreaseIncreaseInInventories                                                       NaN
# AdjustmentsForDecreaseIncreaseInTradeReceivable...                                                NaN
# AdjustmentsForDecreaseIncreaseInTradeReceivable...                                                NaN
# AdjustmentsForDecreaseIncreaseInOtherCurrentAssets                                                NaN
# AdjustmentsForDecreaseIncreaseInOtherNoncurrent...                                                NaN
# AdjustmentsForOtherFinancialAssetsNoncurrent                                                      NaN
# AdjustmentsForOtherFinancialAssetsCurrent                                                         NaN
# AdjustmentsForOtherBankBalances                                                                   NaN
# AdjustmentsForIncreaseDecreaseInTradePayablesCu...                                                NaN
# AdjustmentsForIncreaseDecreaseInTradePayablesNo...                                                NaN
# AdjustmentsForIncreaseDecreaseInOtherCurrentLia...                                                NaN
# AdjustmentsForIncreaseDecreaseInOtherNoncurrent...                                                NaN
# AdjustmentsForDepreciationAndAmortisationExpense                                                  NaN
# AdjustmentsForImpairmentLossReversalOfImpairmen...                                                NaN
# AdjustmentsForProvisionsCurrent                                                                   NaN
# AdjustmentsForProvisionsNoncurrent                                                                NaN
# AdjustmentsForOtherFinancialLiabilitiesCurrent                                                    NaN
# AdjustmentsForOtherFinancialLiabilitiesNoncurrent                                                 NaN
# AdjustmentsForUnrealisedForeignExchangeLossesGains                                                NaN
# AdjustmentsForDividendIncome                                                                      NaN
# AdjustmentsForInterestIncome                                                                      NaN
# AdjustmentsForSharebasedPayments                                                                  NaN
# AdjustmentsForFairValueGainsLosses                                                                NaN
# AdjustmentsForUndistributedProfitsOfAssociates                                                    NaN
# OtherAdjustmentsForWhichCashEffectsAreInvesting...                                                NaN
# OtherAdjustmentsToReconcileProfitLoss                                                             NaN
# OtherAdjustmentsForNoncashItems                                                                   NaN
# ShareOfProfitAndLossFromPartnershipFirmOrAssoci...                                                NaN
# AdjustmentsForReconcileProfitLoss                                                                 NaN
# CashFlowsFromUsedInOperations                                                                     NaN
# DividendsReceivedClassifiedAsOperatingActivities                                                  NaN
# InterestPaidClassifiedAsOperatingActivities                                                       NaN
# InterestReceivedClassifiedAsOperatingActivities                                                   NaN
# IncomeTaxesPaidRefundClassifiedAsOperatingActiv...                                                NaN
# OtherInflowsOutflowsOfCashClassifiedAsOperating...                                                NaN
# CashFlowsFromUsedInOperatingActivities                                                            NaN
# CashFlowsFromLosingControlOfSubsidiariesOrOther...                                                NaN
# CashFlowsUsedInObtainingControlOfSubsidiariesOr...                                                NaN
# OtherCashReceiptsFromSalesOfEquityOrDebtInstrum...                                                NaN
# OtherCashPaymentsToAcquireEquityOrDebtInstrumen...                                                NaN
# OtherCashReceiptsFromSalesOfInterestsInJointVen...                                                NaN
# OtherCashPaymentsToAcquireInterestsInJointVentu...                                                NaN
# CashReceiptsFromShareOfProfitsOfPartnershipFirm...                                                NaN
# CashPaymentForInvestmentInPartnershipFirmOrAsso...                                                NaN
# ProceedsFromSalesOfPropertyPlantAndEquipmentCla...                                                NaN
# PurchaseOfPropertyPlantAndEquipmentClassifiedAs...                                                NaN
# ProceedsFromSalesOfInvestmentPropertyClassified...                                                NaN
# PurchaseOfInvestmentPropertyClassifiedAsInvesti...                                                NaN
# ProceedsFromSalesOfIntangibleAssetsUnderDevelop...                                                NaN
# PurchaseOfIntangibleAssetsUnderDevelopment                                                        NaN
# ProceedsFromSalesOfGoodwillClassifiedAsInvestin...                                                NaN
# PurchaseOfGoodwillClassifiedAsInvestingActivities                                                 NaN
# ProceedsFromSalesOfIntangibleAssetsClassifiedAs...                                                NaN
# PurchaseOfIntangibleAssetsClassifiedAsInvesting...                                                NaN
# ProceedsFromBiologicalAssetsOtherThanBearerPlan...                                                NaN
# PurchaseOfBiologicalAssetsOtherThanBearerPlants...                                                NaN
# ProceedsFromSalesOfOtherLongTermAssetsClassifie...                                                NaN
# PurchaseOfOtherLongTermAssetsClassifiedAsInvest...                                                NaN
# CashAdvancesAndLoansMadeToOtherPartiesClassifie...                                                NaN
# CashReceiptsFromRepaymentOfAdvancesAndLoansMade...                                                NaN
# CashPaymentsForFutureContractsForwardContractsO...                                                NaN
# CashReceiptsFromFutureContractsForwardContracts...                                                NaN
# DividendsReceivedClassifiedAsInvestingActivities                                                  NaN
# InterestReceivedClassifiedAsInvestingActivities                                                   NaN
# IncomeTaxesPaidRefundClassifiedAsInvestingActiv...                                                NaN
# OtherInflowsOutflowsOfCashClassifiedAsInvesting...                                                NaN
# ProceedsFromGovernmentGrantsClassifiedAsInvesti...                                                NaN
# CashFlowsFromUsedInInvestingActivities                                                            NaN
# ProceedsFromChangesInOwnershipInterestsInSubsid...                                                NaN
# PaymentsFromChangesInOwnershipInterestsInSubsid...                                                NaN
# ProceedsFromIssuingSharesClassifiedAsFinancingA...                                                NaN
# ProceedsFromIssuingOtherEquityInstruments                                                         NaN
# PaymentsToAcquireOrRedeemEntitysShares                                                            NaN
# PaymentsOfOtherEquityInstruments                                                                  NaN
# ProceedsFromExerciseOfStockOptions                                                                NaN
# ProceedsFromIssuingDebenturesNotesBondsEtc                                                        NaN
# ProceedsFromBorrowingsClassifiedAsFinancingActi...                                                NaN
# RepaymentsOfBorrowingsClassifiedAsFinancingActi...                                                NaN
# PaymentsOfFinanceLeaseLiabilitiesClassifiedAsFi...                                                NaN
# PaymentsOfLeaseLiabilitiesClassifiedAsFinancing...                                                NaN
# DividendsPaidClassifiedAsFinancingActivities                                                      NaN
# InterestPaidClassifiedAsFinancingActivities                                                       NaN
# IncomeTaxesPaidRefundClassifiedAsFinancingActiv...                                                NaN
# OtherInflowsOutflowsOfCashClassifiedAsFinancing...                                                NaN
# CashFlowsFromUsedInFinancingActivities                                                            NaN
# IncreaseDecreaseInCashAndCashEquivalentsBeforeE...                                                NaN
# EffectOfExchangeRateChangesOnCashAndCashEquival...                                                NaN
# IncreaseDecreaseInCashAndCashEquivalents                                                          NaN
# CashAndCashEquivalentsCashFlowStatement                                                           NaN
# DescriptionOfItemThatWillNotBeReclassifiedToPro...  Share of Other comprehensive income of associates
# AmountOfItemThatWillNotBeReclassifiedToProfitAn...                                      -103600000.00
# IncomeTaxRelatingToItmesThatWillNotBeReclassifi...                                       -24800000.00
# DescriptionOfItemThatWillBeReclassifiedToProfit...  Share of Other comprehensive income of associates
# AmountOfItemThatWillBeReclassifiedToProfitAndLoss                                       -136800000.00
# IncomeTaxRelatingToItmesThatWillBeReclassifiedT...                                        -5800000.00
#
#                                                                2023-09-30
# ScripCode                                                          500182
# Symbol                                                         HEROMOTOCO
# MSEISymbol                                                             NA
# NameOfTheCompany                                    Hero MotoCorp Limited
# ClassOfSecurity                                                    Equity
# DateOfStartOfFinancialYear                                     2023-04-01
# DateOfEndOfFinancialYear                                       2024-03-31
# DateOfBoardMeetingWhenFinancialResultsWereApproved             2023-11-01
# DateOnWhichPriorIntimationOfTheMeetingForConsid...             2023-10-19
# DescriptionOfPresentationCurrency                                     INR
# LevelOfRoundingUsedInFinancialStatements                           Crores
# ReportingQuarter                                              Half yearly
# StartTimeOfBoardMeeting                                          13:00:00
# EndTimeOfBoardMeeting                                            16:45:00
# DateOfStartOfBoardMeeting                                      2023-11-01
# DateOfEndOfBoardMeeting                                        2023-11-01
# WhetherCashFlowStatementIsApplicableOnCompany                        true
# TypeOfCashFlowStatement                                Cash Flow Indirect
# DeclarationOfUnmodifiedOpinionOrStatementOnImpa...         Not applicable
# IsCompanyReportingMultisegmentOrSingleSegment              Single segment
# DescriptionOfSingleSegment                                     Automotive
# DateOfStartOfReportingPeriod                                   2023-04-01
# DateOfEndOfReportingPeriod                                     2023-09-30
# WhetherResultsAreAuditedOrUnaudited                             Unaudited
# NatureOfReportStandaloneConsolidated                         Consolidated
# RevenueFromOperations                                     183840800000.00
# OtherIncome                                                 4336400000.00
# Income                                                    188177200000.00
# ...
# DateOfBoardMeetingWhenFinancialResultsWereApproved             2023-11-01
# DateOnWhichPriorIntimationOfTheMeetingForConsid...             2023-10-19
# DescriptionOfPresentationCurrency                                     INR
# LevelOfRoundingUsedInFinancialStatements                           Crores
# ReportingQuarter                                              Half yearly
# StartTimeOfBoardMeeting                                          13:00:00
# EndTimeOfBoardMeeting                                            16:45:00
# DateOfStartOfBoardMeeting                                      2023-11-01
# DateOfEndOfBoardMeeting                                        2023-11-01
# WhetherCashFlowStatementIsApplicableOnCompany                        true
# TypeOfCashFlowStatement                                Cash Flow Indirect
# DeclarationOfUnmodifiedOpinionOrStatementOnImpa...         Not applicable
# IsCompanyReportingMultisegmentOrSingleSegment              Single segment
# DescriptionOfSingleSegment                                     Automotive
# DateOfStartOfReportingPeriod                                   2023-04-01
# DateOfEndOfReportingPeriod                                     2023-09-30
# WhetherResultsAreAuditedOrUnaudited                             Unaudited
# NatureOfReportStandaloneConsolidated                         Consolidated
# RevenueFromOperations                                     183840800000.00
# OtherIncome                                                 4336400000.00
# Income                                                    188177200000.00
# CostOfMaterialsConsumed                                   125616800000.00
# PurchasesOfStockInTrade                                      148400000.00
# ChangesInInventoriesOfFinishedGoodsWorkInProgre...           500500000.00
# EmployeeBenefitExpense                                     11897000000.00
# FinanceCosts                                                 459900000.00
# DepreciationDepletionAndAmortisationExpense                 3668300000.00
# OtherExpenses                                              19966300000.00
# Expenses                                                  162257200000.00
# ProfitBeforeExceptionalItemsAndTax                         25920000000.00
# ExceptionalItemsBeforeTax                                  -1599900000.00
# ProfitBeforeTax                                            24320100000.00
# CurrentTax                                                  5787000000.00
# DeferredTax                                                  557600000.00
# TaxExpense                                                  6344600000.00
# NetMovementInRegulatoryDeferralAccountBalancesR...                   0.00
# ProfitLossForPeriodFromContinuingOperations                17975500000.00
# ProfitLossFromDiscontinuedOperationsBeforeTax                        0.00
# TaxExpenseOfDiscontinuedOperations                                   0.00
# ProfitLossFromDiscontinuedOperationsAfterTax                         0.00
# ShareOfProfitLossOfAssociatesAndJointVenturesAc...          -899700000.00
# ProfitLossForPeriod                                        17075800000.00
# OtherComprehensiveIncomeNetOfTaxes                           -78800000.00
# ComprehensiveIncomeForThePeriod                            16997000000.00
# ProfitOrLossAttributableToOwnersOfParent                   17164100000.00
# ProfitOrLossAttributableToNonControllingInterests            -88300000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...         17075000000.00
# ComprehensiveIncomeForThePeriodAttributableToOw...           -78000000.00
# PaidUpValueOfEquityShareCapital                              399700000.00
# FaceValueOfEquityShareCapital                                           2
# BasicEarningsLossPerShareFromContinuingOperations                   85.88
# DilutedEarningsLossPerShareFromContinuingOperat...                  85.75
# BasicEarningsLossPerShareFromDiscontinuedOperat...                   0.00
# DilutedEarningsLossPerShareFromDiscontinuedOper...                   0.00
# BasicEarningsLossPerShareFromContinuingAndDisco...                  85.88
# DilutedEarningsLossPerShareFromContinuingAndDis...                  85.75
# DisclosureOfNotesOnFinancialResultsExplanatoryT...                    NaN
# ReserveExcludingRevaluationReserves                                   NaN
# DescriptionOfOtherExpenses                                 Other Expenses
# NonControllingInterest                                      1247400000.00
# PropertyPlantAndEquipment                                  50535900000.00
# CapitalWorkInProgress                                       1750500000.00
# InvestmentProperty                                                   0.00
# Goodwill                                                             0.00
# OtherIntangibleAssets                                       5490300000.00
# IntangibleAssetsUnderDevelopment                            3335900000.00
# BiologicalAssetsOtherThanBearerPlants                                0.00
# InvestmentsAccountedForUsingEquityMethod                   29816400000.00
# NoncurrentInvestments                                      50993600000.00
# TradeReceivablesNoncurrent                                           0.00
# LoansNoncurrent                                              185400000.00
# OtherNoncurrentFinancialAssets                              2069100000.00
# NoncurrentFinancialAssets                                  53248100000.00
# DeferredTaxAssetsNet                                        2489200000.00
# OtherNoncurrentAssets                                       6191500000.00
# NoncurrentAssets                                          152857800000.00
# Inventories                                                20321600000.00
# CurrentInvestments                                         31369400000.00
# TradeReceivablesCurrent                                    42294900000.00
# CashAndCashEquivalents                                      3665600000.00
# BankBalanceOtherThanCashAndCashEquivalents                  1233000000.00
# LoansCurrent                                                 225500000.00
# OtherCurrentFinancialAssets                                 7756900000.00
# CurrentFinancialAssets                                     86545300000.00
# CurrentTaxAssets                                                     0.00
# OtherCurrentAssets                                          3386400000.00
# CurrentAssets                                             110253300000.00
# NoncurrentAssetsClassifiedAsHeldForSale                               NaN
# RegulatoryDeferralAccountDebitBalancesAndRelate...                    NaN
# Assets                                                    263111100000.00
# EquityShareCapital                                           399700000.00
# OtherEquity                                               176340000000.00
# EquityAttributableToOwnersOfParent                        176739700000.00
# Equity                                                    177987100000.00
# BorrowingsNoncurrent                                          67800000.00
# TradePayablesNoncurrent                                              0.00
# OtherNoncurrentFinancialLiabilities                         3806100000.00
# NoncurrentFinancialLiabilities                              3873900000.00
# ProvisionsNoncurrent                                        2298500000.00
# DeferredTaxLiabilitiesNet                                   5409100000.00
# DeferredGovernmentGrantsNoncurrent                                   0.00
# OtherNoncurrentLiabilities                                           0.00
# NoncurrentLiabilities                                      11581500000.00
# BorrowingsCurrent                                           3937300000.00
# TradePayablesCurrent                                       59631700000.00
# OtherCurrentFinancialLiabilities                            2383100000.00
# CurrentFinancialLiabilities                                65952100000.00
# OtherCurrentLiabilities                                     5632200000.00
# ProvisionsCurrent                                           1958200000.00
# CurrentTaxLiabilities                                                0.00
# DeferredGovernmentGrantsCurrent                                      0.00
# CurrentLiabilities                                         73542500000.00
# Liabilities                                                85124000000.00
# EquityAndLiabilities                                      263111100000.00
# AdjustmentsForFinanceCosts                                   459900000.00
# AdjustmentsForDecreaseIncreaseInInventories                -2757700000.00
# AdjustmentsForDecreaseIncreaseInTradeReceivable...        -15286400000.00
# AdjustmentsForDecreaseIncreaseInTradeReceivable...                   0.00
# AdjustmentsForDecreaseIncreaseInOtherCurrentAssets          -691800000.00
# AdjustmentsForDecreaseIncreaseInOtherNoncurrent...            70600000.00
# AdjustmentsForOtherFinancialAssetsNoncurrent                         0.00
# AdjustmentsForOtherFinancialAssetsCurrent                  -2048500000.00
# AdjustmentsForOtherBankBalances                                      0.00
# AdjustmentsForIncreaseDecreaseInTradePayablesCu...         12030200000.00
# AdjustmentsForIncreaseDecreaseInTradePayablesNo...                   0.00
# AdjustmentsForIncreaseDecreaseInOtherCurrentLia...            11300000.00
# AdjustmentsForIncreaseDecreaseInOtherNoncurrent...                   0.00
# AdjustmentsForDepreciationAndAmortisationExpense            3668300000.00
# AdjustmentsForImpairmentLossReversalOfImpairmen...                   0.00
# AdjustmentsForProvisionsCurrent                               31400000.00
# AdjustmentsForProvisionsNoncurrent                           229400000.00
# AdjustmentsForOtherFinancialLiabilitiesCurrent               -18600000.00
# AdjustmentsForOtherFinancialLiabilitiesNoncurrent                    0.00
# AdjustmentsForUnrealisedForeignExchangeLossesGains           -23000000.00
# AdjustmentsForDividendIncome                                 177800000.00
# AdjustmentsForInterestIncome                                1563900000.00
# AdjustmentsForSharebasedPayments                             101100000.00
# AdjustmentsForFairValueGainsLosses                         -1974400000.00
# AdjustmentsForUndistributedProfitsOfAssociates               899700000.00
# OtherAdjustmentsForWhichCashEffectsAreInvesting...                   0.00
# OtherAdjustmentsToReconcileProfitLoss                        582700000.00
# OtherAdjustmentsForNoncashItems                                      0.00
# ShareOfProfitAndLossFromPartnershipFirmOrAssoci...                   0.00
# AdjustmentsForReconcileProfitLoss                          -8256900000.00
# CashFlowsFromUsedInOperations                              16063200000.00
# DividendsReceivedClassifiedAsOperatingActivities                     0.00
# InterestPaidClassifiedAsOperatingActivities                          0.00
# InterestReceivedClassifiedAsOperatingActivities                      0.00
# IncomeTaxesPaidRefundClassifiedAsOperatingActiv...          5570100000.00
# OtherInflowsOutflowsOfCashClassifiedAsOperating...                   0.00
# CashFlowsFromUsedInOperatingActivities                     10493100000.00
# CashFlowsFromLosingControlOfSubsidiariesOrOther...                   0.00
# CashFlowsUsedInObtainingControlOfSubsidiariesOr...          5000000000.00
# OtherCashReceiptsFromSalesOfEquityOrDebtInstrum...                   0.00
# OtherCashPaymentsToAcquireEquityOrDebtInstrumen...                   0.00
# OtherCashReceiptsFromSalesOfInterestsInJointVen...                   0.00
# OtherCashPaymentsToAcquireInterestsInJointVentu...                   0.00
# CashReceiptsFromShareOfProfitsOfPartnershipFirm...                   0.00
# CashPaymentForInvestmentInPartnershipFirmOrAsso...                   0.00
# ProceedsFromSalesOfPropertyPlantAndEquipmentCla...            45300000.00
# PurchaseOfPropertyPlantAndEquipmentClassifiedAs...          3356200000.00
# ProceedsFromSalesOfInvestmentPropertyClassified...        216592000000.00
# PurchaseOfInvestmentPropertyClassifiedAsInvesti...        213716000000.00
# ProceedsFromSalesOfIntangibleAssetsUnderDevelop...                   0.00
# PurchaseOfIntangibleAssetsUnderDevelopment                           0.00
# ProceedsFromSalesOfGoodwillClassifiedAsInvestin...                   0.00
# PurchaseOfGoodwillClassifiedAsInvestingActivities                    0.00
# ProceedsFromSalesOfIntangibleAssetsClassifiedAs...                   0.00
# PurchaseOfIntangibleAssetsClassifiedAsInvesting...                   0.00
# ProceedsFromBiologicalAssetsOtherThanBearerPlan...                   0.00
# PurchaseOfBiologicalAssetsOtherThanBearerPlants...                   0.00
# ProceedsFromSalesOfOtherLongTermAssetsClassifie...                   0.00
# PurchaseOfOtherLongTermAssetsClassifiedAsInvest...                   0.00
# CashAdvancesAndLoansMadeToOtherPartiesClassifie...                   0.00
# CashReceiptsFromRepaymentOfAdvancesAndLoansMade...                   0.00
# CashPaymentsForFutureContractsForwardContractsO...                   0.00
# CashReceiptsFromFutureContractsForwardContracts...                   0.00
# DividendsReceivedClassifiedAsInvestingActivities             602400000.00
# InterestReceivedClassifiedAsInvestingActivities             1563900000.00
# IncomeTaxesPaidRefundClassifiedAsInvestingActiv...                   0.00
# OtherInflowsOutflowsOfCashClassifiedAsInvesting...           687200000.00
# ProceedsFromGovernmentGrantsClassifiedAsInvesti...                   0.00
# CashFlowsFromUsedInInvestingActivities                     -2581400000.00
# ProceedsFromChangesInOwnershipInterestsInSubsid...           119600000.00
# PaymentsFromChangesInOwnershipInterestsInSubsid...                   0.00
# ProceedsFromIssuingSharesClassifiedAsFinancingA...            26300000.00
# ProceedsFromIssuingOtherEquityInstruments                            0.00
# PaymentsToAcquireOrRedeemEntitysShares                               0.00
# PaymentsOfOtherEquityInstruments                                     0.00
# ProceedsFromExerciseOfStockOptions                                   0.00
# ProceedsFromIssuingDebenturesNotesBondsEtc                           0.00
# ProceedsFromBorrowingsClassifiedAsFinancingActi...          1005800000.00
# RepaymentsOfBorrowingsClassifiedAsFinancingActi...           133100000.00
# PaymentsOfFinanceLeaseLiabilitiesClassifiedAsFi...                   0.00
# PaymentsOfLeaseLiabilitiesClassifiedAsFinancing...            39100000.00
# DividendsPaidClassifiedAsFinancingActivities                7028700000.00
# InterestPaidClassifiedAsFinancingActivities                  459900000.00
# IncomeTaxesPaidRefundClassifiedAsFinancingActiv...                   0.00
# OtherInflowsOutflowsOfCashClassifiedAsFinancing...                   0.00
# CashFlowsFromUsedInFinancingActivities                     -6509100000.00
# IncreaseDecreaseInCashAndCashEquivalentsBeforeE...          1402600000.00
# EffectOfExchangeRateChangesOnCashAndCashEquival...                   0.00
# IncreaseDecreaseInCashAndCashEquivalents                    1402600000.00
# CashAndCashEquivalentsCashFlowStatement                     3665600000.00
# DescriptionOfItemThatWillNotBeReclassifiedToPro...                    NaN
# AmountOfItemThatWillNotBeReclassifiedToProfitAn...                    NaN
# IncomeTaxRelatingToItmesThatWillNotBeReclassifi...            51400000.00
# DescriptionOfItemThatWillBeReclassifiedToProfit...                    NaN
# AmountOfItemThatWillBeReclassifiedToProfitAndLoss                     NaN
# IncomeTaxRelatingToItmesThatWillBeReclassifiedT...            27400000.00

# %%
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
assets = pytesseract.image_to_string(Image.open('tapo.png'))
liabilities = pytesseract.image_to_string(Image.open('tapo1.png'))
print(assets)
print(liabilities)

# %%
assets.split('\n')[3]

# %%
key = '1MVD2LBE1UBKFUX0'

from alpha_vantage.fundamentaldata import FundamentalData
import pandas as pd

def get_fundamental_data(symbol):
    api_key = key
    fd = FundamentalData(key=api_key, output_format='pandas')

    # Get company overview
    overview, _ = fd.get_company_overview(symbol)
    
    # Get earnings
    earnings, _ = fd.get_company_earnings(symbol)

    return overview, earnings

if __name__ == "__main__":
    symbol = input("Enter the stock symbol: ").upper()
    try:
        overview, earnings = get_fundamental_data(symbol)
        print(f"Overview for {symbol}:")
        print(overview)
        print("\nEarnings Data for {symbol}:")
        print(earnings)
    except Exception as e:
        print(f"Error: {e}")

# %%
url = "https://www.nseindia.com/get-quotes/equity?symbol=HDFCBANK#Corporate_Actions"

import pandas
import requests



headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

s = requests.Session()
response = s.get(url,headers=headers)
print(response.content)
# data = requests.get

# %%
oc.sort_values(['itm x oi'],ascending=False).head(1)['strike'].values[0]

# %%
import plotly.graph_objects as go
scrips = ['NIFTY 50','NIFTY BANK', 'INDIA VIX']
kitecodemap = pd.read_csv('kitensecodes.csv')
scrips = [kitecodemap[kitecodemap['tradingsymbol'] == scrip]['instrument_token'].values[0] for scrip in scrips]
to_date = datetime.date.today()
from_date = to_date - datetime.timedelta(days=30)
hist_data = []
for token in scrips:
    data = session.historical_data(token,from_date,to_date,interval='day',continuous=False)
    data = pd.DataFrame(data)
#     data['date'] = data['date'].apply(lambda x : datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S+05:30"))
#     data['date'] = data['date'].apply(lambda x : datetime.datetime.fromtimestamp(x))

    hist_data.append(data[data.columns[:-1]])
# hist_data[0]

# %%
import tkinter as tk

win = tk.Tk()

fig = go.Figure(data=[go.Candlestick(x=hist_data[2]['date'],
                open=hist_data[2]['open'],
                high=hist_data[2]['high'],
                low=hist_data[2]['low'],
                close=hist_data[2]['close'])])
fig.update_layout(xaxis_rangeslider_visible=False)


fig.show()

# %%
# import tradingDB as tdb
# tdbobj = tdb.tradingDB()
# grph = tdbobj.market_snapshot()

# ins = session.instruments(exchange='CDS')
# inspd = pd.DataFrame(ins)
# inspd[['tradingsymbol','instrument_token']].to_csv('kitemcxcodes.csv')

current_month = datetime.date.strftime(datetime.date.today(),'%b')
next_month = datetime.date.strftime(datetime.date.today() + datetime.timedelta(days=31),'%b') 
current_year = datetime.date.strftime(datetime.date.today(),'%y')
crude = 'GOLD'+current_year+next_month.upper()+'FUT'
usdinr = 'USDINR'+current_year+current_month.upper()+'FUT'

ins = session.instruments(exchange='MCX')
inspd = pd.DataFrame(ins)
# inspd[(inspd['tradingsymbol'].str.contains(u'GOLD*****FUT')) & (inspd['segment'] == 'MCX-FUT')].sort_values(by='expiry').head(1)
print(crude+'     '+str(inspd[inspd['tradingsymbol'] == crude]['instrument_token'].values[0]))


# session.quote('MCX:'+crude)

# %%
pd.DataFrame(session.historical_data(65260551,from_date,to_date,'day'))
pd.DataFrame(session.historical_data(2433027,from_date,to_date,'day'))

# %%
pd.DataFrame(session.quote('NSE:NIFTY BANK'))['NSE:NIFTY BANK']

# %%
variety = session.VARIETY_REGULAR
exchange= session.EXCHANGE_NFO
tradingsymbol='TATAPOWER23AUG250CE'
transaction_type=session.TRANSACTION_TYPE_SELL
quantity=3375
product= session.PRODUCT_NRML
order_type = session.ORDER_TYPE_LIMIT
price=15
validity=session.VALIDITY_DAY
disclosed_quantity=None
trigger_price=None
squareoff=None 
stoploss=None
trailing_stoploss=None
tag=None

margin = session.order_margins(variety,exchange, tradingsymbol, transaction_type, quantity, product, order_type, price,
                    validity, disclosed_quantity, trigger_price, squareoff=None, stoploss=None,
                    trailing_stoploss=None, tag=None)

margin

# %%
qt = session.quote('NSE:LIQUIDBEES')
qt

# %%
scrip = 'TATAPOWER'
atm = mu.find_atm(614,5)
atm

# %%
inspd = pd.DataFrame(ins)
#inspd = inspd[(inspd['name'] == scrip) & (inspd['expiry'] == expiry) & (inspd['strike'] >= 18000) & (inspd['strike'] <= 20500) ][['tradingsymbol','strike']]
inspd = inspd[(inspd['name'] == scrip) & (inspd['expiry'] == expiry) & (inspd['strike'] > 0)][['tradingsymbol','strike']]
inspd['tradingsymbol'] = 'NFO:' + inspd['tradingsymbol']
inspd.set_index('tradingsymbol',inplace=True)
inspd
inslist = list(inspd.index)
inslist = inslist[int(len(inslist)/2-len(inslist)/4):int(len(inslist)/2+len(inslist)/4)]
inslist

# %%
def kite_oc(df):
    def kitequote_to_oc(quote):
        oc = pd.DataFrame(quote)
        for key in quote.key:
            qt = quote[key]
            oc = pd.DataFrame(qt)
    for strike in set(list(df['strike'])):
        ce = 'NFO:'+ df[df['strike'] == strike]['tradingsymbol'].head(1).values[0]
        pe = 'NFO:'+ df[df['strike'] == strike]['tradingsymbol'].head(1).values[0]

# %%
oc = pd.DataFrame(qt).T
oc.index.name = 'tradingsymbol'
oc1 = oc.merge(inspd,on='tradingsymbol')[['strike','oi','volume','last_price']]

# %%
scrip = ['TATAPOWER']
expiry_list = [expiry1,expiry2,expiry3]
oc = mu.kite_OC(scrip,expiry_list)
oc.reset_index(inplace=True)

# %%
8 in [1,3,4,5]

# %%
oc.loc[oc['tradingsymbol'].str[-2:] == 'CE'].sort_values(by='oi',ascending=False).head(5).sort_values(by='strike')

# %%
oc.loc[oc['tradingsymbol'].str[-2:] == 'PE'].sort_values(by='oi',ascending=False).head(5).sort_values(by='strike')

# %%
name = 'TATAPOWER'
oi_tree = oc[oc['name'] == name]
for expiry in sorted(set(list(oc['expiry'])),reverse=True):
    oi_tree['oi_ce'+str(expiry)] = oc.loc[(oc['tradingsymbol'].str[-2:] == 'CE') & (oc['expiry'] == expiry),'oi']/oc[(oc['tradingsymbol'].str[-2:] == 'CE') & (oc['expiry'] == expiry)]['oi'].sum()
    oi_tree['oi_pe'+str(expiry)] = -oc.loc[(oc['tradingsymbol'].str[-2:] == 'PE') & (oc['expiry'] == expiry),'oi']/oc[(oc['tradingsymbol'].str[-2:] == 'PE') & (oc['expiry'] == expiry)]['oi'].sum()
oi_tree.fillna(0,inplace=True)

# %%
oi_tree

# %%
import matplotlib.pyplot as plt
oi_tree.sort_values(by=['expiry','strike'],ascending=[True,True],inplace=True)
fig, ax = plt.subplots(1,3,figsize=(20,10),squeeze=False) 

#oi_tree[['oi_ce','oi_pe']].plot(kind='barh')
i= 0
for exp in set(list(oc['expiry'])):
    print(exp)
    ax1 = ax[0,i]
    ax1.set_title(exp)
    ax1.grid()
    ax2 = ax[0,i].twinx()
    x_data = oi_tree[oi_tree['expiry'] == exp]['strike']
    y1_data = oi_tree[oi_tree['expiry'] == exp]['oi_ce'+str(exp)]
    y2_data = oi_tree[oi_tree['expiry'] == exp]['oi_pe'+str(exp)]
    ax1.set_xlabel('OI')
    ax1.set_ylabel('STRIKE')
    ax1.barh(x_data,y1_data,color='b')

    ax2.set_ylabel('STRIKE')
    ax2.barh(x_data,y2_data,color='g')

#     oi_tree[oi_tree['expiry'] == exp].plot(x='strike', y = 'oi_ce'+str(exp), ax = ax[0,i] ,title = exp, kind='barh',ylabel='OI') 
#     oi_tree[oi_tree['expiry'] == exp].plot(x='strike', y = 'oi_pe'+str(exp), ax = ax2,title = exp,secondary_y=True, kind='barh',color='g',ylabel='OI') 
#     ax2.set_ylabel('strike')
    i+=1
plt.show()
