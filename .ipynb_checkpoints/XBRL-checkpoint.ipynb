# %%
import mrigutilities as mu
import pandas as pd
import datetime
import os,sys
import yahooquery as yq
import kite.kite_trade as zkite
import json
from mrigquery import fundamentals as funda
pd.options.display.float_format = '${:,.2f}'.format

expiry1 = mu.last_thursday_of_month(datetime.date.today())
expiry2 = mu.last_thursday_of_month(expiry1 + datetime.timedelta(days=30))
expiry3 = mu.last_thursday_of_month(expiry2 + datetime.timedelta(days=30))
expiry1,expiry2, expiry3
session = mu.getKiteSession()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
engine = mu.sql_engine()
# Out:
# connection active

# %%
from yahooquery import Ticker

symbol_list_yahoo = ['TATAPOWER.NS', 'TATAMOTORS.NS']

ticker = Ticker(symbol_list_yahoo) 
fin_data_dict = ticker.financial_data
fin_data_df = pd.DataFrame.from_dict(fin_data_dict, orient='index').T
fin_data_df

# %%
import xml.etree.ElementTree as ET
import requests


headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

def parse_xbrl(url):
    result = pd.DataFrame()
    # print(url)
    i = 0
    s = requests.Session()
    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    finres = pd.DataFrame.from_dict(results, orient='index')
    finres.rename(columns={0:i},inplace=True)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    results = json.dumps(results)
    return results

url = 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_109449_1202168_25072024030831.xml'
res = json.loads(parse_xbrl(url))['Symbol']
print(res)
# Out:
# HFCL

# %%
# from xbrl import XBRLParser, GAAP, GAAPSerializer
import xml.etree.ElementTree as ET
import requests
eq_dir_qtr = os.path.join('resources','equity_research','FINRESULTS_QTRLY_AXISBANK.csv')
eq_dir_ann = os.path.join('resources','equity_research','FINRESULTS_ANNUAL_AXISBANK.csv')


def parse_xbrl(url):
    result = pd.DataFrame()
    i = 0
    s = requests.Session()
    headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    # finres = pd.DataFrame.from_dict(results, orient='index')
    # finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    return results



sym = os.path.basename(eq_dir).split('.')[0].split('_')[2]
# print(sym)



url = ['https://nsearchives.nseindia.com/corporate/xbrl/BANKING_104623_1105106_21042024122701.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_101078_1023175_16012024051131.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_97616_956099_17102023052102.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_94218_888372_17072023062652.xml',
       'https://nsearchives.nseindia.com/corporate/xbrl/BANKING_90715_821266_17042023022426.xml']

data = pd.read_csv(eq_dir_ann)
cols = {'CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
data = data[cols.keys()]
data['symbol'] = sym
data.rename(columns=cols,inplace=True)
data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
data = data[data['period_ended'] > datetime.date(2020,1,1)] 
data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
print(data['results'])

# %%
# Implementation of specific results file with specific name format having only one symbol

import zipfile,re
import requests
import xml.etree.ElementTree as ET


headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}


def parse_xbrl(url):
    result = pd.DataFrame()
    # print(url)
    i = 0
    s = requests.Session()
    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    finres = pd.DataFrame.from_dict(results, orient='index')
    finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    results = json.dumps(results)
    return results


eq_dir_qtr = os.path.join('resources','equity_research')
timestamp = datetime.datetime.now()
for r,d,f in os.walk(eq_dir_qtr):
    for file in f:
        if re.search("^FINRESULTS_.*csv",file):
        # if re.search("^FINRESULTS_ANNUAL_TATAMOTORS.*csv",file):            
            sym = os.path.basename(file).split('.')[0].split('_')[2]

            # stockbhavlist.append(os.path.join(r,file))
            file = os.path.join(r,file)
            print(file)
            data = pd.read_csv(file)
            cols = {'CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
            data = data[cols.keys()]
            data['symbol'] = sym
            data.rename(columns=cols,inplace=True)
            data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
            data = data[data['period_ended'] > datetime.date(2020,1,1)] 
            data = data[data['consolidated'] == 'Consolidated']
            try:
                data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
                data['timestamp'] = timestamp
                data.drop('xbrl_url', axis=1, inplace=True)
                data.to_sql('financial_results',engine,if_exists='append',index=False)
                print(data)#[['consolidated','xbrl_url','results']])
            except:
                pass

# %%
# Implementation of general results file having several symbols together

import zipfile,re
import requests
import xml.etree.ElementTree as ET


headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}


def parse_xbrl(url):
    result = pd.DataFrame()
    # print(url)
    i = 0
    s = requests.Session()
    response = s.get(url,headers=headers)
    # print(response.content)
    
    # tree = ET.fromstring(response.content)
    
    # tapo = 'C:\\Users\\Santosh Bag\\Downloads\\TAPO.xml'
    # tree = ET.parse(tapo)
    # tree = ET.parse(response.text)
    # root = tree.getroot()
    root = ET.fromstring(response.text)
    results = {}
    for item in root:
        if 'in-bse-fin' in item.tag:
    #         print(item.attrib,item.text)
            results[item.tag.split('}')[1]] = item.text
    finres = pd.DataFrame.from_dict(results, orient='index')
    finres.rename(columns={0:i},inplace=True)
    # print(finres)
    # finres
    # result = pd.concat([result,finres],axis=1)
    # print('RESULT\n',result)
    i = i + 1
    results = json.dumps(results)
    return results

def getSymbol(company_desc):
    print(company_desc)
    sym = company_desc
    try:
        sym = engine.execute("select symbol from security_master where stock_name='"+company_desc+"' limit 1").fetchone()[0]
    except:
        pass
    return sym

eq_dir_qtr = os.path.join('resources','equity_research')
timestamp = datetime.datetime.now()
for r,d,f in os.walk(eq_dir_qtr):
    for file in f:
        if re.search("^FINANCIAL_RESULTS.*csv",file):
        # if re.search("^FINRESULTS_ANNUAL_TATAMOTORS.*csv",file):            
            # sym = os.path.basename(file).split('.')[0].split('_')[2]

            # stockbhavlist.append(os.path.join(r,file))
            file = os.path.join(r,file)
            print(file)
            data = pd.read_csv(file)
            cols = {'COMPANY NAME':'symbol','CONSOLIDATED / NON-CONSOLIDATED' : 'consolidated','PERIOD': 'period','PERIOD ENDED' : 'period_ended','RELATING TO' : 'related_qtr','** XBRL' : 'xbrl_url'}
            data = data[cols.keys()]
            data.rename(columns=cols,inplace=True)
            data['period_ended'] = pd.to_datetime(data['period_ended']).dt.date
            data = data[data['period_ended'] > datetime.date(2020,1,1)] 
            data = data[data['consolidated'] == 'Consolidated']
            try:
                data['results'] = data['xbrl_url'].apply(lambda x: parse_xbrl(x))
                data['timestamp'] = timestamp
                data.drop('xbrl_url', axis=1, inplace=True)
                data['symbol'] = data['symbol'].apply(lambda x: getSymbol(x))                
                # data.to_sql('financial_results',engine,if_exists='append',index=False)
                print(data)#[['consolidated','xbrl_url','results']])
            except:
                pass
            print(data)
# Out:
# resources\equity_research\FINANCIAL_RESULTS.csv
# Coforge Limited
# Suzlon Energy Limited
# Spencer's Retail Limited
# Mahindra Logistics Limited
# Poly Medicure Limited
# ZF Commercial Vehicle Control Systems India Limited
# Mangalore Refinery and Petrochemicals Limited
# Supreme Industries Limited
# Pondy Oxides & Chemicals Limited
# Greenlam Industries Limited
# IDBI Bank Limited
# UCO Bank
# Solara Active Pharma Sciences Limited
# Digicontent Limited
# Dodla Dairy Limited
# MMP Industries Limited
# Indian Overseas Bank
# HDFC Bank Limited
# Poonawalla Fincorp Limited
# Rossari Biotech Limited
# Aarti Surfactants Limited
# Gravita India Limited
# Arihant Capital Markets Limited
# Vikas Lifecare Limited
# Shakti Pumps (India) Limited
# JK Cement Limited
# Kotak Mahindra Bank Limited
# Kabra Extrusion Technik Limited
# Seshasayee Paper and Boards Limited
# Yes Bank Limited
# Integra Essentia Limited
# Union Bank of India
# RBL Bank Limited
# Summit Securities Limited
# Aurum PropTech Limited
# Tree House Education & Accessories Limited
# Ksolves India Limited
# Blue Dart Express Limited
# ROUTE MOBILE LIMITED
# Mahindra EPC Irrigation Limited
# Bharat Petroleum Corporation Limited
# PVR INOX Limited
# Reliance Industries Limited
# JSW Energy Limited
# Patanjali Foods Limited
# Oberoi Realty Limited
# Tejas Networks Limited
# Jubilant Pharmova Limited
# JSW Steel Limited
# Nippon Life India Asset Management Limited
# CREDITACCESS GRAMEEN LIMITED
# UltraTech Cement Limited
# The Indian Hotels Company Limited
# One 97 Communications Limited
# CIE Automotive India Limited
# Wipro Limited
# Transformers And Rectifiers (India) Limited
# Atul Limited
# Sagar Cements Limited
# Onward Technologies Limited
# Aether Industries Limited
# Inventure Growth & Securities Limited
# L&T Technology Services Limited
# Tanla Platforms Limited
# Havells India Limited
# Grindwell Norton Limited
# Premier Explosives Limited
# Infosys Limited
# The South Indian Bank Limited
# CEAT Limited
# Shoppers Stop Limited
# Tata Communications Limited
# Sterling and Wilson Renewable Energy Limited
# Choice International Limited
# Persistent Systems Limited
# Polycab India Limited
# Dalmia Bharat Limited
# Menon Bearings Limited
# Reliance Industrial Infrastructure Limited
# Central Bank of India
# JSW Infrastructure Limited
# Tata Technologies Limited
# Newgen Software Technologies Limited
# Mastek Limited
# Vimta Labs Limited
# Asian Paints Limited
# Hathway Cable & Datacom Limited
# LTIMindtree Limited
# Alok Industries Limited
# TV18 Broadcast Limited
# Network18 Media & Investments Limited
# Elecon Engineering Company Limited
# Jubilant Ingrevia Limited
# Agro Tech Foods Limited
# CRISIL Limited
# L&T Finance Limited
# Himadri Speciality Chemical Limited
# Century Textiles & Industries Limited
# Bajaj Auto Limited
# Viceroy Hotels Limited
# Kellton Tech Solutions Limited
# D.B.Corp Limited
# Angel One Limited
# Jio Financial Services Limited
# Den Networks Limited
# Monarch Networth Capital Limited
# HDFC Asset Management Company Limited
# Bank of Maharashtra
# Ganesh Housing Corporation Limited
# Geojit Financial Services Limited
# Avenue Supermarts Limited
# Bhansali Engineering Polymers Limited
# Excel Realty N Infra Limited
# HCL Technologies Limited
# 5Paisa Capital Limited
# Oriental Hotels Limited
# Vipul Limited
# NELCO Limited
# GTPL Hathway Limited
# Tata Consultancy Services Limited
# GNA Axles Limited
# JTL INDUSTRIES LIMITED
# Wealth First Portfolio Managers Limited
# DRC Systems India Limited
# Hexa Tradex Limited
# Lancor Holdings Limited
# Kesoram Industries Limited
# KCP Sugar and Industries Corporation Limited
# Delta Corp Limited
# R. S. Software (India) Limited
# Shalby Limited
#                        symbol  consolidated     period period_ended  \
# 1                     COFORGE  Consolidated  Quarterly   2024-06-30
# 3                      SUZLON  Consolidated  Quarterly   2024-06-30
# 5    Spencer's Retail Limited  Consolidated  Quarterly   2024-06-30
# 7                      MAHLOG  Consolidated  Quarterly   2024-06-30
# 9                     POLYMED  Consolidated  Quarterly   2024-06-30
# 12                  ZFCVINDIA  Consolidated  Quarterly   2024-06-30
# 15                       MRPL  Consolidated  Quarterly   2024-06-30
# 18                 SUPREMEIND  Consolidated  Quarterly   2024-06-30
# 20                       POCL  Consolidated  Quarterly   2024-06-30
# 22                   GREENLAM  Consolidated  Quarterly   2024-06-30
# 24                       IDBI  Consolidated  Quarterly   2024-06-30
# 26                    UCOBANK  Consolidated  Quarterly   2024-06-30
# 28                     SOLARA  Consolidated  Quarterly   2024-06-30
# 30                  DGCONTENT  Consolidated  Quarterly   2024-06-30
# 33                      DODLA  Consolidated  Quarterly   2024-06-30
# 35     MMP Industries Limited  Consolidated  Quarterly   2024-06-30
# 37                        IOB  Consolidated  Quarterly   2024-06-30
# 39                   HDFCBANK  Consolidated  Quarterly   2024-06-30
# 43                 POONAWALLA  Consolidated  Quarterly   2024-06-30
# 45                    ROSSARI  Consolidated  Quarterly   2024-06-30
# 47                  AARTISURF  Consolidated  Quarterly   2024-06-30
# 49                    GRAVITA  Consolidated  Quarterly   2024-06-30
# 51                 ARIHANTCAP  Consolidated  Quarterly   2024-06-30
# 53                  VIKASLIFE  Consolidated  Quarterly   2024-06-30
# 57                 SHAKTIPUMP  Consolidated  Quarterly   2024-06-30
# 58                   JKCEMENT  Consolidated  Quarterly   2024-06-30
# 61                  KOTAKBANK  Consolidated  Quarterly   2024-06-30
# 63                 KABRAEXTRU  Consolidated  Quarterly   2024-06-30
# 65                 SESHAPAPER  Consolidated  Quarterly   2024-06-30
# 67                    YESBANK  Consolidated  Quarterly   2024-06-30
# 70                   ESSENTIA  Consolidated  Quarterly   2024-06-30
# 73                  UNIONBANK  Consolidated  Quarterly   2024-06-30
# 74                    RBLBANK  Consolidated  Quarterly   2024-06-30
# 76                  SUMMITSEC  Consolidated  Quarterly   2024-06-30
# 78                      AURUM  Consolidated  Quarterly   2024-06-30
# 81                  TREEHOUSE  Consolidated  Quarterly   2024-06-30
# 83                    KSOLVES  Consolidated  Quarterly   2024-06-30
# 85                   BLUEDART  Consolidated  Quarterly   2024-06-30
# 87                      ROUTE  Consolidated  Quarterly   2024-06-30
# 89                     MAHEPC  Consolidated  Quarterly   2024-06-30
# 91                       BPCL  Consolidated  Quarterly   2024-06-30
# 93                    PVRINOX  Consolidated  Quarterly   2024-06-30
# 97                   RELIANCE  Consolidated  Quarterly   2024-06-30
# 99                  JSWENERGY  Consolidated  Quarterly   2024-06-30
# 101                 PATANJALI  Consolidated  Quarterly   2024-06-30
# 103                OBEROIRLTY  Consolidated  Quarterly   2024-06-30
# 105                  TEJASNET  Consolidated  Quarterly   2024-06-30
# 107                JUBLPHARMA  Consolidated  Quarterly   2024-06-30
# 110                  JSWSTEEL  Consolidated  Quarterly   2024-06-30
# 112                 NAM-INDIA  Consolidated  Quarterly   2024-06-30
# 114                 CREDITACC  Consolidated  Quarterly   2024-06-30
# 116                ULTRACEMCO  Consolidated  Quarterly   2024-06-30
# 118                  INDHOTEL  Consolidated  Quarterly   2024-06-30
# 121                     PAYTM  Consolidated  Quarterly   2024-06-30
# 125                  CIEINDIA  Consolidated  Quarterly   2024-06-30
# 126                     WIPRO  Consolidated  Quarterly   2024-06-30
# 128                      TRIL  Consolidated  Quarterly   2024-06-30
# 130                      ATUL  Consolidated  Quarterly   2024-06-30
# 133                    SAGCEM  Consolidated  Quarterly   2024-06-30
# 137                 ONWARDTEC  Consolidated  Quarterly   2024-06-30
# 139                    AETHER  Consolidated  Quarterly   2024-06-30
# 141                 INVENTURE  Consolidated  Quarterly   2024-06-30
# 143                      LTTS  Consolidated  Quarterly   2024-06-30
# 145                     TANLA  Consolidated  Quarterly   2024-06-30
# 148                   HAVELLS  Consolidated  Quarterly   2024-06-30
# 150                 GRINDWELL  Consolidated  Quarterly   2024-06-30
# 152                 PREMEXPLN  Consolidated  Quarterly   2024-06-30
# 154                      INFY  Consolidated  Quarterly   2024-06-30
# 156                 SOUTHBANK  Consolidated  Quarterly   2024-06-30
# 157                   CEATLTD  Consolidated  Quarterly   2024-06-30
# 160                SHOPERSTOP  Consolidated  Quarterly   2024-06-30
# 164                  TATACOMM  Consolidated  Quarterly   2024-06-30
# 166                   SWSOLAR  Consolidated  Quarterly   2024-06-30
# 168                  CHOICEIN  Consolidated  Quarterly   2024-06-30
# 170                PERSISTENT  Consolidated  Quarterly   2024-06-30
# 172                   POLYCAB  Consolidated  Quarterly   2024-06-30
# 174                 DALMIABHA  Consolidated  Quarterly   2024-06-30
# 176                   MENONBE  Consolidated  Quarterly   2024-06-30
# 177                      RIIL  Consolidated  Quarterly   2024-06-30
# 180                 CENTRALBK  Consolidated  Quarterly   2024-06-30
# 184                  JSWINFRA  Consolidated  Quarterly   2024-06-30
# 186                  TATATECH  Consolidated  Quarterly   2024-06-30
# 188                    NEWGEN  Consolidated  Quarterly   2024-06-30
# 191                    MASTEK  Consolidated  Quarterly   2024-06-30
# 197                 VIMTALABS  Consolidated  Quarterly   2024-06-30
# 198                ASIANPAINT  Consolidated  Quarterly   2024-06-30
# 200                   HATHWAY  Consolidated  Quarterly   2024-06-30
# 202                      LTIM  Consolidated  Quarterly   2024-06-30
# 205                  ALOKTEXT  Consolidated  Quarterly   2024-06-30
# 207                TV18BRDCST  Consolidated  Quarterly   2024-06-30
# 209                 NETWORK18  Consolidated  Quarterly   2024-06-30
# 211                    ELECON  Consolidated  Quarterly   2024-06-30
# 213                JUBLINGREA  Consolidated  Quarterly   2024-06-30
# 215                      ATFL  Consolidated  Quarterly   2024-06-30
# 218                    CRISIL  Consolidated  Quarterly   2024-06-30
# 221                       LTF  Consolidated  Quarterly   2024-06-30
# 223                      HSCL  Consolidated  Quarterly   2024-06-30
# 224                CENTURYTEX  Consolidated  Quarterly   2024-06-30
# 227                BAJAJ-AUTO  Consolidated  Quarterly   2024-06-30
# 229                     VHLTD  Consolidated  Quarterly   2024-06-30
# 231                KELLTONTEC  Consolidated  Quarterly   2024-06-30
# 234                    DBCORP  Consolidated  Quarterly   2024-06-30
# 239                  ANGELONE  Consolidated  Quarterly   2024-06-30
# 241                    JIOFIN  Consolidated  Quarterly   2024-06-30
# 244                       DEN  Consolidated  Quarterly   2024-06-30
# 247                   MONARCH  Consolidated  Quarterly   2024-06-30
# 250                   HDFCAMC  Consolidated  Quarterly   2024-06-30
# 253                  MAHABANK  Consolidated  Quarterly   2024-06-30
# 256                GANESHHOUC  Consolidated  Quarterly   2024-06-30
# 259                 GEOJITFSL  Consolidated  Quarterly   2024-06-30
# 261                     DMART  Consolidated  Quarterly   2024-06-30
# 264                      BEPL  Consolidated  Quarterly   2024-06-30
# 266                     EXCEL  Consolidated  Quarterly   2024-06-30
# 270                   HCLTECH  Consolidated  Quarterly   2024-06-30
# 272                    5PAISA  Consolidated  Quarterly   2024-06-30
# 275                 ORIENTHOT  Consolidated  Quarterly   2024-06-30
# 277                  VIPULLTD  Consolidated  Quarterly   2024-06-30
# 279                     NELCO  Consolidated  Quarterly   2024-06-30
# 281                      GTPL  Consolidated  Quarterly   2024-06-30
# 282                       TCS  Consolidated  Quarterly   2024-06-30
# 286                       GNA  Consolidated  Quarterly   2024-06-30
# 288                    JTLIND  Consolidated  Quarterly   2024-06-30
# 290                    WEALTH  Consolidated  Quarterly   2024-06-30
# 293                DRCSYSTEMS  Consolidated  Quarterly   2024-06-30
# 295                HEXATRADEX  Consolidated  Quarterly   2024-06-30
# 298                 LANCORHOL  Consolidated  Quarterly   2024-06-30
# 299                KESORAMIND  Consolidated  Quarterly   2024-06-30
# 301                 KCPSUGIND  Consolidated  Quarterly   2024-06-30
# 303                 DELTACORP  Consolidated  Quarterly   2024-06-30
# 305                RSSOFTWARE  Consolidated  Quarterly   2024-06-30
# 309                    SHALBY  Consolidated  Quarterly   2024-06-30
#
#         related_qtr                                            results  \
# 1     First Quarter  {"ScripCode": "532541", "Symbol": "COFORGE", "...
# 3     First Quarter  {"ScripCode": "532667", "Symbol": "SUZLON", "M...
# 5     First Quarter  {"ScripCode": "542337", "Symbol": "SPENCERS", ...
# 7     First Quarter  {"ScripCode": "540768", "Symbol": "MAHLOG", "M...
# 9     First Quarter  {"ScripCode": "531768", "Symbol": "POLYMED", "...
# 12    First Quarter  {"ScripCode": "533023", "Symbol": "ZFCVINDIA",...
# 15    First Quarter  {"ScripCode": "500109", "Symbol": "MRPL", "MSE...
# 18    First Quarter  {"ScripCode": "509930", "Symbol": "SUPREMEIND"...
# 20    First Quarter  {"ScripCode": "532626", "Symbol": "POCL", "MSE...
# 22    First Quarter  {"ScripCode": "538979", "Symbol": "GREENLAM", ...
# 24    First Quarter  {"ScripCode": "500116", "Symbol": "IDBI", "MSE...
# 26    First Quarter  {"ScripCode": "532505", "Symbol": "UCOBANK", "...
# 28    First Quarter  {"ScripCode": "541540", "Symbol": "SOLARA", "M...
# 30    First Quarter  {"ScripCode": "542685", "Symbol": "DGCONTENT",...
# 33    First Quarter  {"ScripCode": "543306", "Symbol": "DODLA", "MS...
# 35    First Quarter  {"ScripCode": "123123", "Symbol": "MMP", "MSEI...
# 37    First Quarter  {"ScripCode": "532388", "Symbol": "IOB", "MSEI...
# 39    First Quarter  {"ScripCode": "500180", "Symbol": "HDFCBANK", ...
# 43    First Quarter  {"ScripCode": "524000", "Symbol": "POONAWALLA"...
# 45    First Quarter  {"ScripCode": "543213", "Symbol": "ROSSARI", "...
# 47    First Quarter  {"ScripCode": "543210", "Symbol": "AARTISURF",...
# 49    First Quarter  {"ScripCode": "533282", "Symbol": "GRAVITA", "...
# 51    First Quarter  {"ScripCode": "511605", "Symbol": "ARIHANTCAP"...
# 53    First Quarter  {"ScripCode": "542655", "Symbol": "VIKASLIFE",...
# 57    First Quarter  {"ScripCode": "531431", "Symbol": "SHAKTIPUMP"...
# 58    First Quarter  {"ScripCode": "532644", "Symbol": "JKCEMENT", ...
# 61    First Quarter  {"ScripCode": "500247", "Symbol": "KOTAKBANK",...
# 63    First Quarter  {"ScripCode": "524109", "Symbol": "KABRAEXTRU"...
# 65    First Quarter  {"ScripCode": "502450", "Symbol": "SESHAPAPER"...
# 67    First Quarter  {"ScripCode": "532648", "Symbol": "YESBANK", "...
# 70    First Quarter  {"ScripCode": "535958", "Symbol": "ESSENTIA", ...
# 73    First Quarter  {"ScripCode": "532477", "Symbol": "UNIONBANK",...
# 74    First Quarter  {"ScripCode": "540065", "Symbol": "RBLBANK", "...
# 76    First Quarter  {"ScripCode": "533306", "Symbol": "SUMMITSEC",...
# 78    First Quarter  {"ScripCode": "539289", "Symbol": "AURUM", "MS...
# 81    First Quarter  {"ScripCode": "533540", "Symbol": "TREEHOUSE",...
# 83    First Quarter  {"ScripCode": "543599", "Symbol": "KSOLVES", "...
# 85    First Quarter  {"ScripCode": "526612", "Symbol": "BLUEDART", ...
# 87    First Quarter  {"ScripCode": "543228", "Symbol": "ROUTE", "MS...
# 89    First Quarter  {"ScripCode": "523754", "Symbol": "MAHEPC", "M...
# 91    First Quarter  {"ScripCode": "500547", "Symbol": "BPCL", "MSE...
# 93    First Quarter  {"ScripCode": "532689", "Symbol": "PVRINOX", "...
# 97    First Quarter  {"ScripCode": "500325", "Symbol": "RELIANCE", ...
# 99    First Quarter  {"ScripCode": "533148", "Symbol": "JSWENERGY",...
# 101   First Quarter  {"ScripCode": "500368", "Symbol": "PATANJALI",...
# 103   First Quarter  {"ScripCode": "533273", "Symbol": "OBEROIRLTY"...
# 105   First Quarter  {"ScripCode": "540595", "Symbol": "TEJASNET", ...
# 107   First Quarter  {"ScripCode": "530019", "Symbol": "JUBLPHARMA"...
# 110   First Quarter  {"ScripCode": "500228", "Symbol": "JSWSTEEL", ...
# 112   First Quarter  {"ScripCode": "540767", "Symbol": "NAM-INDIA",...
# 114   First Quarter  {"ScripCode": "541770", "Symbol": "CREDITACC",...
# 116   First Quarter  {"ScripCode": "532538", "Symbol": "ULTRACEMCO"...
# 118   First Quarter  {"ScripCode": "500850", "Symbol": "INDHOTEL", ...
# 121   First Quarter  {"ScripCode": "543396", "Symbol": "PAYTM", "MS...
# 125  Second Quarter  {"ScripCode": "532756", "Symbol": "CIEINDIA", ...
# 126   First Quarter  {"ScripCode": "507685", "Symbol": "WIPRO", "MS...
# 128   First Quarter  {"ScripCode": "532928", "Symbol": "TRIL", "MSE...
# 130   First Quarter  {"ScripCode": "500027", "Symbol": "ATUL", "MSE...
# 133   First Quarter  {"ScripCode": "502090", "Symbol": "SAGCEM", "M...
# 137   First Quarter  {"ScripCode": "517536", "Symbol": "ONWARDTEC",...
# 139   First Quarter  {"ScripCode": "543534", "Symbol": "AETHER", "M...
# 141   First Quarter  {"ScripCode": "533506", "Symbol": "INVENTURE",...
# 143   First Quarter  {"ScripCode": "540115", "Symbol": "LTTS", "MSE...
# 145   First Quarter  {"ScripCode": "532790", "Symbol": "TANLA", "MS...
# 148   First Quarter  {"ScripCode": "517354", "Symbol": "HAVELLS", "...
# 150   First Quarter  {"ScripCode": "506076", "Symbol": "GRINDWELL",...
# 152   First Quarter  {"ScripCode": "526247", "Symbol": "PREMEXPLN",...
# 154   First Quarter  {"ScripCode": "500209", "Symbol": "INFY", "MSE...
# 156   First Quarter  {"ScripCode": "532218", "Symbol": "SOUTHBANK",...
# 157   First Quarter  {"ScripCode": "500878", "Symbol": "CEATLTD", "...
# 160   First Quarter  {"ScripCode": "532638", "Symbol": "SHOPERSTOP"...
# 164   First Quarter  {"ScripCode": "500483", "Symbol": "TATACOMM", ...
# 166   First Quarter  {"ScripCode": "542760", "Symbol": "SWSOLAR", "...
# 168   First Quarter  {"ScripCode": "531358", "Symbol": "CHOICEIN", ...
# 170   First Quarter  {"ScripCode": "533179", "Symbol": "PERSISTENT"...
# 172   First Quarter  {"ScripCode": "542652", "Symbol": "POLYCAB", "...
# 174   First Quarter  {"ScripCode": "542216", "Symbol": "DALBHARAT",...
# 176   First Quarter  {"ScripCode": "523828", "Symbol": "MENONBE", "...
# 177   First Quarter  {"ScripCode": "523445", "Symbol": "RIIL", "MSE...
# 180   First Quarter  {"ScripCode": "532885", "Symbol": "CENTRALBK",...
# 184   First Quarter  {"ScripCode": "543994", "Symbol": "JSWINFRA", ...
# 186   First Quarter  {"ScripCode": "544028", "Symbol": "TATATECH", ...
# 188   First Quarter  {"ScripCode": "540900", "Symbol": "NEWGEN", "M...
# 191   First Quarter  {"ScripCode": "523704", "Symbol": "MASTEK", "M...
# 197   First Quarter  {"ScripCode": "524394", "Symbol": "VIMTALABS",...
# 198   First Quarter  {"ScripCode": "500820", "Symbol": "ASIANPAINT"...
# 200   First Quarter  {"ScripCode": "533162", "Symbol": "HATHWAY", "...
# 202   First Quarter  {"ScripCode": "540005", "Symbol": "LTIM", "MSE...
# 205   First Quarter  {"ScripCode": "521070", "Symbol": "ALOKINDS", ...
# 207   First Quarter  {"ScripCode": "532800", "Symbol": "TV18BRDCST"...
# 209   First Quarter  {"ScripCode": "532798", "Symbol": "NETWORK18",...
# 211   First Quarter  {"ScripCode": "505700", "Symbol": "ELECON", "M...
# 213   First Quarter  {"ScripCode": "543271", "Symbol": "JUBLINGREA"...
# 215   First Quarter  {"ScripCode": "500215", "Symbol": "ATFL", "MSE...
# 218  Second Quarter  {"ScripCode": "500092", "Symbol": "CRISIL", "M...
# 221   First Quarter  {"ScripCode": "533519", "Symbol": "LTF", "MSEI...
# 223   First Quarter  {"ScripCode": "500184", "Symbol": "HSCL", "MSE...
# 224   First Quarter  {"ScripCode": "500040", "Symbol": "CENTURYTEX"...
# 227   First Quarter  {"ScripCode": "532977", "Symbol": "BAJAJ-AUTO"...
# 229   First Quarter  {"ScripCode": "523796", "Symbol": "VHLTD", "MS...
# 231   First Quarter  {"ScripCode": "519602", "Symbol": "KELLTONTEC"...
# 234   First Quarter  {"ScripCode": "533151", "Symbol": "DBCORP", "M...
# 239   First Quarter  {"ScripCode": "543235", "Symbol": "ANGELONE", ...
# 241   First Quarter  {"ScripCode": "543940", "Symbol": "JIOFIN", "M...
# 244   First Quarter  {"ScripCode": "533137", "Symbol": "DEN", "MSEI...
# 247   First Quarter  {"ScripCode": "511551", "Symbol": "MONARCH", "...
# 250   First Quarter  {"ScripCode": "541729", "Symbol": "HDFCAMC", "...
# 253   First Quarter  {"ScripCode": "532525", "Symbol": "MAHABANK", ...
# 256   First Quarter  {"ScripCode": "526367", "Symbol": "GANESHHOUC"...
# 259   First Quarter  {"ScripCode": "532285", "Symbol": "GEOJITFSL",...
# 261   First Quarter  {"ScripCode": "540376", "Symbol": "DMART", "MS...
# 264   First Quarter  {"ScripCode": "500052", "Symbol": "BEPL", "MSE...
# 266   First Quarter  {"ScripCode": "533090", "Symbol": "EXCEL", "MS...
# 270   First Quarter  {"ScripCode": "532281", "Symbol": "HCLTECH", "...
# 272   First Quarter  {"ScripCode": "540776", "Symbol": "5PAISA", "M...
# 275   First Quarter  {"ScripCode": "500314", "Symbol": "ORIENTHOT",...
# 277   First Quarter  {"ScripCode": "511726", "Symbol": "VIPULLTD", ...
# 279   First Quarter  {"ScripCode": "504112", "Symbol": "NELCO", "MS...
# 281   First Quarter  {"ScripCode": "540602", "Symbol": "GTPL", "MSE...
# 282   First Quarter  {"ScripCode": "532540", "Symbol": "TCS", "MSEI...
# 286   First Quarter  {"ScripCode": "540124", "Symbol": "GNA", "MSEI...
# 288   First Quarter  {"ScripCode": "534600", "Symbol": "JTLIND", "M...
# 290   First Quarter  {"ScripCode": "123456", "Symbol": "WEALTH", "M...
# 293   First Quarter  {"ScripCode": "543268", "Symbol": "DRCSYSTEMS"...
# 295   First Quarter  {"ScripCode": "534328", "Symbol": "HEXATRADEX"...
# 298   First Quarter  {"ScripCode": "509048", "Symbol": "LANCORHOL",...
# 299   First Quarter  {"ScripCode": "502937", "Symbol": "KESORAMIND"...
# 301   First Quarter  {"ScripCode": "533192", "Symbol": "KCPSUGIND",...
# 303   First Quarter  {"ScripCode": "532848", "Symbol": "DELTACORP",...
# 305   First Quarter  {"ScripCode": "517447", "Symbol": "RSSOFTWARE"...
# 309   First Quarter  {"ScripCode": "540797", "Symbol": "SHALBY", "M...
#
#                      timestamp
# 1   2024-07-23 12:14:12.975168
# 3   2024-07-23 12:14:12.975168
# 5   2024-07-23 12:14:12.975168
# 7   2024-07-23 12:14:12.975168
# 9   2024-07-23 12:14:12.975168
# 12  2024-07-23 12:14:12.975168
# 15  2024-07-23 12:14:12.975168
# 18  2024-07-23 12:14:12.975168
# 20  2024-07-23 12:14:12.975168
# 22  2024-07-23 12:14:12.975168
# 24  2024-07-23 12:14:12.975168
# 26  2024-07-23 12:14:12.975168
# 28  2024-07-23 12:14:12.975168
# 30  2024-07-23 12:14:12.975168
# 33  2024-07-23 12:14:12.975168
# 35  2024-07-23 12:14:12.975168
# 37  2024-07-23 12:14:12.975168
# 39  2024-07-23 12:14:12.975168
# 43  2024-07-23 12:14:12.975168
# 45  2024-07-23 12:14:12.975168
# 47  2024-07-23 12:14:12.975168
# 49  2024-07-23 12:14:12.975168
# 51  2024-07-23 12:14:12.975168
# 53  2024-07-23 12:14:12.975168
# 57  2024-07-23 12:14:12.975168
# 58  2024-07-23 12:14:12.975168
# 61  2024-07-23 12:14:12.975168
# 63  2024-07-23 12:14:12.975168
# 65  2024-07-23 12:14:12.975168
# 67  2024-07-23 12:14:12.975168
# 70  2024-07-23 12:14:12.975168
# 73  2024-07-23 12:14:12.975168
# 74  2024-07-23 12:14:12.975168
# 76  2024-07-23 12:14:12.975168
# 78  2024-07-23 12:14:12.975168
# 81  2024-07-23 12:14:12.975168
# 83  2024-07-23 12:14:12.975168
# 85  2024-07-23 12:14:12.975168
# 87  2024-07-23 12:14:12.975168
# 89  2024-07-23 12:14:12.975168
# 91  2024-07-23 12:14:12.975168
# 93  2024-07-23 12:14:12.975168
# 97  2024-07-23 12:14:12.975168
# 99  2024-07-23 12:14:12.975168
# 101 2024-07-23 12:14:12.975168
# 103 2024-07-23 12:14:12.975168
# 105 2024-07-23 12:14:12.975168
# 107 2024-07-23 12:14:12.975168
# 110 2024-07-23 12:14:12.975168
# 112 2024-07-23 12:14:12.975168
# 114 2024-07-23 12:14:12.975168
# 116 2024-07-23 12:14:12.975168
# 118 2024-07-23 12:14:12.975168
# 121 2024-07-23 12:14:12.975168
# 125 2024-07-23 12:14:12.975168
# 126 2024-07-23 12:14:12.975168
# 128 2024-07-23 12:14:12.975168
# 130 2024-07-23 12:14:12.975168
# 133 2024-07-23 12:14:12.975168
# 137 2024-07-23 12:14:12.975168
# 139 2024-07-23 12:14:12.975168
# 141 2024-07-23 12:14:12.975168
# 143 2024-07-23 12:14:12.975168
# 145 2024-07-23 12:14:12.975168
# 148 2024-07-23 12:14:12.975168
# 150 2024-07-23 12:14:12.975168
# 152 2024-07-23 12:14:12.975168
# 154 2024-07-23 12:14:12.975168
# 156 2024-07-23 12:14:12.975168
# 157 2024-07-23 12:14:12.975168
# 160 2024-07-23 12:14:12.975168
# 164 2024-07-23 12:14:12.975168
# 166 2024-07-23 12:14:12.975168
# 168 2024-07-23 12:14:12.975168
# 170 2024-07-23 12:14:12.975168
# 172 2024-07-23 12:14:12.975168
# 174 2024-07-23 12:14:12.975168
# 176 2024-07-23 12:14:12.975168
# 177 2024-07-23 12:14:12.975168
# 180 2024-07-23 12:14:12.975168
# 184 2024-07-23 12:14:12.975168
# 186 2024-07-23 12:14:12.975168
# 188 2024-07-23 12:14:12.975168
# 191 2024-07-23 12:14:12.975168
# 197 2024-07-23 12:14:12.975168
# 198 2024-07-23 12:14:12.975168
# 200 2024-07-23 12:14:12.975168
# 202 2024-07-23 12:14:12.975168
# 205 2024-07-23 12:14:12.975168
# 207 2024-07-23 12:14:12.975168
# 209 2024-07-23 12:14:12.975168
# 211 2024-07-23 12:14:12.975168
# 213 2024-07-23 12:14:12.975168
# 215 2024-07-23 12:14:12.975168
# 218 2024-07-23 12:14:12.975168
# 221 2024-07-23 12:14:12.975168
# 223 2024-07-23 12:14:12.975168
# 224 2024-07-23 12:14:12.975168
# 227 2024-07-23 12:14:12.975168
# 229 2024-07-23 12:14:12.975168
# 231 2024-07-23 12:14:12.975168
# 234 2024-07-23 12:14:12.975168
# 239 2024-07-23 12:14:12.975168
# 241 2024-07-23 12:14:12.975168
# 244 2024-07-23 12:14:12.975168
# 247 2024-07-23 12:14:12.975168
# 250 2024-07-23 12:14:12.975168
# 253 2024-07-23 12:14:12.975168
# 256 2024-07-23 12:14:12.975168
# 259 2024-07-23 12:14:12.975168
# 261 2024-07-23 12:14:12.975168
# 264 2024-07-23 12:14:12.975168
# 266 2024-07-23 12:14:12.975168
# 270 2024-07-23 12:14:12.975168
# 272 2024-07-23 12:14:12.975168
# 275 2024-07-23 12:14:12.975168
# 277 2024-07-23 12:14:12.975168
# 279 2024-07-23 12:14:12.975168
# 281 2024-07-23 12:14:12.975168
# 282 2024-07-23 12:14:12.975168
# 286 2024-07-23 12:14:12.975168
# 288 2024-07-23 12:14:12.975168
# 290 2024-07-23 12:14:12.975168
# 293 2024-07-23 12:14:12.975168
# 295 2024-07-23 12:14:12.975168
# 298 2024-07-23 12:14:12.975168
# 299 2024-07-23 12:14:12.975168
# 301 2024-07-23 12:14:12.975168
# 303 2024-07-23 12:14:12.975168
# 305 2024-07-23 12:14:12.975168
# 309 2024-07-23 12:14:12.975168
#                        symbol  consolidated     period period_ended  \
# 1                     COFORGE  Consolidated  Quarterly   2024-06-30
# 3                      SUZLON  Consolidated  Quarterly   2024-06-30
# 5    Spencer's Retail Limited  Consolidated  Quarterly   2024-06-30
# 7                      MAHLOG  Consolidated  Quarterly   2024-06-30
# 9                     POLYMED  Consolidated  Quarterly   2024-06-30
# 12                  ZFCVINDIA  Consolidated  Quarterly   2024-06-30
# 15                       MRPL  Consolidated  Quarterly   2024-06-30
# 18                 SUPREMEIND  Consolidated  Quarterly   2024-06-30
# 20                       POCL  Consolidated  Quarterly   2024-06-30
# 22                   GREENLAM  Consolidated  Quarterly   2024-06-30
# 24                       IDBI  Consolidated  Quarterly   2024-06-30
# 26                    UCOBANK  Consolidated  Quarterly   2024-06-30
# 28                     SOLARA  Consolidated  Quarterly   2024-06-30
# 30                  DGCONTENT  Consolidated  Quarterly   2024-06-30
# 33                      DODLA  Consolidated  Quarterly   2024-06-30
# 35     MMP Industries Limited  Consolidated  Quarterly   2024-06-30
# 37                        IOB  Consolidated  Quarterly   2024-06-30
# 39                   HDFCBANK  Consolidated  Quarterly   2024-06-30
# 43                 POONAWALLA  Consolidated  Quarterly   2024-06-30
# 45                    ROSSARI  Consolidated  Quarterly   2024-06-30
# 47                  AARTISURF  Consolidated  Quarterly   2024-06-30
# 49                    GRAVITA  Consolidated  Quarterly   2024-06-30
# 51                 ARIHANTCAP  Consolidated  Quarterly   2024-06-30
# 53                  VIKASLIFE  Consolidated  Quarterly   2024-06-30
# 57                 SHAKTIPUMP  Consolidated  Quarterly   2024-06-30
# 58                   JKCEMENT  Consolidated  Quarterly   2024-06-30
# 61                  KOTAKBANK  Consolidated  Quarterly   2024-06-30
# 63                 KABRAEXTRU  Consolidated  Quarterly   2024-06-30
# 65                 SESHAPAPER  Consolidated  Quarterly   2024-06-30
# 67                    YESBANK  Consolidated  Quarterly   2024-06-30
# 70                   ESSENTIA  Consolidated  Quarterly   2024-06-30
# 73                  UNIONBANK  Consolidated  Quarterly   2024-06-30
# 74                    RBLBANK  Consolidated  Quarterly   2024-06-30
# 76                  SUMMITSEC  Consolidated  Quarterly   2024-06-30
# 78                      AURUM  Consolidated  Quarterly   2024-06-30
# 81                  TREEHOUSE  Consolidated  Quarterly   2024-06-30
# 83                    KSOLVES  Consolidated  Quarterly   2024-06-30
# 85                   BLUEDART  Consolidated  Quarterly   2024-06-30
# 87                      ROUTE  Consolidated  Quarterly   2024-06-30
# 89                     MAHEPC  Consolidated  Quarterly   2024-06-30
# 91                       BPCL  Consolidated  Quarterly   2024-06-30
# 93                    PVRINOX  Consolidated  Quarterly   2024-06-30
# 97                   RELIANCE  Consolidated  Quarterly   2024-06-30
# 99                  JSWENERGY  Consolidated  Quarterly   2024-06-30
# 101                 PATANJALI  Consolidated  Quarterly   2024-06-30
# 103                OBEROIRLTY  Consolidated  Quarterly   2024-06-30
# 105                  TEJASNET  Consolidated  Quarterly   2024-06-30
# 107                JUBLPHARMA  Consolidated  Quarterly   2024-06-30
# 110                  JSWSTEEL  Consolidated  Quarterly   2024-06-30
# 112                 NAM-INDIA  Consolidated  Quarterly   2024-06-30
# 114                 CREDITACC  Consolidated  Quarterly   2024-06-30
# 116                ULTRACEMCO  Consolidated  Quarterly   2024-06-30
# 118                  INDHOTEL  Consolidated  Quarterly   2024-06-30
# 121                     PAYTM  Consolidated  Quarterly   2024-06-30
# 125                  CIEINDIA  Consolidated  Quarterly   2024-06-30
# 126                     WIPRO  Consolidated  Quarterly   2024-06-30
# 128                      TRIL  Consolidated  Quarterly   2024-06-30
# 130                      ATUL  Consolidated  Quarterly   2024-06-30
# 133                    SAGCEM  Consolidated  Quarterly   2024-06-30
# 137                 ONWARDTEC  Consolidated  Quarterly   2024-06-30
# 139                    AETHER  Consolidated  Quarterly   2024-06-30
# 141                 INVENTURE  Consolidated  Quarterly   2024-06-30
# 143                      LTTS  Consolidated  Quarterly   2024-06-30
# 145                     TANLA  Consolidated  Quarterly   2024-06-30
# 148                   HAVELLS  Consolidated  Quarterly   2024-06-30
# 150                 GRINDWELL  Consolidated  Quarterly   2024-06-30
# 152                 PREMEXPLN  Consolidated  Quarterly   2024-06-30
# 154                      INFY  Consolidated  Quarterly   2024-06-30
# 156                 SOUTHBANK  Consolidated  Quarterly   2024-06-30
# 157                   CEATLTD  Consolidated  Quarterly   2024-06-30
# 160                SHOPERSTOP  Consolidated  Quarterly   2024-06-30
# 164                  TATACOMM  Consolidated  Quarterly   2024-06-30
# 166                   SWSOLAR  Consolidated  Quarterly   2024-06-30
# 168                  CHOICEIN  Consolidated  Quarterly   2024-06-30
# 170                PERSISTENT  Consolidated  Quarterly   2024-06-30
# 172                   POLYCAB  Consolidated  Quarterly   2024-06-30
# 174                 DALMIABHA  Consolidated  Quarterly   2024-06-30
# 176                   MENONBE  Consolidated  Quarterly   2024-06-30
# 177                      RIIL  Consolidated  Quarterly   2024-06-30
# 180                 CENTRALBK  Consolidated  Quarterly   2024-06-30
# 184                  JSWINFRA  Consolidated  Quarterly   2024-06-30
# 186                  TATATECH  Consolidated  Quarterly   2024-06-30
# 188                    NEWGEN  Consolidated  Quarterly   2024-06-30
# 191                    MASTEK  Consolidated  Quarterly   2024-06-30
# 197                 VIMTALABS  Consolidated  Quarterly   2024-06-30
# 198                ASIANPAINT  Consolidated  Quarterly   2024-06-30
# 200                   HATHWAY  Consolidated  Quarterly   2024-06-30
# 202                      LTIM  Consolidated  Quarterly   2024-06-30
# 205                  ALOKTEXT  Consolidated  Quarterly   2024-06-30
# 207                TV18BRDCST  Consolidated  Quarterly   2024-06-30
# 209                 NETWORK18  Consolidated  Quarterly   2024-06-30
# 211                    ELECON  Consolidated  Quarterly   2024-06-30
# 213                JUBLINGREA  Consolidated  Quarterly   2024-06-30
# 215                      ATFL  Consolidated  Quarterly   2024-06-30
# 218                    CRISIL  Consolidated  Quarterly   2024-06-30
# 221                       LTF  Consolidated  Quarterly   2024-06-30
# 223                      HSCL  Consolidated  Quarterly   2024-06-30
# 224                CENTURYTEX  Consolidated  Quarterly   2024-06-30
# 227                BAJAJ-AUTO  Consolidated  Quarterly   2024-06-30
# 229                     VHLTD  Consolidated  Quarterly   2024-06-30
# 231                KELLTONTEC  Consolidated  Quarterly   2024-06-30
# 234                    DBCORP  Consolidated  Quarterly   2024-06-30
# 239                  ANGELONE  Consolidated  Quarterly   2024-06-30
# 241                    JIOFIN  Consolidated  Quarterly   2024-06-30
# 244                       DEN  Consolidated  Quarterly   2024-06-30
# 247                   MONARCH  Consolidated  Quarterly   2024-06-30
# 250                   HDFCAMC  Consolidated  Quarterly   2024-06-30
# 253                  MAHABANK  Consolidated  Quarterly   2024-06-30
# 256                GANESHHOUC  Consolidated  Quarterly   2024-06-30
# 259                 GEOJITFSL  Consolidated  Quarterly   2024-06-30
# 261                     DMART  Consolidated  Quarterly   2024-06-30
# 264                      BEPL  Consolidated  Quarterly   2024-06-30
# 266                     EXCEL  Consolidated  Quarterly   2024-06-30
# 270                   HCLTECH  Consolidated  Quarterly   2024-06-30
# 272                    5PAISA  Consolidated  Quarterly   2024-06-30
# 275                 ORIENTHOT  Consolidated  Quarterly   2024-06-30
# 277                  VIPULLTD  Consolidated  Quarterly   2024-06-30
# 279                     NELCO  Consolidated  Quarterly   2024-06-30
# 281                      GTPL  Consolidated  Quarterly   2024-06-30
# 282                       TCS  Consolidated  Quarterly   2024-06-30
# 286                       GNA  Consolidated  Quarterly   2024-06-30
# 288                    JTLIND  Consolidated  Quarterly   2024-06-30
# 290                    WEALTH  Consolidated  Quarterly   2024-06-30
# 293                DRCSYSTEMS  Consolidated  Quarterly   2024-06-30
# 295                HEXATRADEX  Consolidated  Quarterly   2024-06-30
# 298                 LANCORHOL  Consolidated  Quarterly   2024-06-30
# 299                KESORAMIND  Consolidated  Quarterly   2024-06-30
# 301                 KCPSUGIND  Consolidated  Quarterly   2024-06-30
# 303                 DELTACORP  Consolidated  Quarterly   2024-06-30
# 305                RSSOFTWARE  Consolidated  Quarterly   2024-06-30
# 309                    SHALBY  Consolidated  Quarterly   2024-06-30
#
#         related_qtr                                            results  \
# 1     First Quarter  {"ScripCode": "532541", "Symbol": "COFORGE", "...
# 3     First Quarter  {"ScripCode": "532667", "Symbol": "SUZLON", "M...
# 5     First Quarter  {"ScripCode": "542337", "Symbol": "SPENCERS", ...
# 7     First Quarter  {"ScripCode": "540768", "Symbol": "MAHLOG", "M...
# 9     First Quarter  {"ScripCode": "531768", "Symbol": "POLYMED", "...
# 12    First Quarter  {"ScripCode": "533023", "Symbol": "ZFCVINDIA",...
# 15    First Quarter  {"ScripCode": "500109", "Symbol": "MRPL", "MSE...
# 18    First Quarter  {"ScripCode": "509930", "Symbol": "SUPREMEIND"...
# 20    First Quarter  {"ScripCode": "532626", "Symbol": "POCL", "MSE...
# 22    First Quarter  {"ScripCode": "538979", "Symbol": "GREENLAM", ...
# 24    First Quarter  {"ScripCode": "500116", "Symbol": "IDBI", "MSE...
# 26    First Quarter  {"ScripCode": "532505", "Symbol": "UCOBANK", "...
# 28    First Quarter  {"ScripCode": "541540", "Symbol": "SOLARA", "M...
# 30    First Quarter  {"ScripCode": "542685", "Symbol": "DGCONTENT",...
# 33    First Quarter  {"ScripCode": "543306", "Symbol": "DODLA", "MS...
# 35    First Quarter  {"ScripCode": "123123", "Symbol": "MMP", "MSEI...
# 37    First Quarter  {"ScripCode": "532388", "Symbol": "IOB", "MSEI...
# 39    First Quarter  {"ScripCode": "500180", "Symbol": "HDFCBANK", ...
# 43    First Quarter  {"ScripCode": "524000", "Symbol": "POONAWALLA"...
# 45    First Quarter  {"ScripCode": "543213", "Symbol": "ROSSARI", "...
# 47    First Quarter  {"ScripCode": "543210", "Symbol": "AARTISURF",...
# 49    First Quarter  {"ScripCode": "533282", "Symbol": "GRAVITA", "...
# 51    First Quarter  {"ScripCode": "511605", "Symbol": "ARIHANTCAP"...
# 53    First Quarter  {"ScripCode": "542655", "Symbol": "VIKASLIFE",...
# 57    First Quarter  {"ScripCode": "531431", "Symbol": "SHAKTIPUMP"...
# 58    First Quarter  {"ScripCode": "532644", "Symbol": "JKCEMENT", ...
# 61    First Quarter  {"ScripCode": "500247", "Symbol": "KOTAKBANK",...
# 63    First Quarter  {"ScripCode": "524109", "Symbol": "KABRAEXTRU"...
# 65    First Quarter  {"ScripCode": "502450", "Symbol": "SESHAPAPER"...
# 67    First Quarter  {"ScripCode": "532648", "Symbol": "YESBANK", "...
# 70    First Quarter  {"ScripCode": "535958", "Symbol": "ESSENTIA", ...
# 73    First Quarter  {"ScripCode": "532477", "Symbol": "UNIONBANK",...
# 74    First Quarter  {"ScripCode": "540065", "Symbol": "RBLBANK", "...
# 76    First Quarter  {"ScripCode": "533306", "Symbol": "SUMMITSEC",...
# 78    First Quarter  {"ScripCode": "539289", "Symbol": "AURUM", "MS...
# 81    First Quarter  {"ScripCode": "533540", "Symbol": "TREEHOUSE",...
# 83    First Quarter  {"ScripCode": "543599", "Symbol": "KSOLVES", "...
# 85    First Quarter  {"ScripCode": "526612", "Symbol": "BLUEDART", ...
# 87    First Quarter  {"ScripCode": "543228", "Symbol": "ROUTE", "MS...
# 89    First Quarter  {"ScripCode": "523754", "Symbol": "MAHEPC", "M...
# 91    First Quarter  {"ScripCode": "500547", "Symbol": "BPCL", "MSE...
# 93    First Quarter  {"ScripCode": "532689", "Symbol": "PVRINOX", "...
# 97    First Quarter  {"ScripCode": "500325", "Symbol": "RELIANCE", ...
# 99    First Quarter  {"ScripCode": "533148", "Symbol": "JSWENERGY",...
# 101   First Quarter  {"ScripCode": "500368", "Symbol": "PATANJALI",...
# 103   First Quarter  {"ScripCode": "533273", "Symbol": "OBEROIRLTY"...
# 105   First Quarter  {"ScripCode": "540595", "Symbol": "TEJASNET", ...
# 107   First Quarter  {"ScripCode": "530019", "Symbol": "JUBLPHARMA"...
# 110   First Quarter  {"ScripCode": "500228", "Symbol": "JSWSTEEL", ...
# 112   First Quarter  {"ScripCode": "540767", "Symbol": "NAM-INDIA",...
# 114   First Quarter  {"ScripCode": "541770", "Symbol": "CREDITACC",...
# 116   First Quarter  {"ScripCode": "532538", "Symbol": "ULTRACEMCO"...
# 118   First Quarter  {"ScripCode": "500850", "Symbol": "INDHOTEL", ...
# 121   First Quarter  {"ScripCode": "543396", "Symbol": "PAYTM", "MS...
# 125  Second Quarter  {"ScripCode": "532756", "Symbol": "CIEINDIA", ...
# 126   First Quarter  {"ScripCode": "507685", "Symbol": "WIPRO", "MS...
# 128   First Quarter  {"ScripCode": "532928", "Symbol": "TRIL", "MSE...
# 130   First Quarter  {"ScripCode": "500027", "Symbol": "ATUL", "MSE...
# 133   First Quarter  {"ScripCode": "502090", "Symbol": "SAGCEM", "M...
# 137   First Quarter  {"ScripCode": "517536", "Symbol": "ONWARDTEC",...
# 139   First Quarter  {"ScripCode": "543534", "Symbol": "AETHER", "M...
# 141   First Quarter  {"ScripCode": "533506", "Symbol": "INVENTURE",...
# 143   First Quarter  {"ScripCode": "540115", "Symbol": "LTTS", "MSE...
# 145   First Quarter  {"ScripCode": "532790", "Symbol": "TANLA", "MS...
# 148   First Quarter  {"ScripCode": "517354", "Symbol": "HAVELLS", "...
# 150   First Quarter  {"ScripCode": "506076", "Symbol": "GRINDWELL",...
# 152   First Quarter  {"ScripCode": "526247", "Symbol": "PREMEXPLN",...
# 154   First Quarter  {"ScripCode": "500209", "Symbol": "INFY", "MSE...
# 156   First Quarter  {"ScripCode": "532218", "Symbol": "SOUTHBANK",...
# 157   First Quarter  {"ScripCode": "500878", "Symbol": "CEATLTD", "...
# 160   First Quarter  {"ScripCode": "532638", "Symbol": "SHOPERSTOP"...
# 164   First Quarter  {"ScripCode": "500483", "Symbol": "TATACOMM", ...
# 166   First Quarter  {"ScripCode": "542760", "Symbol": "SWSOLAR", "...
# 168   First Quarter  {"ScripCode": "531358", "Symbol": "CHOICEIN", ...
# 170   First Quarter  {"ScripCode": "533179", "Symbol": "PERSISTENT"...
# 172   First Quarter  {"ScripCode": "542652", "Symbol": "POLYCAB", "...
# 174   First Quarter  {"ScripCode": "542216", "Symbol": "DALBHARAT",...
# 176   First Quarter  {"ScripCode": "523828", "Symbol": "MENONBE", "...
# 177   First Quarter  {"ScripCode": "523445", "Symbol": "RIIL", "MSE...
# 180   First Quarter  {"ScripCode": "532885", "Symbol": "CENTRALBK",...
# 184   First Quarter  {"ScripCode": "543994", "Symbol": "JSWINFRA", ...
# 186   First Quarter  {"ScripCode": "544028", "Symbol": "TATATECH", ...
# 188   First Quarter  {"ScripCode": "540900", "Symbol": "NEWGEN", "M...
# 191   First Quarter  {"ScripCode": "523704", "Symbol": "MASTEK", "M...
# 197   First Quarter  {"ScripCode": "524394", "Symbol": "VIMTALABS",...
# 198   First Quarter  {"ScripCode": "500820", "Symbol": "ASIANPAINT"...
# 200   First Quarter  {"ScripCode": "533162", "Symbol": "HATHWAY", "...
# 202   First Quarter  {"ScripCode": "540005", "Symbol": "LTIM", "MSE...
# 205   First Quarter  {"ScripCode": "521070", "Symbol": "ALOKINDS", ...
# 207   First Quarter  {"ScripCode": "532800", "Symbol": "TV18BRDCST"...
# 209   First Quarter  {"ScripCode": "532798", "Symbol": "NETWORK18",...
# 211   First Quarter  {"ScripCode": "505700", "Symbol": "ELECON", "M...
# 213   First Quarter  {"ScripCode": "543271", "Symbol": "JUBLINGREA"...
# 215   First Quarter  {"ScripCode": "500215", "Symbol": "ATFL", "MSE...
# 218  Second Quarter  {"ScripCode": "500092", "Symbol": "CRISIL", "M...
# 221   First Quarter  {"ScripCode": "533519", "Symbol": "LTF", "MSEI...
# 223   First Quarter  {"ScripCode": "500184", "Symbol": "HSCL", "MSE...
# 224   First Quarter  {"ScripCode": "500040", "Symbol": "CENTURYTEX"...
# 227   First Quarter  {"ScripCode": "532977", "Symbol": "BAJAJ-AUTO"...
# 229   First Quarter  {"ScripCode": "523796", "Symbol": "VHLTD", "MS...
# 231   First Quarter  {"ScripCode": "519602", "Symbol": "KELLTONTEC"...
# 234   First Quarter  {"ScripCode": "533151", "Symbol": "DBCORP", "M...
# 239   First Quarter  {"ScripCode": "543235", "Symbol": "ANGELONE", ...
# 241   First Quarter  {"ScripCode": "543940", "Symbol": "JIOFIN", "M...
# 244   First Quarter  {"ScripCode": "533137", "Symbol": "DEN", "MSEI...
# 247   First Quarter  {"ScripCode": "511551", "Symbol": "MONARCH", "...
# 250   First Quarter  {"ScripCode": "541729", "Symbol": "HDFCAMC", "...
# 253   First Quarter  {"ScripCode": "532525", "Symbol": "MAHABANK", ...
# 256   First Quarter  {"ScripCode": "526367", "Symbol": "GANESHHOUC"...
# 259   First Quarter  {"ScripCode": "532285", "Symbol": "GEOJITFSL",...
# 261   First Quarter  {"ScripCode": "540376", "Symbol": "DMART", "MS...
# 264   First Quarter  {"ScripCode": "500052", "Symbol": "BEPL", "MSE...
# 266   First Quarter  {"ScripCode": "533090", "Symbol": "EXCEL", "MS...
# 270   First Quarter  {"ScripCode": "532281", "Symbol": "HCLTECH", "...
# 272   First Quarter  {"ScripCode": "540776", "Symbol": "5PAISA", "M...
# 275   First Quarter  {"ScripCode": "500314", "Symbol": "ORIENTHOT",...
# 277   First Quarter  {"ScripCode": "511726", "Symbol": "VIPULLTD", ...
# 279   First Quarter  {"ScripCode": "504112", "Symbol": "NELCO", "MS...
# 281   First Quarter  {"ScripCode": "540602", "Symbol": "GTPL", "MSE...
# 282   First Quarter  {"ScripCode": "532540", "Symbol": "TCS", "MSEI...
# 286   First Quarter  {"ScripCode": "540124", "Symbol": "GNA", "MSEI...
# 288   First Quarter  {"ScripCode": "534600", "Symbol": "JTLIND", "M...
# 290   First Quarter  {"ScripCode": "123456", "Symbol": "WEALTH", "M...
# 293   First Quarter  {"ScripCode": "543268", "Symbol": "DRCSYSTEMS"...
# 295   First Quarter  {"ScripCode": "534328", "Symbol": "HEXATRADEX"...
# 298   First Quarter  {"ScripCode": "509048", "Symbol": "LANCORHOL",...
# 299   First Quarter  {"ScripCode": "502937", "Symbol": "KESORAMIND"...
# 301   First Quarter  {"ScripCode": "533192", "Symbol": "KCPSUGIND",...
# 303   First Quarter  {"ScripCode": "532848", "Symbol": "DELTACORP",...
# 305   First Quarter  {"ScripCode": "517447", "Symbol": "RSSOFTWARE"...
# 309   First Quarter  {"ScripCode": "540797", "Symbol": "SHALBY", "M...
#
#                      timestamp
# 1   2024-07-23 12:14:12.975168
# 3   2024-07-23 12:14:12.975168
# 5   2024-07-23 12:14:12.975168
# 7   2024-07-23 12:14:12.975168
# 9   2024-07-23 12:14:12.975168
# 12  2024-07-23 12:14:12.975168
# 15  2024-07-23 12:14:12.975168
# 18  2024-07-23 12:14:12.975168
# 20  2024-07-23 12:14:12.975168
# 22  2024-07-23 12:14:12.975168
# 24  2024-07-23 12:14:12.975168
# 26  2024-07-23 12:14:12.975168
# 28  2024-07-23 12:14:12.975168
# 30  2024-07-23 12:14:12.975168
# 33  2024-07-23 12:14:12.975168
# 35  2024-07-23 12:14:12.975168
# 37  2024-07-23 12:14:12.975168
# 39  2024-07-23 12:14:12.975168
# 43  2024-07-23 12:14:12.975168
# 45  2024-07-23 12:14:12.975168
# 47  2024-07-23 12:14:12.975168
# 49  2024-07-23 12:14:12.975168
# 51  2024-07-23 12:14:12.975168
# 53  2024-07-23 12:14:12.975168
# 57  2024-07-23 12:14:12.975168
# 58  2024-07-23 12:14:12.975168
# 61  2024-07-23 12:14:12.975168
# 63  2024-07-23 12:14:12.975168
# 65  2024-07-23 12:14:12.975168
# 67  2024-07-23 12:14:12.975168
# 70  2024-07-23 12:14:12.975168
# 73  2024-07-23 12:14:12.975168
# 74  2024-07-23 12:14:12.975168
# 76  2024-07-23 12:14:12.975168
# 78  2024-07-23 12:14:12.975168
# 81  2024-07-23 12:14:12.975168
# 83  2024-07-23 12:14:12.975168
# 85  2024-07-23 12:14:12.975168
# 87  2024-07-23 12:14:12.975168
# 89  2024-07-23 12:14:12.975168
# 91  2024-07-23 12:14:12.975168
# 93  2024-07-23 12:14:12.975168
# 97  2024-07-23 12:14:12.975168
# 99  2024-07-23 12:14:12.975168
# 101 2024-07-23 12:14:12.975168
# 103 2024-07-23 12:14:12.975168
# 105 2024-07-23 12:14:12.975168
# 107 2024-07-23 12:14:12.975168
# 110 2024-07-23 12:14:12.975168
# 112 2024-07-23 12:14:12.975168
# 114 2024-07-23 12:14:12.975168
# 116 2024-07-23 12:14:12.975168
# 118 2024-07-23 12:14:12.975168
# 121 2024-07-23 12:14:12.975168
# 125 2024-07-23 12:14:12.975168
# 126 2024-07-23 12:14:12.975168
# 128 2024-07-23 12:14:12.975168
# 130 2024-07-23 12:14:12.975168
# 133 2024-07-23 12:14:12.975168
# 137 2024-07-23 12:14:12.975168
# 139 2024-07-23 12:14:12.975168
# 141 2024-07-23 12:14:12.975168
# 143 2024-07-23 12:14:12.975168
# 145 2024-07-23 12:14:12.975168
# 148 2024-07-23 12:14:12.975168
# 150 2024-07-23 12:14:12.975168
# 152 2024-07-23 12:14:12.975168
# 154 2024-07-23 12:14:12.975168
# 156 2024-07-23 12:14:12.975168
# 157 2024-07-23 12:14:12.975168
# 160 2024-07-23 12:14:12.975168
# 164 2024-07-23 12:14:12.975168
# 166 2024-07-23 12:14:12.975168
# 168 2024-07-23 12:14:12.975168
# 170 2024-07-23 12:14:12.975168
# 172 2024-07-23 12:14:12.975168
# 174 2024-07-23 12:14:12.975168
# 176 2024-07-23 12:14:12.975168
# 177 2024-07-23 12:14:12.975168
# 180 2024-07-23 12:14:12.975168
# 184 2024-07-23 12:14:12.975168
# 186 2024-07-23 12:14:12.975168
# 188 2024-07-23 12:14:12.975168
# 191 2024-07-23 12:14:12.975168
# 197 2024-07-23 12:14:12.975168
# 198 2024-07-23 12:14:12.975168
# 200 2024-07-23 12:14:12.975168
# 202 2024-07-23 12:14:12.975168
# 205 2024-07-23 12:14:12.975168
# 207 2024-07-23 12:14:12.975168
# 209 2024-07-23 12:14:12.975168
# 211 2024-07-23 12:14:12.975168
# 213 2024-07-23 12:14:12.975168
# 215 2024-07-23 12:14:12.975168
# 218 2024-07-23 12:14:12.975168
# 221 2024-07-23 12:14:12.975168
# 223 2024-07-23 12:14:12.975168
# 224 2024-07-23 12:14:12.975168
# 227 2024-07-23 12:14:12.975168
# 229 2024-07-23 12:14:12.975168
# 231 2024-07-23 12:14:12.975168
# 234 2024-07-23 12:14:12.975168
# 239 2024-07-23 12:14:12.975168
# 241 2024-07-23 12:14:12.975168
# 244 2024-07-23 12:14:12.975168
# 247 2024-07-23 12:14:12.975168
# 250 2024-07-23 12:14:12.975168
# 253 2024-07-23 12:14:12.975168
# 256 2024-07-23 12:14:12.975168
# 259 2024-07-23 12:14:12.975168
# 261 2024-07-23 12:14:12.975168
# 264 2024-07-23 12:14:12.975168
# 266 2024-07-23 12:14:12.975168
# 270 2024-07-23 12:14:12.975168
# 272 2024-07-23 12:14:12.975168
# 275 2024-07-23 12:14:12.975168
# 277 2024-07-23 12:14:12.975168
# 279 2024-07-23 12:14:12.975168
# 281 2024-07-23 12:14:12.975168
# 282 2024-07-23 12:14:12.975168
# 286 2024-07-23 12:14:12.975168
# 288 2024-07-23 12:14:12.975168
# 290 2024-07-23 12:14:12.975168
# 293 2024-07-23 12:14:12.975168
# 295 2024-07-23 12:14:12.975168
# 298 2024-07-23 12:14:12.975168
# 299 2024-07-23 12:14:12.975168
# 301 2024-07-23 12:14:12.975168
# 303 2024-07-23 12:14:12.975168
# 305 2024-07-23 12:14:12.975168
# 309 2024-07-23 12:14:12.975168

# %%
symbol = 'TATASTEEL'
data_assets = funda.getResults(symbol,result_type='assets')
data_assets_top = pd.DataFrame([['' for c in data_assets.columns]],columns=data_assets.columns,index=['Assets'])
data_liabilities = funda.getResults(symbol,result_type='liabilities')
data_liabilities_top = pd.DataFrame([['' for c in data_assets.columns]],columns=data_liabilities.columns,index=['Liabilities'])
pd.concat([data_assets_top,data_assets,data_liabilities_top,data_liabilities])

# data_assets.index.name = 'Assets'
# data_liabilities.index.name = 'Liabilities'
# data_assets.reset_index()
# data_liabilities.reset_index()

# pd.concat([data_assets,data_liabilities])
# pd.concat([funda.getResults(symbol,result_type='assets'),funda.getResults(symbol,result_type='liabilities')])
# Out:
#                           Liabilities 2024-06-30        2024-03-31 2023-12-31  \
# 0              equity_and_liabilities        NaN  2734235000000.00        NaN
# 1                         liabilities        NaN  1809907600000.00        NaN
# 2             non_current_liabilities        NaN   825872800000.00        NaN
# 3              borrowings_non_current        NaN   561154300000.00        NaN
# 4          trade_payables_non_current        NaN              0.00        NaN
# 5   non_current_financial_liabilities        NaN   576073700000.00        NaN
# 6              provisions_non_current        NaN    54240300000.00        NaN
# 7        deferred_tax_liabilities_net        NaN   129923400000.00        NaN
# 8                 current_liabilities        NaN   984034800000.00        NaN
# 9                  borrowings_current        NaN   309666900000.00        NaN
# 10             trade_payables_current        NaN   354346600000.00        NaN
# 11      current_financial_liabilities        NaN   770613900000.00        NaN
# 12                 provisions_current        NaN    37790800000.00        NaN
# 13            current_tax_liabilities        NaN    21668500000.00        NaN
#
#           2023-09-30
# 0   2718140000000.00
# 1   1810117500000.00
# 2    784386700000.00
# 3    516579400000.00
# 4               0.00
# 5    536587000000.00
# 6     47124100000.00
# 7    131778700000.00
# 8   1025730800000.00
# 9    380650100000.00
# 10   332567100000.00
# 11   813071900000.00
# 12    43494800000.00
# 13    13271400000.00

# %%
def getResults(symbol,period_start=None,period_end=None,period_type='Quarterly'):

    export_dir = os.path.join('downloads')
    end_date = datetime.date.today()
    if period_end is not None:
        end_date = datetime.datetime.strptime(period_end,'%Y-%m-%d')    
    if period_start is not None:
        start_date = datetime.datetime.strptime(period_start,'%Y-%m-%d')
    else:
        if period_type = 'Annual':
            start_date = end_date - datetime.timedelta(days=368*4)
        else:
            start_date = end_date - datetime.timedelta(days=368)

    sql = "select results from financial_results where symbol='{}' and " \
          "period_ended >= '{}' and period_ended <= '{}' and period='{}' order by period_ended desc"
    results = pd.read_sql(sql.format(symbol,start_date.strftime('%Y-%m-%d'),end_date.strftime('%Y-%m-%d'),period_type),engine)
    result = pd.DataFrame()
    for inx in results.index:
        finres = pd.DataFrame.from_dict(json.loads(results.loc[inx]['results']), orient='index')
        finres.rename(columns={0:finres.loc['DateOfEndOfReportingPeriod'][0]},inplace=True)
        result = pd.concat([result,finres],axis=1)
    
    timestamp = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
    export_file = os.path.join(export_dir,symbol+"_"+start_date.strftime('%Y%m%d')+"_"+end_date.strftime('%Y%m%d')+"_"+period_type+"_"+timestamp+".csv")
    print(result)
    result.to_csv(export_file)
    return result
    # print(json.loads(results.iloc[1]['results']))

# %%
# Out:
# 0    HFCL
# Name: Symbol, dtype: object
# '{"ScripCode": "500183", "Symbol": "HFCL", "MSEISymbol": "NOTLISTED", "NameOfTheCompany": "HFCL Limited", "ClassOfSecurity": "Equity", "DateOfStartOfFinancialYear": "2024-04-01", "DateOfEndOfFinancialYear": "2025-03-31", "DateOfBoardMeetingWhenFinancialResultsWereApproved": "2024-07-24", "DateOnWhichPriorIntimationOfTheMeetingForConsideringFinancialResultsWasInformedToTheExchange": "2024-07-12", "DescriptionOfPresentationCurrency": "INR", "LevelOfRoundingUsedInFinancialStatements": "Crores", "ReportingQuarter": "First quarter", "StartTimeOfBoardMeeting": "17:00:00", "EndTimeOfBoardMeeting": "17:35:00", "DateOfStartOfBoardMeeting": "2024-07-24", "DateOfEndOfBoardMeeting": "2024-07-24", "DeclarationOfUnmodifiedOpinionOrStatementOnImpactOfAuditQualification": "Not applicable", "IsCompanyReportingMultisegmentOrSingleSegment": "Multi segment", "DateOfStartOfReportingPeriod": "2024-04-01", "DateOfEndOfReportingPeriod": "2024-06-30", "WhetherResultsAreAuditedOrUnaudited": "Unaudited", "NatureOfReportStandaloneConsolidated": "Consolidated", "RevenueFromOperations": "11582400000.00", "OtherIncome": "105000000.00", "Income": "11687400000.00", "CostOfMaterialsConsumed": "4113000000.00", "PurchasesOfStockInTrade": "4355600000.00", "ChangesInInventoriesOfFinishedGoodsWorkInProgressAndStockInTrade": "-274600000.00", "EmployeeBenefitExpense": "887000000.00", "FinanceCosts": "423100000.00", "DepreciationDepletionAndAmortisationExpense": "240700000.00", "OtherExpenses": "752700000.00", "Expenses": "10497500000.00", "ProfitBeforeExceptionalItemsAndTax": "1189900000.00", "ExceptionalItemsBeforeTax": "0.00", "ProfitBeforeTax": "1189900000.00", "CurrentTax": "214900000.00", "DeferredTax": "-133500000.00", "TaxExpense": "81400000.00", "NetMovementInRegulatoryDeferralAccountBalancesRelatedToProfitOrLossAndTheRelatedDeferredTaxMovement": "0.00", "ProfitLossForPeriodFromContinuingOperations": "1108500000.00", "ProfitLossFromDiscontinuedOperationsBeforeTax": "0.00", "TaxExpenseOfDiscontinuedOperations": "0.00", "ProfitLossFromDiscontinuedOperationsAfterTax": "0.00", "ShareOfProfitLossOfAssociatesAndJointVenturesAccountedForUsingEquityMethod": "-2000000.00", "ProfitLossForPeriod": "1106500000.00", "OtherComprehensiveIncomeNetOfTaxes": "1951000000.00", "ComprehensiveIncomeForThePeriod": "3057500000.00", "ProfitOrLossAttributableToOwnersOfParent": "1113000000.00", "ProfitOrLossAttributableToNonControllingInterests": "-6600000.00", "ComprehensiveIncomeForThePeriodAttributableToOwnersOfParent": "3064000000.00", "ComprehensiveIncomeForThePeriodAttributableToOwnersOfParentNonControllingInterests": "-6600000.00", "PaidUpValueOfEquityShareCapital": "1441800000.00", "FaceValueOfEquityShareCapital": "1", "BasicEarningsLossPerShareFromContinuingOperations": "0.77", "DilutedEarningsLossPerShareFromContinuingOperations": "0.77", "BasicEarningsLossPerShareFromDiscontinuedOperations": "0.00", "DilutedEarningsLossPerShareFromDiscontinuedOperations": "0.00", "BasicEarningsLossPerShareFromContinuingAndDiscontinuedOperations": "0.77", "DilutedEarningsLossPerShareFromContinuingAndDiscontinuedOperations": "0.77", "DisclosureOfNotesOnFinancialResultsExplanatoryTextBlock": "Notes :             1. The above Un-Audited Standalone & Consolidated Financial Results of the Company for the first quarter ended 30th June, 2024 have been reviewed and recommended by the Audit Committee and were approved by the Board of Directors of the Company at their respective meetings held on 24th July, 2024.           2. The above Results are in compliance with the Indian Accounting Standards (Ind-AS) as prescribed under Section 133 of the Companies Act, 2013 read with the Companies (Indian Accounting Standards) Rules, 2015 (as amended).            3. I) During the previous year, the Company had issued  5,10,14,491 equity shares of face value of Re. 1 each at an issue price of Rs.69/- per equity share (including premium of Rs.68/- per equity share), aggregating to Approx. Rs. 352.00 Crore (includin ...

# %%
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
assets = pytesseract.image_to_string(Image.open('tapo.png'))
liabilities = pytesseract.image_to_string(Image.open('tapo1.png'))
print(assets)
print(liabilities)

# %%
from strategies import stocks as st
tcs = st.Stock('TCS')
tcs.get_income_statement()
ratios = list(tcs.income_statement) + tcs.income_statement.values.tolist()
ratios
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ['income_statement',
#  '2024-06-30',
#  '2024-03-31',
#  '2023-12-31',
#  '2023-09-30',
#  ['total_revenue',
#   '635750000000.00',
#   '2453150000000.00',
#   '1829210000000.00',
#   '1214760000000.00'],
#  ['revenue',
#   '626130000000.00',
#   '2408930000000.00',
#   '1796560000000.00',
#   '1190730000000.00'],
#  ['other_income',
#   '9620000000.00',
#   '44220000000.00',
#   '32650000000.00',
#   '24030000000.00'],
#  ['total_expenses',
#   '473440000000.00',
#   '1823600000000.00',
#   '1368150000000.00',
#   '911570000000.00'],
#  ['materials_cost', '0.00', '0.00', '0.00', '0.00'],
#  ['employee_cost',
#   '364160000000.00',
#   '1401310000000.00',
#   '1049930000000.00',
#   '702710000000.00'],
#  ['depreciation_amortization',
#   '12200000000.00',
#   '49850000000.00',
#   '37390000000.00',
#   '25060000000.00'],
#  ['other_expenses',
#   '73840000000.00',
#   '327640000000.00',
#   '253900000000.00',
#   '170900000000.00'],
#  ['profit_before_tax',
#   '162310000000.00',
#   '619970000000.00',
#   '451480000000.00',
#   '303190000000.00'],
#  ['tax_expense',
#   '41260000000.00',
#   '158980000000.00',
#   '115510000000.00',
#   '78190000000.00'],
#  ['profit_loss',
#   '121050000000.00',
#   '460990000000.00',
#   '335970000000.00',
#   '225000000000.00']]

# %%
key = '1MVD2LBE1UBKFUX0'

from alpha_vantage.fundamentaldata import FundamentalData
import pandas as pd

def get_fundamental_data(symbol):
    api_key = key
    fd = FundamentalData(key=api_key, output_format='pandas')

    # Get company overview
    overview, _ = fd.get_company_overview(symbol)
    
    # Get earnings
    earnings, _ = fd.get_company_earnings(symbol)

    return overview, earnings

if __name__ == "__main__":
    symbol = input("Enter the stock symbol: ").upper()
    try:
        overview, earnings = get_fundamental_data(symbol)
        print(f"Overview for {symbol}:")
        print(overview)
        print("\nEarnings Data for {symbol}:")
        print(earnings)
    except Exception as e:
        print(f"Error: {e}")

# %%
url = "https://www.nseindia.com/get-quotes/equity?symbol=HDFCBANK#Corporate_Actions"

import pandas
import requests



headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

s = requests.Session()
response = s.get(url,headers=headers)
print(response.content)
# data = requests.get

# %%
oc.sort_values(['itm x oi'],ascending=False).head(1)['strike'].values[0]

# %%
import plotly.graph_objects as go
scrips = ['NIFTY 50','NIFTY BANK', 'INDIA VIX']
kitecodemap = pd.read_csv('kitensecodes.csv')
scrips = [kitecodemap[kitecodemap['tradingsymbol'] == scrip]['instrument_token'].values[0] for scrip in scrips]
to_date = datetime.date.today()
from_date = to_date - datetime.timedelta(days=30)
hist_data = []
for token in scrips:
    data = session.historical_data(token,from_date,to_date,interval='day',continuous=False)
    data = pd.DataFrame(data)
#     data['date'] = data['date'].apply(lambda x : datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S+05:30"))
#     data['date'] = data['date'].apply(lambda x : datetime.datetime.fromtimestamp(x))

    hist_data.append(data[data.columns[:-1]])
# hist_data[0]

# %%
import tkinter as tk

win = tk.Tk()

fig = go.Figure(data=[go.Candlestick(x=hist_data[2]['date'],
                open=hist_data[2]['open'],
                high=hist_data[2]['high'],
                low=hist_data[2]['low'],
                close=hist_data[2]['close'])])
fig.update_layout(xaxis_rangeslider_visible=False)


fig.show()

# %%
# import tradingDB as tdb
# tdbobj = tdb.tradingDB()
# grph = tdbobj.market_snapshot()

# ins = session.instruments(exchange='CDS')
# inspd = pd.DataFrame(ins)
# inspd[['tradingsymbol','instrument_token']].to_csv('kitemcxcodes.csv')

current_month = datetime.date.strftime(datetime.date.today(),'%b')
next_month = datetime.date.strftime(datetime.date.today() + datetime.timedelta(days=31),'%b') 
current_year = datetime.date.strftime(datetime.date.today(),'%y')
crude = 'GOLD'+current_year+next_month.upper()+'FUT'
usdinr = 'USDINR'+current_year+current_month.upper()+'FUT'

ins = session.instruments(exchange='MCX')
inspd = pd.DataFrame(ins)
# inspd[(inspd['tradingsymbol'].str.contains(u'GOLD*****FUT')) & (inspd['segment'] == 'MCX-FUT')].sort_values(by='expiry').head(1)
print(crude+'     '+str(inspd[inspd['tradingsymbol'] == crude]['instrument_token'].values[0]))


# session.quote('MCX:'+crude)

# %%
pd.DataFrame(session.historical_data(65260551,from_date,to_date,'day'))
pd.DataFrame(session.historical_data(2433027,from_date,to_date,'day'))

# %%
pd.DataFrame(session.quote('NSE:NIFTY BANK'))['NSE:NIFTY BANK']

# %%
variety = session.VARIETY_REGULAR
exchange= session.EXCHANGE_NFO
tradingsymbol='TATAPOWER23AUG250CE'
transaction_type=session.TRANSACTION_TYPE_SELL
quantity=3375
product= session.PRODUCT_NRML
order_type = session.ORDER_TYPE_LIMIT
price=15
validity=session.VALIDITY_DAY
disclosed_quantity=None
trigger_price=None
squareoff=None 
stoploss=None
trailing_stoploss=None
tag=None

margin = session.order_margins(variety,exchange, tradingsymbol, transaction_type, quantity, product, order_type, price,
                    validity, disclosed_quantity, trigger_price, squareoff=None, stoploss=None,
                    trailing_stoploss=None, tag=None)

margin

# %%
qt = session.quote('NSE:LIQUIDBEES')
qt

# %%
scrip = 'TATAPOWER'
atm = mu.find_atm(614,5)
atm

# %%
inspd = pd.DataFrame(ins)
#inspd = inspd[(inspd['name'] == scrip) & (inspd['expiry'] == expiry) & (inspd['strike'] >= 18000) & (inspd['strike'] <= 20500) ][['tradingsymbol','strike']]
inspd = inspd[(inspd['name'] == scrip) & (inspd['expiry'] == expiry) & (inspd['strike'] > 0)][['tradingsymbol','strike']]
inspd['tradingsymbol'] = 'NFO:' + inspd['tradingsymbol']
inspd.set_index('tradingsymbol',inplace=True)
inspd
inslist = list(inspd.index)
inslist = inslist[int(len(inslist)/2-len(inslist)/4):int(len(inslist)/2+len(inslist)/4)]
inslist

# %%
def kite_oc(df):
    def kitequote_to_oc(quote):
        oc = pd.DataFrame(quote)
        for key in quote.key:
            qt = quote[key]
            oc = pd.DataFrame(qt)
    for strike in set(list(df['strike'])):
        ce = 'NFO:'+ df[df['strike'] == strike]['tradingsymbol'].head(1).values[0]
        pe = 'NFO:'+ df[df['strike'] == strike]['tradingsymbol'].head(1).values[0]

# %%
oc = pd.DataFrame(qt).T
oc.index.name = 'tradingsymbol'
oc1 = oc.merge(inspd,on='tradingsymbol')[['strike','oi','volume','last_price']]

# %%
scrip = ['TATAPOWER']
expiry_list = [expiry1,expiry2,expiry3]
oc = mu.kite_OC(scrip,expiry_list)
oc.reset_index(inplace=True)

# %%
8 in [1,3,4,5]

# %%
oc.loc[oc['tradingsymbol'].str[-2:] == 'CE'].sort_values(by='oi',ascending=False).head(5).sort_values(by='strike')

# %%
oc.loc[oc['tradingsymbol'].str[-2:] == 'PE'].sort_values(by='oi',ascending=False).head(5).sort_values(by='strike')

# %%
name = 'TATAPOWER'
oi_tree = oc[oc['name'] == name]
for expiry in sorted(set(list(oc['expiry'])),reverse=True):
    oi_tree['oi_ce'+str(expiry)] = oc.loc[(oc['tradingsymbol'].str[-2:] == 'CE') & (oc['expiry'] == expiry),'oi']/oc[(oc['tradingsymbol'].str[-2:] == 'CE') & (oc['expiry'] == expiry)]['oi'].sum()
    oi_tree['oi_pe'+str(expiry)] = -oc.loc[(oc['tradingsymbol'].str[-2:] == 'PE') & (oc['expiry'] == expiry),'oi']/oc[(oc['tradingsymbol'].str[-2:] == 'PE') & (oc['expiry'] == expiry)]['oi'].sum()
oi_tree.fillna(0,inplace=True)

# %%
oi_tree

# %%
import matplotlib.pyplot as plt
oi_tree.sort_values(by=['expiry','strike'],ascending=[True,True],inplace=True)
fig, ax = plt.subplots(1,3,figsize=(20,10),squeeze=False) 

#oi_tree[['oi_ce','oi_pe']].plot(kind='barh')
i= 0
for exp in set(list(oc['expiry'])):
    print(exp)
    ax1 = ax[0,i]
    ax1.set_title(exp)
    ax1.grid()
    ax2 = ax[0,i].twinx()
    x_data = oi_tree[oi_tree['expiry'] == exp]['strike']
    y1_data = oi_tree[oi_tree['expiry'] == exp]['oi_ce'+str(exp)]
    y2_data = oi_tree[oi_tree['expiry'] == exp]['oi_pe'+str(exp)]
    ax1.set_xlabel('OI')
    ax1.set_ylabel('STRIKE')
    ax1.barh(x_data,y1_data,color='b')

    ax2.set_ylabel('STRIKE')
    ax2.barh(x_data,y2_data,color='g')

#     oi_tree[oi_tree['expiry'] == exp].plot(x='strike', y = 'oi_ce'+str(exp), ax = ax[0,i] ,title = exp, kind='barh',ylabel='OI') 
#     oi_tree[oi_tree['expiry'] == exp].plot(x='strike', y = 'oi_pe'+str(exp), ax = ax2,title = exp,secondary_y=True, kind='barh',color='g',ylabel='OI') 
#     ax2.set_ylabel('strike')
    i+=1
plt.show()

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                  index=['cobra', 'viper', 'sidewinder'],
                  columns=['max_speed', 'shield'])
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
for i in df.index:
    df.loc[i,'shield'] = df.loc[i,'shield']*df.loc[i,'shield']
print(df)
# Out:
#             max_speed  shield
# cobra               1       4
# viper               4      25
# sidewinder          7      64
