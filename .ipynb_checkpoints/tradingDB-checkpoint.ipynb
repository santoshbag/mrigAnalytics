# %%
import tradingDB as tdb
import pandas as pd

def highlight(s):
    if s.l_s == '':
        return ['background-color: yellow'] * len(s)
    else:
        return ['background-color: white'] * len(s)
# Out:
# C:\anaconda\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         scrip             instrument    l_s      qty  orig_liab  curr_liab  \
# 0    ASHOKLEY                               -10000.0   -26750.0   -28750.0
# 1    ASHOKLEY     ASHOKLEY23MAY140PE   Long  -5000.0   -12250.0    -6750.0
# 2    ASHOKLEY     ASHOKLEY23MAY145CE  Short  -5000.0   -14500.0   -22000.0
# 3   BANKNIFTY                                 -375.0  -399055.0  -499490.0
# 4   BANKNIFTY  BANKNIFTY23JUN41000PE   Long    -75.0   -23758.0   -20235.0
# 5   BANKNIFTY  BANKNIFTY23JUN41500PE   Long    -75.0   -30362.0   -26310.0
# 6   BANKNIFTY  BANKNIFTY23JUN42000PE   Long    -75.0   -39549.0   -34399.0
# 7   BANKNIFTY  BANKNIFTY23MAY42000PE   Long    -25.0    -7259.0    -5110.0
# 8   BANKNIFTY  BANKNIFTY23MAY42500PE   Long    -25.0   -10645.0    -7850.0
# 9   BANKNIFTY      BANKNIFTY23MAYFUT   Long     75.0        0.0        0.0
# 10  BANKNIFTY  BANKNIFTY23MAY41000CE  Short    -75.0  -128906.0  -171488.0
# 11  BANKNIFTY  BANKNIFTY23MAY41500CE  Short    -75.0   -95800.0  -137726.0
# 12  BANKNIFTY  BANKNIFTY23MAY41800PE  Short     50.0        0.0        0.0
# 13  BANKNIFTY  BANKNIFTY23MAY42000CE  Short    -50.0   -49526.0   -70652.0
# 14  BANKNIFTY  BANKNIFTY23MAY42500CE  Short    -25.0   -13250.0   -25720.0
# 15        IEX                               -11250.0   -85125.0   -86250.0
# 16        IEX          IEX23MAY150PE   Long  -3750.0   -13312.0    -8625.0
# 17        IEX        IEX23MAY147.5CE  Short  -3750.0   -35625.0   -42375.0
# 18        IEX          IEX23MAY150CE  Short  -3750.0   -36188.0   -35250.0
# 19      NIFTY                                 -600.0  -394238.0  -403845.0
# 20      NIFTY      NIFTY23DEC17000PE   Long   -200.0   -63320.0   -47080.0
# 21      NIFTY      NIFTY23DEC17500PE   Long   -100.0   -32250.0   -30855.0
# 22      NIFTY      NIFTY23JUN19000CE   Long     50.0        0.0        0.0
# 23      NIFTY      NIFTY23MAY17500PE   Long   -100.0   -17428.0    -4025.0
# 24      NIFTY      NIFTY23MAY17700PE   Long   -100.0   -24550.0    -6395.0
# 25      NIFTY      NIFTY23MAY18500CE   Long     50.0        0.0        0.0
# 26      NIFTY          NIFTY23MAYFUT   Long    150.0        0.0        0.0
# 27      NIFTY      NIFTY23DEC18000CE  Short   -200.0  -155948.0  -181390.0
# 28      NIFTY      NIFTY23DEC18500CE  Short   -200.0   -93800.0  -121520.0
# 29      NIFTY      NIFTY23MAY17350PE  Short     50.0        0.0        0.0
# 30      NIFTY      NIFTY23MAY17600PE  Short     50.0        0.0        0.0
# 31      NIFTY      NIFTY23MAY18000CE  Short    -50.0    -6942.0   -12580.0
# 32  TATAPOWER                                -6750.0   -24469.0   -25988.0
# 33  TATAPOWER    TATAPOWER23MAY190PE   Long  -3375.0    -9619.0    -4219.0
# 34  TATAPOWER    TATAPOWER23MAY200CE  Short  -3375.0   -14850.0   -21769.0
#
#      delta   theta      pnl
# 0  -1703.0   667.0  -2000.0
# 1   1174.0   363.0   5500.0
# 2  -2877.0   304.0  -7500.0
# 3    -77.0  2630.0 -81472.0
# 4     13.0   826.0   3522.0
# 5     16.0   867.0   4051.0
# 6     20.0   902.0   5150.0
# 7      5.0   360.0   2149.0
# 8      7.0   389.0   2795.0
# 9     75.0    75.0  23642.0
# 10   -71.0  -112.0 -42581.0
# 11   -67.0    70.0 -41926.0
# 12    -9.0  -691.0  -4678.0
# 13   -46.0  -117.0 -21126.0
# 14   -20.0    61.0 -12470.0
# 15 -4613.0   894.0  -1124.0
# 16  1032.0   379.0   4688.0
# 17 -2932.0   239.0  -6750.0
# 18 -2713.0   276.0    938.0
# 19   -32.0  1322.0  16914.0
# 20    39.0   588.0  16240.0
# 21    25.0   293.0   1395.0
# 22     7.0   -49.0   -610.0
# 23    13.0   458.0  13402.0
# 24    21.0   498.0  18155.0
# 25    10.0   -91.0   -202.0
# 26   150.0   150.0  33362.0
# 27  -140.0  -129.0 -25442.0
# 28  -113.0   -45.0 -27720.0
# 29    -5.0  -212.0  -4408.0
# 30    -8.0  -239.0  -1620.0
# 31   -31.0   100.0  -5638.0
# 32 -1329.0   617.0  -1519.0
# 33   578.0   298.0   5400.0
# 34 -1907.0   319.0  -6919.0
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:105: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = positions.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:107: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')
# G:\Mrig Analytics\mrigAnalytics\tradingDB.py:109: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')

# %%
pos = tdb.showDB(True)

df1 = pos.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()

df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')

df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')


df = (pd.concat([df1, df3])
        .reindex(df1.columns, axis=1)
        .fillna('')
        .sort_values(['scrip','l_s'], ascending=True,ignore_index=True))
#df.set_index('scrip',inplace=True)

df.style.apply(highlight, axis=1).format(precision=0)
# Out:
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_13212\2899713447.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = pos.groupby(by=['scrip','instrument','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round()
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_13212\2899713447.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df1.groupby(by=['scrip','l_s'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(instrument = '')
# C:\Users\Santosh Bag\AppData\Local\Temp\ipykernel_13212\2899713447.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df1.groupby(by=['scrip'], as_index=False)['qty','orig_liab','curr_liab','delta','theta','pnl'].sum().fillna(0).round().assign(l_s = '')

# %%
# Out:
# <style type="text/css">
# #T_6c673_row0_col0, #T_6c673_row0_col1, #T_6c673_row0_col2, #T_6c673_row0_col3, #T_6c673_row0_col4, #T_6c673_row0_col5, #T_6c673_row0_col6, #T_6c673_row0_col7, #T_6c673_row0_col8, #T_6c673_row3_col0, #T_6c673_row3_col1, #T_6c673_row3_col2, #T_6c673_row3_col3, #T_6c673_row3_col4, #T_6c673_row3_col5, #T_6c673_row3_col6, #T_6c673_row3_col7, #T_6c673_row3_col8, #T_6c673_row15_col0, #T_6c673_row15_col1, #T_6c673_row15_col2, #T_6c673_row15_col3, #T_6c673_row15_col4, #T_6c673_row15_col5, #T_6c673_row15_col6, #T_6c673_row15_col7, #T_6c673_row15_col8, #T_6c673_row19_col0, #T_6c673_row19_col1, #T_6c673_row19_col2, #T_6c673_row19_col3, #T_6c673_row19_col4, #T_6c673_row19_col5, #T_6c673_row19_col6, #T_6c673_row19_col7, #T_6c673_row19_col8, #T_6c673_row32_col0, #T_6c673_row32_col1, #T_6c673_row32_col2, #T_6c673_row32_col3, #T_6c673_row32_col4, #T_6c673_row32_col5, #T_6c673_row32_col6, #T_6c673_row32_col7, #T_6c673_row32_col8 {
#   background-color: yellow;
# }
# #T_6c673_row1_col0, #T_6c673_row1_col1, #T_6c673_row1_col2, #T_6c673_row1_col3, #T_6c673_row1_col4, #T_6c673_row1_col5, #T_6c673_row1_col6, #T_6c673_row1_col7, #T_6c673_row1_col8, #T_6c673_row2_col0, #T_6c673_row2_col1, #T_6c673_row2_col2, #T_6c673_row2_col3, #T_6c673_row2_col4, #T_6c673_row2_col5, #T_6c673_row2_col6, #T_6c673_row2_col7, #T_6c673_row2_col8, #T_6c673_row4_col0, #T_6c673_row4_col1, #T_6c673_row4_col2, #T_6c673_row4_col3, #T_6c673_row4_col4, #T_6c673_row4_col5, #T_6c673_row4_col6, #T_6c673_row4_col7, #T_6c673_row4_col8, #T_6c673_row5_col0, #T_6c673_row5_col1, #T_6c673_row5_col2, #T_6c673_row5_col3, #T_6c673_row5_col4, #T_6c673_row5_col5, #T_6c673_row5_col6, #T_6c673_row5_col7, #T_6c673_row5_col8, #T_6c673_row6_col0, #T_6c673_row6_col1, #T_6c673_row6_col2, #T_6c673_row6_col3, #T_6c673_row6_col4, #T_6c673_row6_col5, #T_6c673_row6_col6, #T_6c673_row6_col7, #T_6c673_row6_col8, #T_6c673_row7_col0, #T_6c673_row7_col1, #T_6c673_row7_col2, #T_6c673_row7_col3, #T_6c673_row7_col4, #T_6c673_row7_col5, #T_6c673_row7_col6, #T_6c673_row7_col7, #T_6c673_row7_col8, #T_6c673_row8_col0, #T_6c673_row8_col1, #T_6c673_row8_col2, #T_6c673_row8_col3, #T_6c673_row8_col4, #T_6c673_row8_col5, #T_6c673_row8_col6, #T_6c673_row8_col7, #T_6c673_row8_col8, #T_6c673_row9_col0, #T_6c673_row9_col1, #T_6c673_row9_col2, #T_6c673_row9_col3, #T_6c673_row9_col4, #T_6c673_row9_col5, #T_6c673_row9_col6, #T_6c673_row9_col7, #T_6c673_row9_col8, #T_6c673_row10_col0, #T_6c673_row10_col1, #T_6c673_row10_col2, #T_6c673_row10_col3, #T_6c673_row10_col4, #T_6c673_row10_col5, #T_6c673_row10_col6, #T_6c673_row10_col7, #T_6c673_row10_col8, #T_6c673_row11_col0, #T_6c673_row11_col1, #T_6c673_row11_col2, #T_6c673_row11_col3, #T_6c673_row11_col4, #T_6c673_row11_col5, #T_6c673_row11_col6, #T_6c673_row11_col7, #T_6c673_row11_col8, #T_6c673_row12_col0, #T_6c673_row12_col1, #T_6c673_row12_col2, #T_6c673_row12_col3, #T_6c673_row12_col4, #T_6c673_row12_col5, #T_6c673_row12_col6, #T_6c673_row12_col7, #T_6c673_row12_col8, #T_6c673_row13_col0, #T_6c673_row13_col1, #T_6c673_row13_col2, #T_6c673_row13_col3, #T_6c673_row13_col4, #T_6c673_row13_col5, #T_6c673_row13_col6, #T_6c673_row13_col7, #T_6c673_row13_col8, #T_6c673_row14_col0, #T_6c673_row14_col1, #T_6c673_row14_col2, #T_6c673_row14_col3, #T_6c673_row14_col4, #T_6c673_row14_col5, #T_6c673_row14_col6, #T_6c673_row14_col7, #T_6c673_row14_col8, #T_6c673_row16_col0, #T_6c673_row16_col1, #T_6c673_row16_col2, #T_6c673_row16_col3, #T_6c673_row16_col4, #T_6c673_row16_col5, #T_6c673_row16_col6, #T_6c673_row16_col7, #T_6c673_row16_col8, #T_6c673_row17_col0, #T_6c673_row17_col1, #T_6c673_row17_col2, #T_6c673_row17_col3, #T_6c673_row17_col4, #T_6c673_row17_col5, #T_6c673_row17_col6, #T_6c673_row17_col7, #T_6c673_row17_col8, #T_6c673_row18_col0, #T_6c673_row18_col1, #T_6c673_row18_col2, #T_6c673_row18_col3, #T_6c673_row18_col4, #T_6c673_row18_col5, #T_6c673_row18_col6, #T_6c673_row18_col7, #T_6c673_row18_col8, #T_6c673_row20_col0, #T_6c673_row20_col1, #T_6c673_row20_col2, #T_6c673_row20_col3, #T_6c673_row20_col4, #T_6c673_row20_col5, #T_6c673_row20_col6, #T_6c673_row20_col7, #T_6c673_row20_col8, #T_6c673_row21_col0, #T_6c673_row21_col1, #T_6c673_row21_col2, #T_6c673_row21_col3, #T_6c673_row21_col4, #T_6c673_row21_col5, #T_6c673_row21_col6, #T_6c673_row21_col7, #T_6c673_row21_col8, #T_6c673_row22_col0, #T_6c673_row22_col1, #T_6c673_row22_col2, #T_6c673_row22_col3, #T_6c673_row22_col4, #T_6c673_row22_col5, #T_6c673_row22_col6, #T_6c673_row22_col7, #T_6c673_row22_col8, #T_6c673_row23_col0, #T_6c673_row23_col1, #T_6c673_row23_col2, #T_6c673_row23_col3, #T_6c673_row23_col4, #T_6c673_row23_col5, #T_6c673_row23_col6, #T_6c673_row23_col7, #T_6c673_row23_col8, #T_6c673_row24_col0, #T_6c673_row24_col1, #T_6c673_row24_col2, #T_6c673_row24_col3, #T_6c673_row24_col4, #T_6c673_row24_col5, #T_6c673_row24_col6, #T_6c673_row24_col7, #T_6c673_row24_col8, #T_6c673_row25_col0, #T_6c673_row25_col1, #T_6c673_row25_col2, #T_6c673_row25_col3, #T_6c673_row25_col4 ...
#   background-color: white;
# }
# </style>
# <table id="T_6c673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c673_level0_col0" class="col_heading level0 col0" >scrip</th>
#       <th id="T_6c673_level0_col1" class="col_heading level0 col1" >instrument</th>
#       <th id="T_6c673_level0_col2" class="col_heading level0 col2" >l_s</th>
#       <th id="T_6c673_level0_col3" class="col_heading level0 col3" >qty</th>
#       <th id="T_6c673_level0_col4" class="col_heading level0 col4" >orig_liab</th>
#       <th id="T_6c673_level0_col5" class="col_heading level0 col5" >curr_liab</th>
#       <th id="T_6c673_level0_col6" class="col_heading level0 col6" >delta</th>
#       <th id="T_6c673_level0_col7" class="col_heading level0 col7" >theta</th>
#       <th id="T_6c673_level0_col8" class="col_heading level0 col8" >pnl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c673_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c673_row0_col0" class="data row0 col0" >ASHOKLEY</td>
#       <td id="T_6c673_row0_col1" class="data row0 col1" ></td>
#       <td id="T_6c673_row0_col2" class="data row0 col2" ></td>
#       <td id="T_6c673_row0_col3" class="data row0 col3" >-10000</td>
#       <td id="T_6c673_row0_col4" class="data row0 col4" >-26750</td>
#       <td id="T_6c673_row0_col5" class="data row0 col5" >-28750</td>
#       <td id="T_6c673_row0_col6" class="data row0 col6" >-17
