# %%
import mrigstatics as ms
from fredapi import Fred
fred = Fred(api_key=ms.fred_api)

fred.search('india auto ')
# fred.get_series('INDPRMNTO01GYSAM')
# Out:
#                                     id realtime_start realtime_end  \
# series id
# INDSLRTCR03MLSAM      INDSLRTCR03MLSAM     2024-11-21   2024-11-21
# INDSLRTCR03IXOBSAQ  INDSLRTCR03IXOBSAQ     2024-11-21   2024-11-21
# INDSLRTCR03MLSAQ      INDSLRTCR03MLSAQ     2024-11-21   2024-11-21
# INDSLRTCR03IXOBSAM  INDSLRTCR03IXOBSAM     2024-11-21   2024-11-21
#
#                                                                 title  \
# series id
# INDSLRTCR03MLSAM    Sales: Retail Trade: Car Registration: Passeng...
# INDSLRTCR03IXOBSAQ  Sales: Retail Trade: Car Registration: Passeng...
# INDSLRTCR03MLSAQ    Sales: Retail Trade: Car Registration: Passeng...
# INDSLRTCR03IXOBSAM  Production, Sales, Work Started and Orders: Pa...
#
#                    observation_start observation_end  frequency  \
# series id
# INDSLRTCR03MLSAM          2001-05-01      2022-03-01    Monthly
# INDSLRTCR03IXOBSAQ        2001-07-01      2021-07-01  Quarterly
# ...
