# %%
import stockScreener as ss

# %%
bigM = ss.big_money_zack()

# %%
smg
# Out:
#             ratio_date                  industry  basic_eps       close  \
# symbol
# JINDALSAW   2019-03-30                    METALS      15.64   85.355556
# CHAMBLFERT  2019-03-30  FERTILISERS & PESTICIDES      13.10  165.788889
# BIRLACORPN  2019-03-30  CEMENT & CEMENT PRODUCTS      17.89  520.183333
# KEC         2019-03-30              CONSTRUCTION      19.36  297.827778
# KTKBANK     2019-03-30        FINANCIAL SERVICES      16.89  131.861111
# SOBHA       2019-03-30              CONSTRUCTION      30.23  485.872222
# TIMKEN      2019-03-30  INDUSTRIAL MANUFACTURING      19.92  580.900000
#
#             eps_growth  sales_per_share  earnings_retention_ratio  \
# symbol
# JINDALSAW     0.296849       854.771881                       0.0
# CHAMBLFERT    0.135182       611.825487                       0.0
# BIRLACORPN    0.196656      1588.073148                       0.0
# KEC           0.157203       779.190498                       0.0
# ...

# %%
smg = ss.small_cap_growth()

# %%
import strategies.stocks as st

# %%
bata = st.Stock('BATAINDIA')

# %%
bata.quote

# %%
bata = mu.getStockQuote('BATAINDIA')

# %%
bata

# %%
import mrigutilities as mu

# %%
bata = mu.getStockQuote('BATAINDIA')

# %%
bata
# Out:
# {'adhocMargin': '-',
#  'applicableMargin': 12.5,
#  'averagePrice': 1158.24,
#  'basePrice': 1165.5,
#  'bcEndDate': '20-JUL-18',
#  'bcStartDate': '11-JUL-18',
#  'buyPrice1': 1157.35,
#  'buyPrice2': 1157.25,
#  'buyPrice3': 1157.2,
#  'buyPrice4': 1157.15,
#  'buyPrice5': 1157.1,
#  'buyQuantity1': 1,
#  'buyQuantity2': 33,
#  'buyQuantity3': 33,
#  'buyQuantity4': 5,
#  'buyQuantity5': 2,
#  'change': -7.55,
#  'closePrice': 0.0,
#  'cm_adj_high_dt': '10-JAN-19',
#  'cm_adj_low_dt': '06-FEB-18',
#  'cm_ffm': 7040.55,
#  'companyName': 'Bata India Limited',
#  'css_status_desc': 'Listed',
#  'dayHigh': 1166.85,
#  'dayLow': 1151.0,
#  'deliveryQuantity': 258859,
#  'deliveryToTradedQuantity': 23.36,
#  'exDate': '09-JUL-18',
#  'extremeLossMargin': 5.0,
#  'faceValue': 5.0,
#  'high52': 1169.9,
#  'indexVar': '-',
#  'isExDateFlag': False,
#  'isinCode': 'INE176A01028',
#  'lastPrice': 1157.95,
#  'low52': 653.1,
#  'marketType': 'N',
#  'momentum': 2314.2,
#  'ndEndDate': '-',
# ...
